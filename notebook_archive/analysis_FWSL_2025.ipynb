# %% [markdown]
# ## Preliminary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./FWSL25_matches2.csv')

# %%
df.shape
# Out:
# (1658, 89)

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns#all numeric columns
num_cols = ['duration','distance_km','sprint_distance_m','power_plays','energy_kcal','impacts',
                   'player_load','top_speed_kmh','distance_per_min_mmin','power_score_wkg','work_ratio','max_acceleration_mss','max_deceleration_mss']# numeric columns of high interest
intensity_metrics =['player_load','top_speed_kmh','distance_per_min_mmin','power_score_wkg','work_ratio','max_acceleration_mss','max_deceleration_mss']
volume_metrics = ['distance_km','sprint_distance_m','power_plays','energy_kcal','impacts']

# %%
df['match_day'] = df['match_day'].str.replace('Wmd', 'MD')

# %%
from IPython.display import HTML

def style_table_for_docs(df, hide_index=False):
    styled = (
        df.style
        .set_properties(**{
            'color': 'black',
            'background-color': 'white',
            'border': '1px solid black',
            'text-align': 'center',
            'padding': '2px'  # reduces row height
        })
        .set_table_styles([
            {'selector': 'th', 'props': [
                ('color', 'black'), 
                ('border', '1px solid black'),
                ('padding', '2px')  # also reduce header row height
            ]},
            {'selector': 'td', 'props': [
                ('color', 'black'), 
                ('border', '1px solid black'),
                ('padding', '2px')
            ]},
            {'selector': 'table', 'props': [
                ('border', '2px solid black'), 
                ('border-collapse', 'collapse')
            ]}
        ])
    )
    
    if hide_index:
        styled = styled.hide(axis='index')

    return styled

# %%
df['total_accelerations'] = df[
	[
		'accelerations_zone_count:_1__2_mss',
		'accelerations_zone_count:_2__3_mss',
		'accelerations_zone_count:_3__4_mss',
		'accelerations_zone_count:_>_4_mss'
	]
].sum(axis=1)

df['total_decelerations'] = df[
	[
		'deceleration_zone_count:_1__2_mss',
		'deceleration_zone_count:_2__3_mss',
		'deceleration_zone_count:_3__4_mss',
		'deceleration_zone_count:_>_4_mss'
	]
].sum(axis=1)

# %%
volume_metrics.append('total_accelerations')
volume_metrics.append('total_decelerations')

df['acc_counts_per_min'] = df['total_accelerations'] / df['duration']
df['dec_counts_per_min'] = df['total_decelerations'] / df['duration']

intensity_metrics.append('acc_counts_per_min')
intensity_metrics.append('dec_counts_per_min')

# %% [markdown]
# ## Summary

# %%
table1 = df[['player_load','power_score_wkg','work_ratio']].agg(['sum', 'mean', 'std']).T
style_table_for_docs(table1.round(2))
# Out:
# <style type="text/css">
# #T_1d07f th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_1d07f td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_1d07f table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_1d07f_row0_col0, #T_1d07f_row0_col1, #T_1d07f_row0_col2, #T_1d07f_row1_col0, #T_1d07f_row1_col1, #T_1d07f_row1_col2, #T_1d07f_row2_col0, #T_1d07f_row2_col1, #T_1d07f_row2_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_1d07f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d07f_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_1d07f_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_1d07f_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d07f_level0_row0" class="row_heading level0 row0" >player_load</th>
#       <td id="T_1d07f_row0_col0" class="data row0 col0" >599477.840000</td>
#       <td id="T_1d07f_row0_col1" class="data row0 col1" >361.570000</td>
#       <td id="T_1d07f_row0_col2" class="data row0 col2" >94.260000</td>
#     </tr>
#     <tr>
#       <th id="T_1d07f_level0_row1" class="row_heading level0 row1" >power_score_wkg</th>
#       <td id="T_1d07f_row1_col0" class="data row1 col0" >19248.830000</td>
#       <td id="T_1d07f_row1_col1" class="data row1 col1" >11.610000</td>
#       <td id="T_1d07f_row1_col2" class="data row1 col2" >3.120000</td>
#     </tr>
#     <tr>
#       <th id="T_1d07f_level0_row2" class="row_heading level0 row2" >work_ratio</th>
#       <td id="T_1d07f_row2_col0" class="data row2 col0" >98163.500000</td>
#       <td id="T_1d07f_row2_col1" class="data row2 col1" >59.210000</td>
#       <td id="T_1d07f_row2_col2" class="data row2 col2" >17.570000</td>
#     </tr>
#   </tbody>
# </table>

# %%
summary_table_intensity = df[intensity_metrics].agg(['max', 'mean', 'std']).T
style_table_for_docs(summary_table_intensity.round(2))
# Out:
# <style type="text/css">
# #T_5b911 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_5b911 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_5b911 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_5b911_row0_col0, #T_5b911_row0_col1, #T_5b911_row0_col2, #T_5b911_row1_col0, #T_5b911_row1_col1, #T_5b911_row1_col2, #T_5b911_row2_col0, #T_5b911_row2_col1, #T_5b911_row2_col2, #T_5b911_row3_col0, #T_5b911_row3_col1, #T_5b911_row3_col2, #T_5b911_row4_col0, #T_5b911_row4_col1, #T_5b911_row4_col2, #T_5b911_row5_col0, #T_5b911_row5_col1, #T_5b911_row5_col2, #T_5b911_row6_col0, #T_5b911_row6_col1, #T_5b911_row6_col2, #T_5b911_row7_col0, #T_5b911_row7_col1, #T_5b911_row7_col2, #T_5b911_row8_col0, #T_5b911_row8_col1, #T_5b911_row8_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_5b911">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b911_level0_col0" class="col_heading level0 col0" >max</th>
#       <th id="T_5b911_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_5b911_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b911_level0_row0" class="row_heading level0 row0" >player_load</th>
#       <td id="T_5b911_row0_col0" class="data row0 col0" >593.190000</td>
#       <td id="T_5b911_row0_col1" class="data row0 col1" >361.570000</td>
#       <td id="T_5b911_row0_col2" class="data row0 col2" >94.260000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row1" class="row_heading level0 row1" >top_speed_kmh</th>
#       <td id="T_5b911_row1_col0" class="data row1 col0" >32.400000</td>
#       <td id="T_5b911_row1_col1" class="data row1 col1" >25.620000</td>
#       <td id="T_5b911_row1_col2" class="data row1 col2" >2.010000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row2" class="row_heading level0 row2" >distance_per_min_mmin</th>
#       <td id="T_5b911_row2_col0" class="data row2 col0" >116.960000</td>
#       <td id="T_5b911_row2_col1" class="data row2 col1" >74.850000</td>
#       <td id="T_5b911_row2_col2" class="data row2 col2" >19.840000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row3" class="row_heading level0 row3" >power_score_wkg</th>
#       <td id="T_5b911_row3_col0" class="data row3 col0" >18.790000</td>
#       <td id="T_5b911_row3_col1" class="data row3 col1" >11.610000</td>
#       <td id="T_5b911_row3_col2" class="data row3 col2" >3.120000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row4" class="row_heading level0 row4" >work_ratio</th>
#       <td id="T_5b911_row4_col0" class="data row4 col0" >101.920000</td>
#       <td id="T_5b911_row4_col1" class="data row4 col1" >59.210000</td>
#       <td id="T_5b911_row4_col2" class="data row4 col2" >17.570000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row5" class="row_heading level0 row5" >max_acceleration_mss</th>
#       <td id="T_5b911_row5_col0" class="data row5 col0" >10.000000</td>
#       <td id="T_5b911_row5_col1" class="data row5 col1" >5.230000</td>
#       <td id="T_5b911_row5_col2" class="data row5 col2" >0.570000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row6" class="row_heading level0 row6" >max_deceleration_mss</th>
#       <td id="T_5b911_row6_col0" class="data row6 col0" >10.000000</td>
#       <td id="T_5b911_row6_col1" class="data row6 col1" >6.440000</td>
#       <td id="T_5b911_row6_col2" class="data row6 col2" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row7" class="row_heading level0 row7" >acc_counts_per_min</th>
#       <td id="T_5b911_row7_col0" class="data row7 col0" >5.980000</td>
#       <td id="T_5b911_row7_col1" class="data row7 col1" >3.580000</td>
#       <td id="T_5b911_row7_col2" class="data row7 col2" >1.010000</td>
#     </tr>
#     <tr>
#       <th id="T_5b911_level0_row8" class="row_heading level0 row8" >dec_counts_per_min</th>
#       <td id="T_5b911_row8_col0" class="data row8 col0" >5.970000</td>
#       <td id="T_5b911_row8_col1" class="data row8 col1" >3.470000</td>
#       <td id="T_5b911_row8_col2" class="data row8 col2" >0.990000</td>
#     </tr>
#   </tbody>
# </table>

# %%
summary_table_volume = df[volume_metrics].agg(['sum','mean', 'std']).T
style_table_for_docs(summary_table_volume.round(2))
# Out:
# <style type="text/css">
# #T_ac86c th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_ac86c td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_ac86c table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_ac86c_row0_col0, #T_ac86c_row0_col1, #T_ac86c_row0_col2, #T_ac86c_row1_col0, #T_ac86c_row1_col1, #T_ac86c_row1_col2, #T_ac86c_row2_col0, #T_ac86c_row2_col1, #T_ac86c_row2_col2, #T_ac86c_row3_col0, #T_ac86c_row3_col1, #T_ac86c_row3_col2, #T_ac86c_row4_col0, #T_ac86c_row4_col1, #T_ac86c_row4_col2, #T_ac86c_row5_col0, #T_ac86c_row5_col1, #T_ac86c_row5_col2, #T_ac86c_row6_col0, #T_ac86c_row6_col1, #T_ac86c_row6_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_ac86c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac86c_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_ac86c_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_ac86c_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac86c_level0_row0" class="row_heading level0 row0" >distance_km</th>
#       <td id="T_ac86c_row0_col0" class="data row0 col0" >12258.410000</td>
#       <td id="T_ac86c_row0_col1" class="data row0 col1" >7.390000</td>
#       <td id="T_ac86c_row0_col2" class="data row0 col2" >1.970000</td>
#     </tr>
#     <tr>
#       <th id="T_ac86c_level0_row1" class="row_heading level0 row1" >sprint_distance_m</th>
#       <td id="T_ac86c_row1_col0" class="data row1 col0" >710881.850000</td>
#       <td id="T_ac86c_row1_col1" class="data row1 col1" >428.760000</td>
#       <td id="T_ac86c_row1_col2" class="data row1 col2" >220.350000</td>
#     </tr>
#     <tr>
#       <th id="T_ac86c_level0_row2" class="row_heading level0 row2" >power_plays</th>
#       <td id="T_ac86c_row2_col0" class="data row2 col0" >62486.000000</td>
#       <td id="T_ac86c_row2_col1" class="data row2 col1" >37.690000</td>
#       <td id="T_ac86c_row2_col2" class="data row2 col2" >15.270000</td>
#     </tr>
#     <tr>
#       <th id="T_ac86c_level0_row3" class="row_heading level0 row3" >energy_kcal</th>
#       <td id="T_ac86c_row3_col0" class="data row3 col0" >1212514.630000</td>
#       <td id="T_ac86c_row3_col1" class="data row3 col1" >731.310000</td>
#       <td id="T_ac86c_row3_col2" class="data row3 col2" >208.920000</td>
#     </tr>
#     <tr>
#       <th id="T_ac86c_level0_row4" class="row_heading level0 row4" >impacts</th>
#       <td id="T_ac86c_row4_col0" class="data row4 col0" >9398.000000</td>
#       <td id="T_ac86c_row4_col1" class="data row4 col1" >5.670000</td>
#       <td id="T_ac86c_row4_col2" class="data row4 col2" >5.580000</td>
#     </tr>
#     <tr>
#       <th id="T_ac86c_level0_row5" class="row_heading level0 row5" >total_accelerations</th>
#       <td id="T_ac86c_row5_col0" class="data row5 col0" >585631.000000</td>
#       <td id="T_ac86c_row5_col1" class="data row5 col1" >353.220000</td>
#       <td id="T_ac86c_row5_col2" class="data row5 col2" >99.960000</td>
#     </tr>
#     <tr>
#       <th id="T_ac86c_level0_row6" class="row_heading level0 row6" >total_decelerations</th>
#       <td id="T_ac86c_row6_col0" class="data row6 col0" >568423.000000</td>
#       <td id="T_ac86c_row6_col1" class="data row6 col1" >342.840000</td>
#       <td id="T_ac86c_row6_col2" class="data row6 col2" >98.190000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Data Overview

# %%
unique_players_per_club = df.groupby('club_for')['p_name'].nunique().reset_index()
unique_players_per_club.columns = ['club_for', 'unique_players']
style_table_for_docs(unique_players_per_club.sort_values(by='unique_players', ascending=False))
# Out:
# <style type="text/css">
# #T_4fd70 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4fd70 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4fd70 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_4fd70_row0_col0, #T_4fd70_row0_col1, #T_4fd70_row1_col0, #T_4fd70_row1_col1, #T_4fd70_row2_col0, #T_4fd70_row2_col1, #T_4fd70_row3_col0, #T_4fd70_row3_col1, #T_4fd70_row4_col0, #T_4fd70_row4_col1, #T_4fd70_row5_col0, #T_4fd70_row5_col1, #T_4fd70_row6_col0, #T_4fd70_row6_col1, #T_4fd70_row7_col0, #T_4fd70_row7_col1, #T_4fd70_row8_col0, #T_4fd70_row8_col1, #T_4fd70_row9_col0, #T_4fd70_row9_col1, #T_4fd70_row10_col0, #T_4fd70_row10_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_4fd70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fd70_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_4fd70_level0_col1" class="col_heading level0 col1" >unique_players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fd70_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_4fd70_row0_col0" class="data row0 col0" >She Maroons Fc</td>
#       <td id="T_4fd70_row0_col1" class="data row0 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4fd70_row1_col0" class="data row1 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_4fd70_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_4fd70_row2_col0" class="data row2 col0" >Kampala Queens Fc</td>
#       <td id="T_4fd70_row2_col1" class="data row2 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_4fd70_row3_col0" class="data row3 col0" >Amus College Wfc</td>
#       <td id="T_4fd70_row3_col1" class="data row3 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_4fd70_row4_col0" class="data row4 col0" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_4fd70_row4_col1" class="data row4 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_4fd70_row5_col0" class="data row5 col0" >Makerere University Wfc</td>
#       <td id="T_4fd70_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_4fd70_row6_col0" class="data row6 col0" >Lady Doves Fc</td>
#       <td id="T_4fd70_row6_col1" class="data row6 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_4fd70_row7_col0" class="data row7 col0" >Wakiso Hill Wfc</td>
#       <td id="T_4fd70_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_4fd70_row8_col0" class="data row8 col0" >Rines Ss Wfc</td>
#       <td id="T_4fd70_row8_col1" class="data row8 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_4fd70_row9_col0" class="data row9 col0" >Olila Hs Wfc</td>
#       <td id="T_4fd70_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_4fd70_level0_row10" class="row_heading level0 row10" >7</th>
#       <td id="T_4fd70_row10_col0" class="data row10 col0" >She Corporates Fc</td>
#       <td id="T_4fd70_row10_col1" class="data row10 col1" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
players_match_days = df.groupby(['p_name', 'player_club_'])['match_day'].nunique().reset_index()
players_match_days.columns = ['p_name', 'player_club_', 'unique_match_days']
style_table_for_docs(players_match_days.sort_values(by='unique_match_days', ascending=False).head(10))
# Out:
# <style type="text/css">
# #T_486a3 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_486a3 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_486a3 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_486a3_row0_col0, #T_486a3_row0_col1, #T_486a3_row0_col2, #T_486a3_row1_col0, #T_486a3_row1_col1, #T_486a3_row1_col2, #T_486a3_row2_col0, #T_486a3_row2_col1, #T_486a3_row2_col2, #T_486a3_row3_col0, #T_486a3_row3_col1, #T_486a3_row3_col2, #T_486a3_row4_col0, #T_486a3_row4_col1, #T_486a3_row4_col2, #T_486a3_row5_col0, #T_486a3_row5_col1, #T_486a3_row5_col2, #T_486a3_row6_col0, #T_486a3_row6_col1, #T_486a3_row6_col2, #T_486a3_row7_col0, #T_486a3_row7_col1, #T_486a3_row7_col2, #T_486a3_row8_col0, #T_486a3_row8_col1, #T_486a3_row8_col2, #T_486a3_row9_col0, #T_486a3_row9_col1, #T_486a3_row9_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_486a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_486a3_level0_col0" class="col_heading level0 col0" >p_name</th>
#       <th id="T_486a3_level0_col1" class="col_heading level0 col1" >player_club_</th>
#       <th id="T_486a3_level0_col2" class="col_heading level0 col2" >unique_match_days</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_486a3_level0_row0" class="row_heading level0 row0" >83</th>
#       <td id="T_486a3_row0_col0" class="data row0 col0" >Joweria Babirye</td>
#       <td id="T_486a3_row0_col1" class="data row0 col1" >She Maroons Fc</td>
#       <td id="T_486a3_row0_col2" class="data row0 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row1" class="row_heading level0 row1" >154</th>
#       <td id="T_486a3_row1_col0" class="data row1 col0" >Samalie Nakacwa</td>
#       <td id="T_486a3_row1_col1" class="data row1 col1" >Kawempe Muslim Lfc</td>
#       <td id="T_486a3_row1_col2" class="data row1 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row2" class="row_heading level0 row2" >164</th>
#       <td id="T_486a3_row2_col0" class="data row2 col0" >Sharifah Nakimera</td>
#       <td id="T_486a3_row2_col1" class="data row2 col1" >Kawempe Muslim Lfc</td>
#       <td id="T_486a3_row2_col2" class="data row2 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row3" class="row_heading level0 row3" >31</th>
#       <td id="T_486a3_row3_col0" class="data row3 col0" >Comfort Aculu</td>
#       <td id="T_486a3_row3_col1" class="data row3 col1" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_486a3_row3_col2" class="data row3 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row4" class="row_heading level0 row4" >96</th>
#       <td id="T_486a3_row4_col0" class="data row4 col0" >Latifah Nakasi</td>
#       <td id="T_486a3_row4_col1" class="data row4 col1" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_486a3_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row5" class="row_heading level0 row5" >78</th>
#       <td id="T_486a3_row5_col0" class="data row5 col0" >Jolly Kobusinge</td>
#       <td id="T_486a3_row5_col1" class="data row5 col1" >Kawempe Muslim Lfc</td>
#       <td id="T_486a3_row5_col2" class="data row5 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row6" class="row_heading level0 row6" >155</th>
#       <td id="T_486a3_row6_col0" class="data row6 col0" >Shadia Nabirye</td>
#       <td id="T_486a3_row6_col1" class="data row6 col1" >Kawempe Muslim Lfc</td>
#       <td id="T_486a3_row6_col2" class="data row6 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row7" class="row_heading level0 row7" >81</th>
#       <td id="T_486a3_row7_col0" class="data row7 col0" >Jovia Nakirya</td>
#       <td id="T_486a3_row7_col1" class="data row7 col1" >Rines Ss Wfc</td>
#       <td id="T_486a3_row7_col2" class="data row7 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row8" class="row_heading level0 row8" >46</th>
#       <td id="T_486a3_row8_col0" class="data row8 col0" >Esther Namataka</td>
#       <td id="T_486a3_row8_col1" class="data row8 col1" >Amus College Wfc</td>
#       <td id="T_486a3_row8_col2" class="data row8 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_486a3_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_486a3_row9_col0" class="data row9 col0" >Agnes Nabukenya</td>
#       <td id="T_486a3_row9_col1" class="data row9 col1" >Kawempe Muslim Lfc</td>
#       <td id="T_486a3_row9_col2" class="data row9 col2" >17</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate average number of unique players per matchday for each club
players_per_club_day = df.groupby(['club_for', 'match_day'])['p_name'].nunique().reset_index()
avg_players_per_matchday = players_per_club_day.groupby('club_for')['p_name'].mean().reset_index()
avg_players_per_matchday.columns = ['club_for', 'avg_players_per_matchday']
style_table_for_docs(avg_players_per_matchday.sort_values(by='avg_players_per_matchday', ascending=False))
# Out:
# <style type="text/css">
# #T_3ccac th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3ccac td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3ccac table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3ccac_row0_col0, #T_3ccac_row0_col1, #T_3ccac_row1_col0, #T_3ccac_row1_col1, #T_3ccac_row2_col0, #T_3ccac_row2_col1, #T_3ccac_row3_col0, #T_3ccac_row3_col1, #T_3ccac_row4_col0, #T_3ccac_row4_col1, #T_3ccac_row5_col0, #T_3ccac_row5_col1, #T_3ccac_row6_col0, #T_3ccac_row6_col1, #T_3ccac_row7_col0, #T_3ccac_row7_col1, #T_3ccac_row8_col0, #T_3ccac_row8_col1, #T_3ccac_row9_col0, #T_3ccac_row9_col1, #T_3ccac_row10_col0, #T_3ccac_row10_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_3ccac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ccac_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_3ccac_level0_col1" class="col_heading level0 col1" >avg_players_per_matchday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ccac_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_3ccac_row0_col0" class="data row0 col0" >She Maroons Fc</td>
#       <td id="T_3ccac_row0_col1" class="data row0 col1" >12.050000</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_3ccac_row1_col0" class="data row1 col0" >Makerere University Wfc</td>
#       <td id="T_3ccac_row1_col1" class="data row1 col1" >11.571429</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_3ccac_row2_col0" class="data row2 col0" >Wakiso Hill Wfc</td>
#       <td id="T_3ccac_row2_col1" class="data row2 col1" >11.250000</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_3ccac_row3_col0" class="data row3 col0" >Amus College Wfc</td>
#       <td id="T_3ccac_row3_col1" class="data row3 col1" >11.058824</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_3ccac_row4_col0" class="data row4 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_3ccac_row4_col1" class="data row4 col1" >11.052632</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_3ccac_row5_col0" class="data row5 col0" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_3ccac_row5_col1" class="data row5 col1" >10.500000</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3ccac_row6_col0" class="data row6 col0" >Rines Ss Wfc</td>
#       <td id="T_3ccac_row6_col1" class="data row6 col1" >10.294118</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_3ccac_row7_col0" class="data row7 col0" >Kampala Queens Fc</td>
#       <td id="T_3ccac_row7_col1" class="data row7 col1" >9.230769</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_3ccac_row8_col0" class="data row8 col0" >Olila Hs Wfc</td>
#       <td id="T_3ccac_row8_col1" class="data row8 col1" >7.700000</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_3ccac_row9_col0" class="data row9 col0" >She Corporates Fc</td>
#       <td id="T_3ccac_row9_col1" class="data row9 col1" >6.666667</td>
#     </tr>
#     <tr>
#       <th id="T_3ccac_level0_row10" class="row_heading level0 row10" >3</th>
#       <td id="T_3ccac_row10_col0" class="data row10 col0" >Lady Doves Fc</td>
#       <td id="T_3ccac_row10_col1" class="data row10 col1" >6.214286</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Count the number of unique matchdays for each club
unique_matchdays_per_club = df.groupby('club_for')['match_day'].nunique().reset_index()
unique_matchdays_per_club.columns = ['club_for', 'unique_matchdays']
style_table_for_docs(unique_matchdays_per_club.sort_values(by='unique_matchdays', ascending=False))
# Out:
# <style type="text/css">
# #T_4b4c0 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4b4c0 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4b4c0 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_4b4c0_row0_col0, #T_4b4c0_row0_col1, #T_4b4c0_row1_col0, #T_4b4c0_row1_col1, #T_4b4c0_row2_col0, #T_4b4c0_row2_col1, #T_4b4c0_row3_col0, #T_4b4c0_row3_col1, #T_4b4c0_row4_col0, #T_4b4c0_row4_col1, #T_4b4c0_row5_col0, #T_4b4c0_row5_col1, #T_4b4c0_row6_col0, #T_4b4c0_row6_col1, #T_4b4c0_row7_col0, #T_4b4c0_row7_col1, #T_4b4c0_row8_col0, #T_4b4c0_row8_col1, #T_4b4c0_row9_col0, #T_4b4c0_row9_col1, #T_4b4c0_row10_col0, #T_4b4c0_row10_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_4b4c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b4c0_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_4b4c0_level0_col1" class="col_heading level0 col1" >unique_matchdays</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b4c0_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_4b4c0_row0_col0" class="data row0 col0" >She Maroons Fc</td>
#       <td id="T_4b4c0_row0_col1" class="data row0 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4b4c0_row1_col0" class="data row1 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_4b4c0_row1_col1" class="data row1 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_4b4c0_row2_col0" class="data row2 col0" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_4b4c0_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_4b4c0_row3_col0" class="data row3 col0" >Rines Ss Wfc</td>
#       <td id="T_4b4c0_row3_col1" class="data row3 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_4b4c0_row4_col0" class="data row4 col0" >Amus College Wfc</td>
#       <td id="T_4b4c0_row4_col1" class="data row4 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_4b4c0_row5_col0" class="data row5 col0" >Wakiso Hill Wfc</td>
#       <td id="T_4b4c0_row5_col1" class="data row5 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_4b4c0_row6_col0" class="data row6 col0" >Lady Doves Fc</td>
#       <td id="T_4b4c0_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_4b4c0_row7_col0" class="data row7 col0" >Makerere University Wfc</td>
#       <td id="T_4b4c0_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_4b4c0_row8_col0" class="data row8 col0" >Kampala Queens Fc</td>
#       <td id="T_4b4c0_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_4b4c0_row9_col0" class="data row9 col0" >Olila Hs Wfc</td>
#       <td id="T_4b4c0_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4b4c0_level0_row10" class="row_heading level0 row10" >7</th>
#       <td id="T_4b4c0_row10_col0" class="data row10 col0" >She Corporates Fc</td>
#       <td id="T_4b4c0_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Sort data
data = unique_matchdays_per_club.sort_values(by='unique_matchdays', ascending=False)

# Define usage tiers and corresponding colors
def usage_tier_color(val):
    if val >= 18:
        return "#4596cf"  # dark blue for high engagement
    elif val >= 13:
        return '#ff7f0e'  # orange for medium
    else:
        return '#d62728'  # red for low

colors = data['unique_matchdays'].map(usage_tier_color).tolist()

# Create barplot
# plt.figure(figsize=(12,6))
sns.barplot(data=data, x='club_for',hue='club_for', y='unique_matchdays', palette=colors,legend=False)

# Benchmark line at maximum matchdays (22)
plt.axhline(22, color='gray', linestyle='--', linewidth=1)
plt.text(-0.5, 22.5, 'Maximum Matchdays (22)', color='gray', fontsize=9)

# Rotate and uppercase x labels
ax = plt.gca()
ax.set_xticklabels([lbl.get_text().upper() for lbl in ax.get_xticklabels()], rotation=90, fontsize=9)

# Title, subtitle, and axis labels
plt.xlabel('Club', fontsize=11)
plt.ylabel('Number of Matchdays Uploaded', fontsize=11)

# Gridlines for y-axis
ax.yaxis.grid(True, linestyle='--', alpha=0.5)
ax.set_axisbelow(True)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

# Annotate values inside bars
for i, value in enumerate(data['unique_matchdays']):
    ax.text(
        i, value - 1.8, str(value),
        ha='center', va='bottom',
        fontsize=8, color='black', fontweight='bold',
        bbox=dict(boxstyle="circle,pad=0.22", edgecolor='#667898', facecolor='white', linewidth=1)
    )
#remove yaxis ticklabels
ax.set_yticklabels([])
ax.set_yticks([])


plt.show()
# Out:
# C:\Users\Travail\AppData\Local\Temp\ipykernel_25892\1451582924.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([lbl.get_text().upper() for lbl in ax.get_xticklabels()], rotation=90, fontsize=9)

# %%
uploaded_matches = {
    "She Maroons FC": 20,
    "Kawempe Muslim LFC": 22,
    "Uganda Martyrs Lubaga WFC": 18,
    "Rines SS WFC": 22,
    "Amus College WFC": 19,
    "Wakiso Hill WFC": 18,
    "Lady Doves FC": 16,
    "Makerere University WFC": 22,
    "Kampala Queens FC": 17,
    "Olila HS WFC": 13,
    "She Corporates FC": 5,
    "FC Tooro Queens": 0,
    
}

uploaded_matches_df = pd.DataFrame(uploaded_matches.items(), columns=['club_for', 'uploaded_matches'])
uploaded_matches_df['club_for'] = uploaded_matches_df['club_for'].str.title()

uploaded_matches_df=uploaded_matches_df.merge(unique_matchdays_per_club, on='club_for', how='left').sort_values(by='unique_matchdays', ascending=False)
uploaded_matches_df = uploaded_matches_df.rename(columns={
    'uploaded_matches': 'Uploaded Matchdays',
    'unique_matchdays': 'Analysed Matchdays',
})

# %%
# Prepare DataFrame
uploaded_matches_df_copy = uploaded_matches_df.copy()
uploaded_matches_df_copy['Analysed']      = uploaded_matches_df_copy['Analysed Matchdays']
uploaded_matches_df_copy['Pending']       = uploaded_matches_df_copy['Uploaded Matchdays'] - uploaded_matches_df_copy['Analysed Matchdays']
uploaded_matches_df_copy['not_uploaded']  = 22 - uploaded_matches_df_copy['Uploaded Matchdays']
uploaded_matches_df_copy = uploaded_matches_df_copy.sort_values('Analysed Matchdays', ascending=False)

# Lighter color palette
colors = {
    'Analysed':      "#38759e",  # softer blue
    'Pending':       "#ee9d50",  # softer orange
    'not_uploaded':  "#f8373a"   # softer red
}

fig, ax = plt.subplots(figsize=(12,6))
x = np.arange(len(uploaded_matches_df_copy))

# Plot segments
ax.bar(x, uploaded_matches_df_copy['Analysed'],
       color=colors['Analysed'],
       label='Analysed')
ax.bar(x, uploaded_matches_df_copy['Pending'],
       bottom=uploaded_matches_df_copy['Analysed'],
       color=colors['Pending'],
       label='Uploaded – Not Analysed')
ax.bar(x, uploaded_matches_df_copy['not_uploaded'],
       bottom=uploaded_matches_df_copy['Analysed'] + uploaded_matches_df_copy['Pending'],
       color=colors['not_uploaded'],
       label='Not Uploaded')

# Benchmark line
ax.axhline(22, color='gray', linestyle='--', linewidth=1)
ax.text(-0.5, 22.5, 'MAXIMUM (30)', color='gray', fontsize=9)

# X labels
ax.set_xticks(x)
ax.set_xticklabels(uploaded_matches_df_copy['club_for'].str.upper(), rotation=90, fontsize=9)

# Clean Y axis
ax.set_yticks([])
ax.set_ylabel('')

# Titles
ax.set_xlabel('CLUB', fontsize=11)
ax.set_title('MATCHDAY COVERAGE PER CLUB', fontsize=14, fontweight='bold',pad='30')

# Gridlines
ax.yaxis.grid(True, linestyle='--', alpha=0.5)
ax.set_axisbelow(True)

# Remove spines
sns.despine(ax=ax, left=True, top=True, right=True)

# Annotation helper
def draw_circle_text(xpos, ypos, txt, color):
    ax.text(
        xpos, ypos, str(int(txt)),
        ha='center', va='center', color='black',
        fontsize=8, fontweight='bold',
        bbox=dict(boxstyle="circle,pad=0.3", facecolor='white', edgecolor='none')
    )

# Annotate segments
for idx, row in enumerate(uploaded_matches_df_copy.itertuples()):
    analysed = row.Analysed
    pending  = row.Pending
    notup    = row.not_uploaded

    # Analysed (always)
    if analysed > 0:
        draw_circle_text(idx, analysed / 2, analysed, colors['Analysed'])

    # Pending (always)
    if pending > 1:
        draw_circle_text(idx, analysed + pending / 2, pending, colors['Pending'])

    # not_uploaded (only if > 1)
    if notup > 1:
        ypos = analysed + pending + notup / 2
        draw_circle_text(idx, ypos, notup, colors['not_uploaded'])

# Legend outside
ax.legend(
    loc='upper left',
    bbox_to_anchor=(1.02, 1),
    borderaxespad=0,
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.patches as mpatches

# 1. Get sorted lists of clubs & matchdays
clubs = sorted(df['club_for'].unique())

# Sort matchdays in correct order: MD1, MD2, ..., MD22
matchday_order = [f'MD{i}' for i in range(1, 23)]
matchdays = [md for md in matchday_order if md in df['match_day'].unique()]

# 2. Build a binary grid (1 = analysed, 0 = missing)
grid_data = []
for md in matchdays:
    row = []
    for club in clubs:
        mask = (df['match_day'] == md) & (df['club_for'] == club)
        is_present = 1 if df.loc[mask, 'p_name'].nunique() > 0 else 0
        row.append(is_present)
    grid_data.append(row)

# 3. Convert to DataFrame
grid_df = pd.DataFrame(grid_data, index=matchdays, columns=clubs)

# 4. Define colors
color_map = {1: '#5cb85c', 0: '#d9534f'}  # green = uploaded, red = missing

# 5. Plot
fig, ax = plt.subplots(figsize=(len(clubs)*0.6 + 2, len(matchdays)*0.4 + 2))

for y, md in enumerate(matchdays):
    for x, club in enumerate(clubs):
        val = grid_df.loc[md, club]
        color = color_map[val]
        rect = plt.Rectangle((x, y), 1, 1, facecolor=color, edgecolor='white')
        ax.add_patch(rect)

# 6. Axis Labels
ax.set_xticks(np.arange(len(clubs)) + 0.5)
ax.set_xticklabels([c.upper() for c in clubs], rotation=90, fontsize=9)
ax.set_yticks(np.arange(len(matchdays)) + 0.5)
ax.set_yticklabels([i.upper() for i in matchdays], fontsize=9)

ax.set_xlim(0, len(clubs))
ax.set_ylim(0, len(matchdays))
ax.invert_yaxis()

ax.set_xlabel('Club', fontsize=11)
ax.set_ylabel('Match Day', fontsize=11)
ax.set_title('Matchdays Analysed per Club', fontsize=13, fontweight='bold')

# 7. Legend
handles = [
    mpatches.Patch(color=color_map[1], label='Analysed Matchday'),
    mpatches.Patch(color=color_map[0], label='Missing Matchday')
]
ax.legend(handles=handles, title='Color Map', loc='upper left', bbox_to_anchor=(1.02, 1), frameon=False)

plt.tight_layout()
plt.show()

# %%
# Calculate total player entries per matchday across all clubs
total_players_per_matchday = df.groupby('match_day')['p_name'].count().reset_index()
total_players_per_matchday.columns = ['match_day', 'total_player_entries']
# Ensure 'match_day' is a categorical variable with the correct order
matchday_order = [f'MD{i}' for i in range(1, 23)]
total_players_per_matchday['match_day'] = pd.Categorical(
    total_players_per_matchday['match_day'],
    categories=matchday_order,
    ordered=True
)
style_table_for_docs(total_players_per_matchday.sort_values(by='match_day'))
# Out:
# <style type="text/css">
# #T_f9f0b th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_f9f0b td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_f9f0b table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_f9f0b_row0_col0, #T_f9f0b_row0_col1, #T_f9f0b_row1_col0, #T_f9f0b_row1_col1, #T_f9f0b_row2_col0, #T_f9f0b_row2_col1, #T_f9f0b_row3_col0, #T_f9f0b_row3_col1, #T_f9f0b_row4_col0, #T_f9f0b_row4_col1, #T_f9f0b_row5_col0, #T_f9f0b_row5_col1, #T_f9f0b_row6_col0, #T_f9f0b_row6_col1, #T_f9f0b_row7_col0, #T_f9f0b_row7_col1, #T_f9f0b_row8_col0, #T_f9f0b_row8_col1, #T_f9f0b_row9_col0, #T_f9f0b_row9_col1, #T_f9f0b_row10_col0, #T_f9f0b_row10_col1, #T_f9f0b_row11_col0, #T_f9f0b_row11_col1, #T_f9f0b_row12_col0, #T_f9f0b_row12_col1, #T_f9f0b_row13_col0, #T_f9f0b_row13_col1, #T_f9f0b_row14_col0, #T_f9f0b_row14_col1, #T_f9f0b_row15_col0, #T_f9f0b_row15_col1, #T_f9f0b_row16_col0, #T_f9f0b_row16_col1, #T_f9f0b_row17_col0, #T_f9f0b_row17_col1, #T_f9f0b_row18_col0, #T_f9f0b_row18_col1, #T_f9f0b_row19_col0, #T_f9f0b_row19_col1, #T_f9f0b_row20_col0, #T_f9f0b_row20_col1, #T_f9f0b_row21_col0, #T_f9f0b_row21_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_f9f0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9f0b_level0_col0" class="col_heading level0 col0" >match_day</th>
#       <th id="T_f9f0b_level0_col1" class="col_heading level0 col1" >total_player_entries</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9f0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9f0b_row0_col0" class="data row0 col0" >MD1</td>
#       <td id="T_f9f0b_row0_col1" class="data row0 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_f9f0b_row1_col0" class="data row1 col0" >MD2</td>
#       <td id="T_f9f0b_row1_col1" class="data row1 col1" >79</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row2" class="row_heading level0 row2" >15</th>
#       <td id="T_f9f0b_row2_col0" class="data row2 col0" >MD3</td>
#       <td id="T_f9f0b_row2_col1" class="data row2 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_f9f0b_row3_col0" class="data row3 col0" >MD4</td>
#       <td id="T_f9f0b_row3_col1" class="data row3 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_f9f0b_row4_col0" class="data row4 col0" >MD5</td>
#       <td id="T_f9f0b_row4_col1" class="data row4 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row5" class="row_heading level0 row5" >18</th>
#       <td id="T_f9f0b_row5_col0" class="data row5 col0" >MD6</td>
#       <td id="T_f9f0b_row5_col1" class="data row5 col1" >94</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_f9f0b_row6_col0" class="data row6 col0" >MD7</td>
#       <td id="T_f9f0b_row6_col1" class="data row6 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row7" class="row_heading level0 row7" >20</th>
#       <td id="T_f9f0b_row7_col0" class="data row7 col0" >MD8</td>
#       <td id="T_f9f0b_row7_col1" class="data row7 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_f9f0b_row8_col0" class="data row8 col0" >MD9</td>
#       <td id="T_f9f0b_row8_col1" class="data row8 col1" >74</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_f9f0b_row9_col0" class="data row9 col0" >MD10</td>
#       <td id="T_f9f0b_row9_col1" class="data row9 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row10" class="row_heading level0 row10" >2</th>
#       <td id="T_f9f0b_row10_col0" class="data row10 col0" >MD11</td>
#       <td id="T_f9f0b_row10_col1" class="data row10 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row11" class="row_heading level0 row11" >3</th>
#       <td id="T_f9f0b_row11_col0" class="data row11 col0" >MD12</td>
#       <td id="T_f9f0b_row11_col1" class="data row11 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_f9f0b_row12_col0" class="data row12 col0" >MD13</td>
#       <td id="T_f9f0b_row12_col1" class="data row12 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row13" class="row_heading level0 row13" >5</th>
#       <td id="T_f9f0b_row13_col0" class="data row13 col0" >MD14</td>
#       <td id="T_f9f0b_row13_col1" class="data row13 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row14" class="row_heading level0 row14" >6</th>
#       <td id="T_f9f0b_row14_col0" class="data row14 col0" >MD15</td>
#       <td id="T_f9f0b_row14_col1" class="data row14 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row15" class="row_heading level0 row15" >7</th>
#       <td id="T_f9f0b_row15_col0" class="data row15 col0" >MD16</td>
#       <td id="T_f9f0b_row15_col1" class="data row15 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row16" class="row_heading level0 row16" >8</th>
#       <td id="T_f9f0b_row16_col0" class="data row16 col0" >MD17</td>
#       <td id="T_f9f0b_row16_col1" class="data row16 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row17" class="row_heading level0 row17" >9</th>
#       <td id="T_f9f0b_row17_col0" class="data row17 col0" >MD18</td>
#       <td id="T_f9f0b_row17_col1" class="data row17 col1" >55</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row18" class="row_heading level0 row18" >10</th>
#       <td id="T_f9f0b_row18_col0" class="data row18 col0" >MD19</td>
#       <td id="T_f9f0b_row18_col1" class="data row18 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row19" class="row_heading level0 row19" >12</th>
#       <td id="T_f9f0b_row19_col0" class="data row19 col0" >MD20</td>
#       <td id="T_f9f0b_row19_col1" class="data row19 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row20" class="row_heading level0 row20" >13</th>
#       <td id="T_f9f0b_row20_col0" class="data row20 col0" >MD21</td>
#       <td id="T_f9f0b_row20_col1" class="data row20 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_f9f0b_level0_row21" class="row_heading level0 row21" >14</th>
#       <td id="T_f9f0b_row21_col0" class="data row21 col0" >MD22</td>
#       <td id="T_f9f0b_row21_col1" class="data row21 col1" >44</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Count the number of unique clubs that submitted data per matchday
clubs_per_matchday = df.groupby('match_day')['club_for'].nunique().reset_index()
clubs_per_matchday.columns = ['match_day', 'num_clubs']
# Ensure 'match_day' is a categorical variable with the correct order
matchday_order = [f'MD{i}' for i in range(1, 31)]
clubs_per_matchday['match_day'] = pd.Categorical(
    clubs_per_matchday['match_day'],
    categories=matchday_order,
    ordered=True
)
style_table_for_docs(clubs_per_matchday.sort_values(by='match_day'))
# Out:
# <style type="text/css">
# #T_4f82d th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4f82d td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4f82d table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_4f82d_row0_col0, #T_4f82d_row0_col1, #T_4f82d_row1_col0, #T_4f82d_row1_col1, #T_4f82d_row2_col0, #T_4f82d_row2_col1, #T_4f82d_row3_col0, #T_4f82d_row3_col1, #T_4f82d_row4_col0, #T_4f82d_row4_col1, #T_4f82d_row5_col0, #T_4f82d_row5_col1, #T_4f82d_row6_col0, #T_4f82d_row6_col1, #T_4f82d_row7_col0, #T_4f82d_row7_col1, #T_4f82d_row8_col0, #T_4f82d_row8_col1, #T_4f82d_row9_col0, #T_4f82d_row9_col1, #T_4f82d_row10_col0, #T_4f82d_row10_col1, #T_4f82d_row11_col0, #T_4f82d_row11_col1, #T_4f82d_row12_col0, #T_4f82d_row12_col1, #T_4f82d_row13_col0, #T_4f82d_row13_col1, #T_4f82d_row14_col0, #T_4f82d_row14_col1, #T_4f82d_row15_col0, #T_4f82d_row15_col1, #T_4f82d_row16_col0, #T_4f82d_row16_col1, #T_4f82d_row17_col0, #T_4f82d_row17_col1, #T_4f82d_row18_col0, #T_4f82d_row18_col1, #T_4f82d_row19_col0, #T_4f82d_row19_col1, #T_4f82d_row20_col0, #T_4f82d_row20_col1, #T_4f82d_row21_col0, #T_4f82d_row21_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_4f82d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f82d_level0_col0" class="col_heading level0 col0" >match_day</th>
#       <th id="T_4f82d_level0_col1" class="col_heading level0 col1" >num_clubs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f82d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f82d_row0_col0" class="data row0 col0" >MD1</td>
#       <td id="T_4f82d_row0_col1" class="data row0 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_4f82d_row1_col0" class="data row1 col0" >MD2</td>
#       <td id="T_4f82d_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row2" class="row_heading level0 row2" >15</th>
#       <td id="T_4f82d_row2_col0" class="data row2 col0" >MD3</td>
#       <td id="T_4f82d_row2_col1" class="data row2 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_4f82d_row3_col0" class="data row3 col0" >MD4</td>
#       <td id="T_4f82d_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row4" class="row_heading level0 row4" >17</th>
#       <td id="T_4f82d_row4_col0" class="data row4 col0" >MD5</td>
#       <td id="T_4f82d_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row5" class="row_heading level0 row5" >18</th>
#       <td id="T_4f82d_row5_col0" class="data row5 col0" >MD6</td>
#       <td id="T_4f82d_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_4f82d_row6_col0" class="data row6 col0" >MD7</td>
#       <td id="T_4f82d_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row7" class="row_heading level0 row7" >20</th>
#       <td id="T_4f82d_row7_col0" class="data row7 col0" >MD8</td>
#       <td id="T_4f82d_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_4f82d_row8_col0" class="data row8 col0" >MD9</td>
#       <td id="T_4f82d_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_4f82d_row9_col0" class="data row9 col0" >MD10</td>
#       <td id="T_4f82d_row9_col1" class="data row9 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row10" class="row_heading level0 row10" >2</th>
#       <td id="T_4f82d_row10_col0" class="data row10 col0" >MD11</td>
#       <td id="T_4f82d_row10_col1" class="data row10 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row11" class="row_heading level0 row11" >3</th>
#       <td id="T_4f82d_row11_col0" class="data row11 col0" >MD12</td>
#       <td id="T_4f82d_row11_col1" class="data row11 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_4f82d_row12_col0" class="data row12 col0" >MD13</td>
#       <td id="T_4f82d_row12_col1" class="data row12 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row13" class="row_heading level0 row13" >5</th>
#       <td id="T_4f82d_row13_col0" class="data row13 col0" >MD14</td>
#       <td id="T_4f82d_row13_col1" class="data row13 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row14" class="row_heading level0 row14" >6</th>
#       <td id="T_4f82d_row14_col0" class="data row14 col0" >MD15</td>
#       <td id="T_4f82d_row14_col1" class="data row14 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row15" class="row_heading level0 row15" >7</th>
#       <td id="T_4f82d_row15_col0" class="data row15 col0" >MD16</td>
#       <td id="T_4f82d_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row16" class="row_heading level0 row16" >8</th>
#       <td id="T_4f82d_row16_col0" class="data row16 col0" >MD17</td>
#       <td id="T_4f82d_row16_col1" class="data row16 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row17" class="row_heading level0 row17" >9</th>
#       <td id="T_4f82d_row17_col0" class="data row17 col0" >MD18</td>
#       <td id="T_4f82d_row17_col1" class="data row17 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row18" class="row_heading level0 row18" >10</th>
#       <td id="T_4f82d_row18_col0" class="data row18 col0" >MD19</td>
#       <td id="T_4f82d_row18_col1" class="data row18 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row19" class="row_heading level0 row19" >12</th>
#       <td id="T_4f82d_row19_col0" class="data row19 col0" >MD20</td>
#       <td id="T_4f82d_row19_col1" class="data row19 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row20" class="row_heading level0 row20" >13</th>
#       <td id="T_4f82d_row20_col0" class="data row20 col0" >MD21</td>
#       <td id="T_4f82d_row20_col1" class="data row20 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4f82d_level0_row21" class="row_heading level0 row21" >14</th>
#       <td id="T_4f82d_row21_col0" class="data row21 col0" >MD22</td>
#       <td id="T_4f82d_row21_col1" class="data row21 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
def plot_line_with_values(data, x_col, y_col, title=None, x_label=None,y_label=None, figsize=(10, 6)):
    # Create figure and axis
    plt.figure(figsize=figsize)
    
    # Plot the line
    sns.lineplot(data=data, x=x_col, y=y_col, marker='o', color='orange', linewidth=2)

    
    # Get current axis
    ax = plt.gca()
    
    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Set spine and tick colors to light gray
    gray_color = '#808080'
    ax.spines['bottom'].set_color(gray_color)
    ax.spines['left'].set_color(gray_color)
    

    if x_col == 'match_day':
        # Ensure match_day is ordered as per matchday_order
        data[x_col] = pd.Categorical(data[x_col], categories=matchday_order, ordered=True)
        data_sorted = data.sort_values(by=x_col)
        xticklabels = [str(Wmd).replace('Wmd', 'Wmd ') for Wmd in data_sorted[x_col]]
        ax.set_xticks(range(len(data_sorted[x_col])))
        ax.set_xticklabels(xticklabels, rotation=90)
        # Re-plot with sorted data to ensure correct order
        
        sns.lineplot(data=data_sorted, x=x_col, y=y_col, marker='o', color='orange', linewidth=2)
        
    # Add value labels above each point
    for i, (x, y) in enumerate(zip(data[x_col], data[y_col])):
        ax.annotate(
            f'{y}', 
            (x, y),
            textcoords="offset points", 
            xytext=(0, 10), 
            ha='center',
            fontsize=8,
            bbox=dict(boxstyle="circle,pad=0.35", edgecolor='#FE912A', facecolor='white', linewidth=1)
        )
    
    # Set title
    if title is None:
        title = f'{y_col} vs {x_col}'
    plt.title(title)

    # #start the y-axis at 0
    # ax.set_ylim(bottom=2,top=14)  # Adjust the top limit as needed
    

    # Set labels
    if x_label is None:
        x_label = x_col.replace('_', ' ').title()
    plt.xlabel(x_label)
    if y_label is None:
        y_label = y_col.replace('_', ' ').title()
    plt.ylabel(y_label)
    plt.grid(axis='y', linestyle='--', linewidth=0.5, color='#E0DCDD', alpha=0.7)
    # Adjust layout
    plt.tight_layout()
    
    return ax

# %%
plot_line_with_values(clubs_per_matchday, 'match_day', 'num_clubs', title='Number of Clubs that Uploaded Data Per Matchday',x_label='Match Day', y_label='Number of Clubs');

# %%
plot_line_with_values(total_players_per_matchday, 'match_day', 'total_player_entries', title='Total Player Entries Per Matchday', x_label='Match Day', y_label='Total Player Entries');

# %%
# Count number and percentage of entries based on 'location'
location_counts = df['location'].value_counts().reset_index()
location_counts.columns = ['location', 'count']
location_counts['percentage'] = (location_counts['count'] / len(df)) * 100

style_table_for_docs(location_counts)
# Out:
# <style type="text/css">
# #T_8fdf9 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_8fdf9 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_8fdf9 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_8fdf9_row0_col0, #T_8fdf9_row0_col1, #T_8fdf9_row0_col2, #T_8fdf9_row1_col0, #T_8fdf9_row1_col1, #T_8fdf9_row1_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_8fdf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fdf9_level0_col0" class="col_heading level0 col0" >location</th>
#       <th id="T_8fdf9_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_8fdf9_level0_col2" class="col_heading level0 col2" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fdf9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fdf9_row0_col0" class="data row0 col0" >Home</td>
#       <td id="T_8fdf9_row0_col1" class="data row0 col1" >875</td>
#       <td id="T_8fdf9_row0_col2" class="data row0 col2" >52.774427</td>
#     </tr>
#     <tr>
#       <th id="T_8fdf9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8fdf9_row1_col0" class="data row1 col0" >Away</td>
#       <td id="T_8fdf9_row1_col1" class="data row1 col1" >783</td>
#       <td id="T_8fdf9_row1_col2" class="data row1 col2" >47.225573</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Count number and percentage of entries based on 'result'
location_counts = df['result'].value_counts().reset_index()
location_counts.columns = ['result', 'count']
location_counts['percentage'] = (location_counts['count'] / len(df)) * 100

style_table_for_docs(location_counts)
# Out:
# <style type="text/css">
# #T_241c6 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_241c6 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_241c6 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_241c6_row0_col0, #T_241c6_row0_col1, #T_241c6_row0_col2, #T_241c6_row1_col0, #T_241c6_row1_col1, #T_241c6_row1_col2, #T_241c6_row2_col0, #T_241c6_row2_col1, #T_241c6_row2_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_241c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_241c6_level0_col0" class="col_heading level0 col0" >result</th>
#       <th id="T_241c6_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_241c6_level0_col2" class="col_heading level0 col2" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_241c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_241c6_row0_col0" class="data row0 col0" >Win</td>
#       <td id="T_241c6_row0_col1" class="data row0 col1" >612</td>
#       <td id="T_241c6_row0_col2" class="data row0 col2" >36.911942</td>
#     </tr>
#     <tr>
#       <th id="T_241c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_241c6_row1_col0" class="data row1 col0" >Draw</td>
#       <td id="T_241c6_row1_col1" class="data row1 col1" >580</td>
#       <td id="T_241c6_row1_col2" class="data row1 col2" >34.981906</td>
#     </tr>
#     <tr>
#       <th id="T_241c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_241c6_row2_col0" class="data row2 col0" >Loss</td>
#       <td id="T_241c6_row2_col1" class="data row2 col1" >466</td>
#       <td id="T_241c6_row2_col2" class="data row2 col2" >28.106152</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate Win-Draw-Loss counts for each club using unique match days
matchday_results = df.groupby(['club_for', 'match_day'])['result'].first().reset_index()
wld_counts = matchday_results.groupby(['club_for', 'result']).size().unstack(fill_value=0)
wld_counts = wld_counts[['Win', 'Draw', 'Loss']]  # Ensure order if all present

style_table_for_docs(wld_counts.sort_values(by='Win', ascending=False))
# Out:
# <style type="text/css">
# #T_3b4b3 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3b4b3 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3b4b3 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3b4b3_row0_col0, #T_3b4b3_row0_col1, #T_3b4b3_row0_col2, #T_3b4b3_row1_col0, #T_3b4b3_row1_col1, #T_3b4b3_row1_col2, #T_3b4b3_row2_col0, #T_3b4b3_row2_col1, #T_3b4b3_row2_col2, #T_3b4b3_row3_col0, #T_3b4b3_row3_col1, #T_3b4b3_row3_col2, #T_3b4b3_row4_col0, #T_3b4b3_row4_col1, #T_3b4b3_row4_col2, #T_3b4b3_row5_col0, #T_3b4b3_row5_col1, #T_3b4b3_row5_col2, #T_3b4b3_row6_col0, #T_3b4b3_row6_col1, #T_3b4b3_row6_col2, #T_3b4b3_row7_col0, #T_3b4b3_row7_col1, #T_3b4b3_row7_col2, #T_3b4b3_row8_col0, #T_3b4b3_row8_col1, #T_3b4b3_row8_col2, #T_3b4b3_row9_col0, #T_3b4b3_row9_col1, #T_3b4b3_row9_col2, #T_3b4b3_row10_col0, #T_3b4b3_row10_col1, #T_3b4b3_row10_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_3b4b3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th id="T_3b4b3_level0_col0" class="col_heading level0 col0" >Win</th>
#       <th id="T_3b4b3_level0_col1" class="col_heading level0 col1" >Draw</th>
#       <th id="T_3b4b3_level0_col2" class="col_heading level0 col2" >Loss</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >club_for</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b4b3_level0_row0" class="row_heading level0 row0" >Kawempe Muslim Lfc</th>
#       <td id="T_3b4b3_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_3b4b3_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_3b4b3_row0_col2" class="data row0 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row1" class="row_heading level0 row1" >Amus College Wfc</th>
#       <td id="T_3b4b3_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_3b4b3_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_3b4b3_row1_col2" class="data row1 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row2" class="row_heading level0 row2" >Kampala Queens Fc</th>
#       <td id="T_3b4b3_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_3b4b3_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_3b4b3_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row3" class="row_heading level0 row3" >Lady Doves Fc</th>
#       <td id="T_3b4b3_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_3b4b3_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_3b4b3_row3_col2" class="data row3 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row4" class="row_heading level0 row4" >She Maroons Fc</th>
#       <td id="T_3b4b3_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_3b4b3_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_3b4b3_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row5" class="row_heading level0 row5" >Rines Ss Wfc</th>
#       <td id="T_3b4b3_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_3b4b3_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_3b4b3_row5_col2" class="data row5 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row6" class="row_heading level0 row6" >Makerere University Wfc</th>
#       <td id="T_3b4b3_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_3b4b3_row6_col1" class="data row6 col1" >6</td>
#       <td id="T_3b4b3_row6_col2" class="data row6 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row7" class="row_heading level0 row7" >Uganda Martyrs Lubaga Wfc</th>
#       <td id="T_3b4b3_row7_col0" class="data row7 col0" >5</td>
#       <td id="T_3b4b3_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_3b4b3_row7_col2" class="data row7 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row8" class="row_heading level0 row8" >Olila Hs Wfc</th>
#       <td id="T_3b4b3_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_3b4b3_row8_col1" class="data row8 col1" >5</td>
#       <td id="T_3b4b3_row8_col2" class="data row8 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row9" class="row_heading level0 row9" >She Corporates Fc</th>
#       <td id="T_3b4b3_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_3b4b3_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_3b4b3_row9_col2" class="data row9 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3b4b3_level0_row10" class="row_heading level0 row10" >Wakiso Hill Wfc</th>
#       <td id="T_3b4b3_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_3b4b3_row10_col1" class="data row10 col1" >5</td>
#       <td id="T_3b4b3_row10_col2" class="data row10 col2" >11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Max Metrics

# %%
speed_table = df[['top_speed_kmh','distance_per_min_mmin','max_acceleration_mss','max_deceleration_mss']].agg(['max', 'mean', 'std']).T
style_table_for_docs(speed_table)
# Out:
# <style type="text/css">
# #T_5abd4 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_5abd4 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_5abd4 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_5abd4_row0_col0, #T_5abd4_row0_col1, #T_5abd4_row0_col2, #T_5abd4_row1_col0, #T_5abd4_row1_col1, #T_5abd4_row1_col2, #T_5abd4_row2_col0, #T_5abd4_row2_col1, #T_5abd4_row2_col2, #T_5abd4_row3_col0, #T_5abd4_row3_col1, #T_5abd4_row3_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_5abd4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5abd4_level0_col0" class="col_heading level0 col0" >max</th>
#       <th id="T_5abd4_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_5abd4_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5abd4_level0_row0" class="row_heading level0 row0" >top_speed_kmh</th>
#       <td id="T_5abd4_row0_col0" class="data row0 col0" >32.400300</td>
#       <td id="T_5abd4_row0_col1" class="data row0 col1" >25.624851</td>
#       <td id="T_5abd4_row0_col2" class="data row0 col2" >2.013774</td>
#     </tr>
#     <tr>
#       <th id="T_5abd4_level0_row1" class="row_heading level0 row1" >distance_per_min_mmin</th>
#       <td id="T_5abd4_row1_col0" class="data row1 col0" >116.958686</td>
#       <td id="T_5abd4_row1_col1" class="data row1 col1" >74.848353</td>
#       <td id="T_5abd4_row1_col2" class="data row1 col2" >19.835923</td>
#     </tr>
#     <tr>
#       <th id="T_5abd4_level0_row2" class="row_heading level0 row2" >max_acceleration_mss</th>
#       <td id="T_5abd4_row2_col0" class="data row2 col0" >10.000000</td>
#       <td id="T_5abd4_row2_col1" class="data row2 col1" >5.226480</td>
#       <td id="T_5abd4_row2_col2" class="data row2 col2" >0.572805</td>
#     </tr>
#     <tr>
#       <th id="T_5abd4_level0_row3" class="row_heading level0 row3" >max_deceleration_mss</th>
#       <td id="T_5abd4_row3_col0" class="data row3 col0" >10.000000</td>
#       <td id="T_5abd4_row3_col1" class="data row3 col1" >6.437293</td>
#       <td id="T_5abd4_row3_col2" class="data row3 col2" >0.952649</td>
#     </tr>
#   </tbody>
# </table>

# %%
distance_speed_zones = ['distance_in_speed_zone_1_km', 'distance_in_speed_zone_2_km', 'distance_in_speed_zone_3_km','distance_in_speed_zone_4_km','distance_in_speed_zone_5_km']
for i in distance_speed_zones:
    df[i] = df[i] * 1000  # Convert from km to m

speed_zone_dist= df[distance_speed_zones].agg(['sum','max', 'mean', 'std']).T.round(2)
style_table_for_docs(speed_zone_dist)
# Out:
# <style type="text/css">
# #T_3a918 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3a918 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3a918 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3a918_row0_col0, #T_3a918_row0_col1, #T_3a918_row0_col2, #T_3a918_row0_col3, #T_3a918_row1_col0, #T_3a918_row1_col1, #T_3a918_row1_col2, #T_3a918_row1_col3, #T_3a918_row2_col0, #T_3a918_row2_col1, #T_3a918_row2_col2, #T_3a918_row2_col3, #T_3a918_row3_col0, #T_3a918_row3_col1, #T_3a918_row3_col2, #T_3a918_row3_col3, #T_3a918_row4_col0, #T_3a918_row4_col1, #T_3a918_row4_col2, #T_3a918_row4_col3 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_3a918">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a918_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_3a918_level0_col1" class="col_heading level0 col1" >max</th>
#       <th id="T_3a918_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_3a918_level0_col3" class="col_heading level0 col3" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a918_level0_row0" class="row_heading level0 row0" >distance_in_speed_zone_1_km</th>
#       <td id="T_3a918_row0_col0" class="data row0 col0" >1602464.400000</td>
#       <td id="T_3a918_row0_col1" class="data row0 col1" >1872.200000</td>
#       <td id="T_3a918_row0_col2" class="data row0 col2" >966.500000</td>
#       <td id="T_3a918_row0_col3" class="data row0 col3" >270.340000</td>
#     </tr>
#     <tr>
#       <th id="T_3a918_level0_row1" class="row_heading level0 row1" >distance_in_speed_zone_2_km</th>
#       <td id="T_3a918_row1_col0" class="data row1 col0" >6626349.800000</td>
#       <td id="T_3a918_row1_col1" class="data row1 col1" >6062.300000</td>
#       <td id="T_3a918_row1_col2" class="data row1 col2" >3996.590000</td>
#       <td id="T_3a918_row1_col3" class="data row1 col3" >1085.770000</td>
#     </tr>
#     <tr>
#       <th id="T_3a918_level0_row2" class="row_heading level0 row2" >distance_in_speed_zone_3_km</th>
#       <td id="T_3a918_row2_col0" class="data row2 col0" >3318721.300000</td>
#       <td id="T_3a918_row2_col1" class="data row2 col1" >4494.400000</td>
#       <td id="T_3a918_row2_col2" class="data row2 col2" >2001.640000</td>
#       <td id="T_3a918_row2_col3" class="data row2 col3" >734.570000</td>
#     </tr>
#     <tr>
#       <th id="T_3a918_level0_row3" class="row_heading level0 row3" >distance_in_speed_zone_4_km</th>
#       <td id="T_3a918_row3_col0" class="data row3 col0" >674312.700000</td>
#       <td id="T_3a918_row3_col1" class="data row3 col1" >1225.000000</td>
#       <td id="T_3a918_row3_col2" class="data row3 col2" >406.700000</td>
#       <td id="T_3a918_row3_col3" class="data row3 col3" >200.620000</td>
#     </tr>
#     <tr>
#       <th id="T_3a918_level0_row4" class="row_heading level0 row4" >distance_in_speed_zone_5_km</th>
#       <td id="T_3a918_row4_col0" class="data row4 col0" >36563.700000</td>
#       <td id="T_3a918_row4_col1" class="data row4 col1" >295.300000</td>
#       <td id="T_3a918_row4_col2" class="data row4 col2" >22.050000</td>
#       <td id="T_3a918_row4_col3" class="data row4 col3" >32.900000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Club Comparison

# %%
club_metrics_mean = (
    df.groupby(['club_for', 'match_day'],observed=False)[volume_metrics+intensity_metrics].mean()
    .groupby('club_for').mean()
    .rename(columns=lambda x: f'avg_{x}')
    .sort_values(by='avg_distance_km', ascending=False)
    .reset_index()
)
style_table_for_docs(club_metrics_mean.round(2))
# Out:
# <style type="text/css">
# #T_250dd th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_250dd td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_250dd table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_250dd_row0_col0, #T_250dd_row0_col1, #T_250dd_row0_col2, #T_250dd_row0_col3, #T_250dd_row0_col4, #T_250dd_row0_col5, #T_250dd_row0_col6, #T_250dd_row0_col7, #T_250dd_row0_col8, #T_250dd_row0_col9, #T_250dd_row0_col10, #T_250dd_row0_col11, #T_250dd_row0_col12, #T_250dd_row0_col13, #T_250dd_row0_col14, #T_250dd_row0_col15, #T_250dd_row0_col16, #T_250dd_row1_col0, #T_250dd_row1_col1, #T_250dd_row1_col2, #T_250dd_row1_col3, #T_250dd_row1_col4, #T_250dd_row1_col5, #T_250dd_row1_col6, #T_250dd_row1_col7, #T_250dd_row1_col8, #T_250dd_row1_col9, #T_250dd_row1_col10, #T_250dd_row1_col11, #T_250dd_row1_col12, #T_250dd_row1_col13, #T_250dd_row1_col14, #T_250dd_row1_col15, #T_250dd_row1_col16, #T_250dd_row2_col0, #T_250dd_row2_col1, #T_250dd_row2_col2, #T_250dd_row2_col3, #T_250dd_row2_col4, #T_250dd_row2_col5, #T_250dd_row2_col6, #T_250dd_row2_col7, #T_250dd_row2_col8, #T_250dd_row2_col9, #T_250dd_row2_col10, #T_250dd_row2_col11, #T_250dd_row2_col12, #T_250dd_row2_col13, #T_250dd_row2_col14, #T_250dd_row2_col15, #T_250dd_row2_col16, #T_250dd_row3_col0, #T_250dd_row3_col1, #T_250dd_row3_col2, #T_250dd_row3_col3, #T_250dd_row3_col4, #T_250dd_row3_col5, #T_250dd_row3_col6, #T_250dd_row3_col7, #T_250dd_row3_col8, #T_250dd_row3_col9, #T_250dd_row3_col10, #T_250dd_row3_col11, #T_250dd_row3_col12, #T_250dd_row3_col13, #T_250dd_row3_col14, #T_250dd_row3_col15, #T_250dd_row3_col16, #T_250dd_row4_col0, #T_250dd_row4_col1, #T_250dd_row4_col2, #T_250dd_row4_col3, #T_250dd_row4_col4, #T_250dd_row4_col5, #T_250dd_row4_col6, #T_250dd_row4_col7, #T_250dd_row4_col8, #T_250dd_row4_col9, #T_250dd_row4_col10, #T_250dd_row4_col11, #T_250dd_row4_col12, #T_250dd_row4_col13, #T_250dd_row4_col14, #T_250dd_row4_col15, #T_250dd_row4_col16, #T_250dd_row5_col0, #T_250dd_row5_col1, #T_250dd_row5_col2, #T_250dd_row5_col3, #T_250dd_row5_col4, #T_250dd_row5_col5, #T_250dd_row5_col6, #T_250dd_row5_col7, #T_250dd_row5_col8, #T_250dd_row5_col9, #T_250dd_row5_col10, #T_250dd_row5_col11, #T_250dd_row5_col12, #T_250dd_row5_col13, #T_250dd_row5_col14, #T_250dd_row5_col15, #T_250dd_row5_col16, #T_250dd_row6_col0, #T_250dd_row6_col1, #T_250dd_row6_col2, #T_250dd_row6_col3, #T_250dd_row6_col4, #T_250dd_row6_col5, #T_250dd_row6_col6, #T_250dd_row6_col7, #T_250dd_row6_col8, #T_250dd_row6_col9, #T_250dd_row6_col10, #T_250dd_row6_col11, #T_250dd_row6_col12, #T_250dd_row6_col13, #T_250dd_row6_col14, #T_250dd_row6_col15, #T_250dd_row6_col16, #T_250dd_row7_col0, #T_250dd_row7_col1, #T_250dd_row7_col2, #T_250dd_row7_col3, #T_250dd_row7_col4, #T_250dd_row7_col5, #T_250dd_row7_col6, #T_250dd_row7_col7, #T_250dd_row7_col8, #T_250dd_row7_col9, #T_250dd_row7_col10, #T_250dd_row7_col11, #T_250dd_row7_col12, #T_250dd_row7_col13, #T_250dd_row7_col14, #T_250dd_row7_col15, #T_250dd_row7_col16, #T_250dd_row8_col0, #T_250dd_row8_col1, #T_250dd_row8_col2, #T_250dd_row8_col3, #T_250dd_row8_col4, #T_250dd_row8_col5, #T_250dd_row8_col6, #T_250dd_row8_col7, #T_250dd_row8_col8, #T_250dd_row8_col9, #T_250dd_row8_col10, #T_250dd_row8_col11, #T_250dd_row8_col12, #T_250dd_row8_col13, #T_250dd_row8_col14, #T_250dd_row8_col15, #T_250dd_row8_col16, #T_250dd_row9_col0, #T_250dd_row9_col1, #T_250dd_row9_col2, #T_250dd_row9_col3, #T_250dd_row9_col4, #T_250dd_row9_col5, #T_250dd_row9_col6, #T_250dd_row9_col7, #T_250dd_row9_col8, #T_250dd_row9_col9, #T_250dd_row9_col10, #T_250dd_row9_col11, #T_250dd_row9_col12, #T_250dd_row9_col13, #T_250dd_row9_col14, #T_250dd_row9_col15, #T_250dd_row9_col16, #T_250dd_row10_col0, #T_250dd_row10_col1, #T_250dd_row10_col2, #T_250dd_row10_col3, #T_250dd_row10_col4, #T_250dd_row10_col5, #T_250dd_row10_col6, #T_250dd_row10_col7, #T_250dd_row10_col8, #T_250dd_row10_col9, #T_250dd_row10_col10, #T_250dd_row10_col11, #T_250dd_row10_col12, #T_250dd_row10_col13, #T_250dd_row10_col14, #T_250dd_row10_col15, #T_250dd_row10_col16 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_250dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_250dd_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_250dd_level0_col1" class="col_heading level0 col1" >avg_distance_km</th>
#       <th id="T_250dd_level0_col2" class="col_heading level0 col2" >avg_sprint_distance_m</th>
#       <th id="T_250dd_level0_col3" class="col_heading level0 col3" >avg_power_plays</th>
#       <th id="T_250dd_level0_col4" class="col_heading level0 col4" >avg_energy_kcal</th>
#       <th id="T_250dd_level0_col5" class="col_heading level0 col5" >avg_impacts</th>
#       <th id="T_250dd_level0_col6" class="col_heading level0 col6" >avg_total_accelerations</th>
#       <th id="T_250dd_level0_col7" class="col_heading level0 col7" >avg_total_decelerations</th>
#       <th id="T_250dd_level0_col8" class="col_heading level0 col8" >avg_player_load</th>
#       <th id="T_250dd_level0_col9" class="col_heading level0 col9" >avg_top_speed_kmh</th>
#       <th id="T_250dd_level0_col10" class="col_heading level0 col10" >avg_distance_per_min_mmin</th>
#       <th id="T_250dd_level0_col11" class="col_heading level0 col11" >avg_power_score_wkg</th>
#       <th id="T_250dd_level0_col12" class="col_heading level0 col12" >avg_work_ratio</th>
#       <th id="T_250dd_level0_col13" class="col_heading level0 col13" >avg_max_acceleration_mss</th>
#       <th id="T_250dd_level0_col14" class="col_heading level0 col14" >avg_max_deceleration_mss</th>
#       <th id="T_250dd_level0_col15" class="col_heading level0 col15" >avg_acc_counts_per_min</th>
#       <th id="T_250dd_level0_col16" class="col_heading level0 col16" >avg_dec_counts_per_min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_250dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_250dd_row0_col0" class="data row0 col0" >Olila Hs Wfc</td>
#       <td id="T_250dd_row0_col1" class="data row0 col1" >8.470000</td>
#       <td id="T_250dd_row0_col2" class="data row0 col2" >496.960000</td>
#       <td id="T_250dd_row0_col3" class="data row0 col3" >42.320000</td>
#       <td id="T_250dd_row0_col4" class="data row0 col4" >825.220000</td>
#       <td id="T_250dd_row0_col5" class="data row0 col5" >3.820000</td>
#       <td id="T_250dd_row0_col6" class="data row0 col6" >386.250000</td>
#       <td id="T_250dd_row0_col7" class="data row0 col7" >374.510000</td>
#       <td id="T_250dd_row0_col8" class="data row0 col8" >384.610000</td>
#       <td id="T_250dd_row0_col9" class="data row0 col9" >25.980000</td>
#       <td id="T_250dd_row0_col10" class="data row0 col10" >86.030000</td>
#       <td id="T_250dd_row0_col11" class="data row0 col11" >13.300000</td>
#       <td id="T_250dd_row0_col12" class="data row0 col12" >69.730000</td>
#       <td id="T_250dd_row0_col13" class="data row0 col13" >5.190000</td>
#       <td id="T_250dd_row0_col14" class="data row0 col14" >6.360000</td>
#       <td id="T_250dd_row0_col15" class="data row0 col15" >3.920000</td>
#       <td id="T_250dd_row0_col16" class="data row0 col16" >3.800000</td>
#     </tr>
#     <tr>
#       <th id="T_250dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_250dd_row1_col0" class="data row1 col0" >Lady Doves Fc</td>
#       <td id="T_250dd_row1_col1" class="data row1 col1" >8.030000</td>
#       <td id="T_250dd_row1_col2" class="data row1 col2" >504.100000</td>
#       <td id="T_250dd_row1_col3" class="data row1 col3" >42.240000</td>
#       <td id="T_250dd_row1_col4" class="data row1 col4" >737.090000</td>
#       <td id="T_250dd_row1_col5" class="data row1 col5" >6.430000</td>
#       <td id="T_250dd_row1_col6" class="data row1 col6" >367.140000</td>
#       <td id="T_250dd_row1_col7" class="data row1 col7" >359.150000</td>
#       <td id="T_250dd_row1_col8" class="data row1 col8" >393.470000</td>
#       <td id="T_250dd_ro

# %%
team_avg_dist_per_match = (
    df
    .groupby(['club_for', 'match_day'], observed=False)['distance_km']
    .sum()  # Total team distance on a match day
    .groupby('club_for')
    .mean()  # Average total team distance per match across all match days
    .reset_index(name='avg_team_distance_per_match_km')
    .sort_values(by='avg_team_distance_per_match_km', ascending=False)
)
style_table_for_docs(team_avg_dist_per_match)
# Out:
# <style type="text/css">
# #T_61945 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_61945 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_61945 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_61945_row0_col0, #T_61945_row0_col1, #T_61945_row1_col0, #T_61945_row1_col1, #T_61945_row2_col0, #T_61945_row2_col1, #T_61945_row3_col0, #T_61945_row3_col1, #T_61945_row4_col0, #T_61945_row4_col1, #T_61945_row5_col0, #T_61945_row5_col1, #T_61945_row6_col0, #T_61945_row6_col1, #T_61945_row7_col0, #T_61945_row7_col1, #T_61945_row8_col0, #T_61945_row8_col1, #T_61945_row9_col0, #T_61945_row9_col1, #T_61945_row10_col0, #T_61945_row10_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_61945">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61945_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_61945_level0_col1" class="col_heading level0 col1" >avg_team_distance_per_match_km</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61945_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61945_row0_col0" class="data row0 col0" >Amus College Wfc</td>
#       <td id="T_61945_row0_col1" class="data row0 col1" >89.607006</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_61945_row1_col0" class="data row1 col0" >Makerere University Wfc</td>
#       <td id="T_61945_row1_col1" class="data row1 col1" >83.084564</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_61945_row2_col0" class="data row2 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_61945_row2_col1" class="data row2 col1" >81.915958</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_61945_row3_col0" class="data row3 col0" >She Maroons Fc</td>
#       <td id="T_61945_row3_col1" class="data row3 col1" >80.710645</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_61945_row4_col0" class="data row4 col0" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_61945_row4_col1" class="data row4 col1" >80.133294</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_61945_row5_col0" class="data row5 col0" >Wakiso Hill Wfc</td>
#       <td id="T_61945_row5_col1" class="data row5 col1" >78.944800</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_61945_row6_col0" class="data row6 col0" >Rines Ss Wfc</td>
#       <td id="T_61945_row6_col1" class="data row6 col1" >75.913506</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_61945_row7_col0" class="data row7 col0" >Kampala Queens Fc</td>
#       <td id="T_61945_row7_col1" class="data row7 col1" >69.374685</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_61945_row8_col0" class="data row8 col0" >Olila Hs Wfc</td>
#       <td id="T_61945_row8_col1" class="data row8 col1" >64.800630</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_61945_row9_col0" class="data row9 col0" >She Corporates Fc</td>
#       <td id="T_61945_row9_col1" class="data row9 col1" >51.422333</td>
#     </tr>
#     <tr>
#       <th id="T_61945_level0_row10" class="row_heading level0 row10" >3</th>
#       <td id="T_61945_row10_col0" class="data row10 col0" >Lady Doves Fc</td>
#       <td id="T_61945_row10_col1" class="data row10 col1" >50.078900</td>
#     </tr>
#   </tbody>
# </table>

# %%
club_intensity_max = (
    df.groupby('club_for')[['top_speed_kmh', 'distance_per_min_mmin']]
    .max()
    .rename(columns=lambda x: f'max_{x}')
    .sort_values(by='max_top_speed_kmh', ascending=False)
    .reset_index()
)
style_table_for_docs(club_intensity_max.round(2))
# Out:
# <style type="text/css">
# #T_a7531 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a7531 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a7531 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_a7531_row0_col0, #T_a7531_row0_col1, #T_a7531_row0_col2, #T_a7531_row1_col0, #T_a7531_row1_col1, #T_a7531_row1_col2, #T_a7531_row2_col0, #T_a7531_row2_col1, #T_a7531_row2_col2, #T_a7531_row3_col0, #T_a7531_row3_col1, #T_a7531_row3_col2, #T_a7531_row4_col0, #T_a7531_row4_col1, #T_a7531_row4_col2, #T_a7531_row5_col0, #T_a7531_row5_col1, #T_a7531_row5_col2, #T_a7531_row6_col0, #T_a7531_row6_col1, #T_a7531_row6_col2, #T_a7531_row7_col0, #T_a7531_row7_col1, #T_a7531_row7_col2, #T_a7531_row8_col0, #T_a7531_row8_col1, #T_a7531_row8_col2, #T_a7531_row9_col0, #T_a7531_row9_col1, #T_a7531_row9_col2, #T_a7531_row10_col0, #T_a7531_row10_col1, #T_a7531_row10_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_a7531">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7531_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_a7531_level0_col1" class="col_heading level0 col1" >max_top_speed_kmh</th>
#       <th id="T_a7531_level0_col2" class="col_heading level0 col2" >max_distance_per_min_mmin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7531_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7531_row0_col0" class="data row0 col0" >Kampala Queens Fc</td>
#       <td id="T_a7531_row0_col1" class="data row0 col1" >32.400000</td>
#       <td id="T_a7531_row0_col2" class="data row0 col2" >105.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7531_row1_col0" class="data row1 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_a7531_row1_col1" class="data row1 col1" >31.170000</td>
#       <td id="T_a7531_row1_col2" class="data row1 col2" >115.150000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7531_row2_col0" class="data row2 col0" >She Maroons Fc</td>
#       <td id="T_a7531_row2_col1" class="data row2 col1" >30.610000</td>
#       <td id="T_a7531_row2_col2" class="data row2 col2" >116.960000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7531_row3_col0" class="data row3 col0" >Amus College Wfc</td>
#       <td id="T_a7531_row3_col1" class="data row3 col1" >30.460000</td>
#       <td id="T_a7531_row3_col2" class="data row3 col2" >111.920000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7531_row4_col0" class="data row4 col0" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_a7531_row4_col1" class="data row4 col1" >30.450000</td>
#       <td id="T_a7531_row4_col2" class="data row4 col2" >107.170000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7531_row5_col0" class="data row5 col0" >Lady Doves Fc</td>
#       <td id="T_a7531_row5_col1" class="data row5 col1" >30.410000</td>
#       <td id="T_a7531_row5_col2" class="data row5 col2" >111.860000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a7531_row6_col0" class="data row6 col0" >Rines Ss Wfc</td>
#       <td id="T_a7531_row6_col1" class="data row6 col1" >30.340000</td>
#       <td id="T_a7531_row6_col2" class="data row6 col2" >113.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a7531_row7_col0" class="data row7 col0" >Olila Hs Wfc</td>
#       <td id="T_a7531_row7_col1" class="data row7 col1" >29.860000</td>
#       <td id="T_a7531_row7_col2" class="data row7 col2" >111.070000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a7531_row8_col0" class="data row8 col0" >Wakiso Hill Wfc</td>
#       <td id="T_a7531_row8_col1" class="data row8 col1" >29.570000</td>
#       <td id="T_a7531_row8_col2" class="data row8 col2" >105.420000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a7531_row9_col0" class="data row9 col0" >Makerere University Wfc</td>
#       <td id="T_a7531_row9_col1" class="data row9 col1" >29.150000</td>
#       <td id="T_a7531_row9_col2" class="data row9 col2" >106.040000</td>
#     </tr>
#     <tr>
#       <th id="T_a7531_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a7531_row10_col0" class="data row10 col0" >She Corporates Fc</td>
#       <td id="T_a7531_row10_col1" class="data row10 col1" >28.050000</td>
#       <td id="T_a7531_row10_col2" class="data row10 col2" >103.360000</td>
#     </tr>
#   </tbody>
# </table>

# %%
club_intensity_avg = (
    df.groupby('club_for')[['top_speed_kmh', 'distance_per_min_mmin']]
    .mean()
    .rename(columns=lambda x: f'avg_{x}')
    .sort_values(by='avg_top_speed_kmh', ascending=False)
    .reset_index()
)
style_table_for_docs(club_intensity_avg.round(2))
# Out:
# <style type="text/css">
# #T_90913 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_90913 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_90913 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_90913_row0_col0, #T_90913_row0_col1, #T_90913_row0_col2, #T_90913_row1_col0, #T_90913_row1_col1, #T_90913_row1_col2, #T_90913_row2_col0, #T_90913_row2_col1, #T_90913_row2_col2, #T_90913_row3_col0, #T_90913_row3_col1, #T_90913_row3_col2, #T_90913_row4_col0, #T_90913_row4_col1, #T_90913_row4_col2, #T_90913_row5_col0, #T_90913_row5_col1, #T_90913_row5_col2, #T_90913_row6_col0, #T_90913_row6_col1, #T_90913_row6_col2, #T_90913_row7_col0, #T_90913_row7_col1, #T_90913_row7_col2, #T_90913_row8_col0, #T_90913_row8_col1, #T_90913_row8_col2, #T_90913_row9_col0, #T_90913_row9_col1, #T_90913_row9_col2, #T_90913_row10_col0, #T_90913_row10_col1, #T_90913_row10_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_90913">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90913_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_90913_level0_col1" class="col_heading level0 col1" >avg_top_speed_kmh</th>
#       <th id="T_90913_level0_col2" class="col_heading level0 col2" >avg_distance_per_min_mmin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90913_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90913_row0_col0" class="data row0 col0" >Kampala Queens Fc</td>
#       <td id="T_90913_row0_col1" class="data row0 col1" >26.340000</td>
#       <td id="T_90913_row0_col2" class="data row0 col2" >76.940000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90913_row1_col0" class="data row1 col0" >Amus College Wfc</td>
#       <td id="T_90913_row1_col1" class="data row1 col1" >26.060000</td>
#       <td id="T_90913_row1_col2" class="data row1 col2" >76.570000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90913_row2_col0" class="data row2 col0" >Lady Doves Fc</td>
#       <td id="T_90913_row2_col1" class="data row2 col1" >25.990000</td>
#       <td id="T_90913_row2_col2" class="data row2 col2" >82.530000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90913_row3_col0" class="data row3 col0" >She Maroons Fc</td>
#       <td id="T_90913_row3_col1" class="data row3 col1" >25.920000</td>
#       <td id="T_90913_row3_col2" class="data row3 col2" >69.470000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90913_row4_col0" class="data row4 col0" >Olila Hs Wfc</td>
#       <td id="T_90913_row4_col1" class="data row4 col1" >25.910000</td>
#       <td id="T_90913_row4_col2" class="data row4 col2" >85.830000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90913_row5_col0" class="data row5 col0" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_90913_row5_col1" class="data row5 col1" >25.570000</td>
#       <td id="T_90913_row5_col2" class="data row5 col2" >75.310000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90913_row6_col0" class="data row6 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_90913_row6_col1" class="data row6 col1" >25.460000</td>
#       <td id="T_90913_row6_col2" class="data row6 col2" >77.050000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90913_row7_col0" class="data row7 col0" >Rines Ss Wfc</td>
#       <td id="T_90913_row7_col1" class="data row7 col1" >25.410000</td>
#       <td id="T_90913_row7_col2" class="data row7 col2" >75.340000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90913_row8_col0" class="data row8 col0" >Wakiso Hill Wfc</td>
#       <td id="T_90913_row8_col1" class="data row8 col1" >25.050000</td>
#       <td id="T_90913_row8_col2" class="data row8 col2" >70.730000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90913_row9_col0" class="data row9 col0" >Makerere University Wfc</td>
#       <td id="T_90913_row9_col1" class="data row9 col1" >25.020000</td>
#       <td id="T_90913_row9_col2" class="data row9 col2" >70.060000</td>
#     </tr>
#     <tr>
#       <th id="T_90913_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_90913_row10_col0" class="data row10 col0" >She Corporates Fc</td>
#       <td id="T_90913_row10_col1" class="data row10 col1" >24.880000</td>
#       <td id="T_90913_row10_col2" class="data row10 col2" >78.490000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Metric High Scores

# %%
# For each metric in volume_metrics, find the player with the highest value, the value, and the club
top_players = []
for metric in volume_metrics +intensity_metrics:
    idx = df[metric].idxmax()
    row = df.loc[idx]
    top_players.append({
        'metric': metric,
        'player': row['p_name'],
        'club': row['club_for'],
        'value': row[metric],
        'match day': row['match_day']
    })

top_players_df = pd.DataFrame(top_players)
style_table_for_docs(top_players_df)
# Out:
# <style type="text/css">
# #T_864cd th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_864cd td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_864cd table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_864cd_row0_col0, #T_864cd_row0_col1, #T_864cd_row0_col2, #T_864cd_row0_col3, #T_864cd_row0_col4, #T_864cd_row1_col0, #T_864cd_row1_col1, #T_864cd_row1_col2, #T_864cd_row1_col3, #T_864cd_row1_col4, #T_864cd_row2_col0, #T_864cd_row2_col1, #T_864cd_row2_col2, #T_864cd_row2_col3, #T_864cd_row2_col4, #T_864cd_row3_col0, #T_864cd_row3_col1, #T_864cd_row3_col2, #T_864cd_row3_col3, #T_864cd_row3_col4, #T_864cd_row4_col0, #T_864cd_row4_col1, #T_864cd_row4_col2, #T_864cd_row4_col3, #T_864cd_row4_col4, #T_864cd_row5_col0, #T_864cd_row5_col1, #T_864cd_row5_col2, #T_864cd_row5_col3, #T_864cd_row5_col4, #T_864cd_row6_col0, #T_864cd_row6_col1, #T_864cd_row6_col2, #T_864cd_row6_col3, #T_864cd_row6_col4, #T_864cd_row7_col0, #T_864cd_row7_col1, #T_864cd_row7_col2, #T_864cd_row7_col3, #T_864cd_row7_col4, #T_864cd_row8_col0, #T_864cd_row8_col1, #T_864cd_row8_col2, #T_864cd_row8_col3, #T_864cd_row8_col4, #T_864cd_row9_col0, #T_864cd_row9_col1, #T_864cd_row9_col2, #T_864cd_row9_col3, #T_864cd_row9_col4, #T_864cd_row10_col0, #T_864cd_row10_col1, #T_864cd_row10_col2, #T_864cd_row10_col3, #T_864cd_row10_col4, #T_864cd_row11_col0, #T_864cd_row11_col1, #T_864cd_row11_col2, #T_864cd_row11_col3, #T_864cd_row11_col4, #T_864cd_row12_col0, #T_864cd_row12_col1, #T_864cd_row12_col2, #T_864cd_row12_col3, #T_864cd_row12_col4, #T_864cd_row13_col0, #T_864cd_row13_col1, #T_864cd_row13_col2, #T_864cd_row13_col3, #T_864cd_row13_col4, #T_864cd_row14_col0, #T_864cd_row14_col1, #T_864cd_row14_col2, #T_864cd_row14_col3, #T_864cd_row14_col4, #T_864cd_row15_col0, #T_864cd_row15_col1, #T_864cd_row15_col2, #T_864cd_row15_col3, #T_864cd_row15_col4 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_864cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_864cd_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_864cd_level0_col1" class="col_heading level0 col1" >player</th>
#       <th id="T_864cd_level0_col2" class="col_heading level0 col2" >club</th>
#       <th id="T_864cd_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_864cd_level0_col4" class="col_heading level0 col4" >match day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_864cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_864cd_row0_col0" class="data row0 col0" >distance_km</td>
#       <td id="T_864cd_row0_col1" class="data row0 col1" >Irene Nantege</td>
#       <td id="T_864cd_row0_col2" class="data row0 col2" >Lady Doves Fc</td>
#       <td id="T_864cd_row0_col3" class="data row0 col3" >11.261000</td>
#       <td id="T_864cd_row0_col4" class="data row0 col4" >MD11</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_864cd_row1_col0" class="data row1 col0" >sprint_distance_m</td>
#       <td id="T_864cd_row1_col1" class="data row1 col1" >Jovia Nakagolo</td>
#       <td id="T_864cd_row1_col2" class="data row1 col2" >Kawempe Muslim Lfc</td>
#       <td id="T_864cd_row1_col3" class="data row1 col3" >1396.526000</td>
#       <td id="T_864cd_row1_col4" class="data row1 col4" >MD20</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_864cd_row2_col0" class="data row2 col0" >power_plays</td>
#       <td id="T_864cd_row2_col1" class="data row2 col1" >Joyce Kainza</td>
#       <td id="T_864cd_row2_col2" class="data row2 col2" >Amus College Wfc</td>
#       <td id="T_864cd_row2_col3" class="data row2 col3" >97.000000</td>
#       <td id="T_864cd_row2_col4" class="data row2 col4" >MD9</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_864cd_row3_col0" class="data row3 col0" >energy_kcal</td>
#       <td id="T_864cd_row3_col1" class="data row3 col1" >Jackeline Adong</td>
#       <td id="T_864cd_row3_col2" class="data row3 col2" >She Maroons Fc</td>
#       <td id="T_864cd_row3_col3" class="data row3 col3" >1334.901400</td>
#       <td id="T_864cd_row3_col4" class="data row3 col4" >MD20</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_864cd_row4_col0" class="data row4 col0" >impacts</td>
#       <td id="T_864cd_row4_col1" class="data row4 col1" >Yasmeen Nalukwago</td>
#       <td id="T_864cd_row4_col2" class="data row4 col2" >Rines Ss Wfc</td>
#       <td id="T_864cd_row4_col3" class="data row4 col3" >44.000000</td>
#       <td id="T_864cd_row4_col4" class="data row4 col4" >MD17</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_864cd_row5_col0" class="data row5 col0" >total_accelerations</td>
#       <td id="T_864cd_row5_col1" class="data row5 col1" >Immaculate Nakanjako</td>
#       <td id="T_864cd_row5_col2" class="data row5 col2" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_864cd_row5_col3" class="data row5 col3" >601.000000</td>
#       <td id="T_864cd_row5_col4" class="data row5 col4" >MD2</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_864cd_row6_col0" class="data row6 col0" >total_decelerations</td>
#       <td id="T_864cd_row6_col1" class="data row6 col1" >Phionah Arach</td>
#       <td id="T_864cd_row6_col2" class="data row6 col2" >Rines Ss Wfc</td>
#       <td id="T_864cd_row6_col3" class="data row6 col3" >586.000000</td>
#       <td id="T_864cd_row6_col4" class="data row6 col4" >MD17</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_864cd_row7_col0" class="data row7 col0" >player_load</td>
#       <td id="T_864cd_row7_col1" class="data row7 col1" >Catherine Namataka</td>
#       <td id="T_864cd_row7_col2" class="data row7 col2" >Amus College Wfc</td>
#       <td id="T_864cd_row7_col3" class="data row7 col3" >593.191200</td>
#       <td id="T_864cd_row7_col4" class="data row7 col4" >MD13</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_864cd_row8_col0" class="data row8 col0" >top_speed_kmh</td>
#       <td id="T_864cd_row8_col1" class="data row8 col1" >Muduwa Peace</td>
#       <td id="T_864cd_row8_col2" class="data row8 col2" >Kampala Queens Fc</td>
#       <td id="T_864cd_row8_col3" class="data row8 col3" >32.400300</td>
#       <td id="T_864cd_row8_col4" class="data row8 col4" >MD17</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_864cd_row9_col0" class="data row9 col0" >distance_per_min_mmin</td>
#       <td id="T_864cd_row9_col1" class="data row9 col1" >Jackeline Adong</td>
#       <td id="T_864cd_row9_col2" class="data row9 col2" >She Maroons Fc</td>
#       <td id="T_864cd_row9_col3" class="data row9 col3" >116.958686</td>
#       <td id="T_864cd_row9_col4" class="data row9 col4" >MD20</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_864cd_row10_col0" class="data row10 col0" >power_score_wkg</td>
#       <td id="T_864cd_row10_col1" class="data row10 col1" >Jackeline Adong</td>
#       <td id="T_864cd_row10_col2" class="data row10 col2" >She Maroons Fc</td>
#       <td id="T_864cd_row10_col3" class="data row10 col3" >18.785700</td>
#       <td id="T_864cd_row10_col4" class="data row10 col4" >MD20</td>
#     </tr>
#     <tr>
#       <th id="T_864cd_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_864cd_row11_col0" class="data row11 col0" >work_ratio</td>
#       <td id="T_864cd_row11_col1" class="data row11 col1" >Dorcus Nabuufu</td>
#       <td id="T_864cd_row11_col2" class="data row11 col2" >She Maroons Fc</td>
#       <td id="T

# %% [markdown]
# ### Comparison by Position Group

# %%
# Calculate average volume metrics by general position
avg_volume_by_position = df.groupby('general_position')[volume_metrics].mean().round(2)
style_table_for_docs(avg_volume_by_position)
# Out:
# <style type="text/css">
# #T_be9d8 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_be9d8 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_be9d8 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_be9d8_row0_col0, #T_be9d8_row0_col1, #T_be9d8_row0_col2, #T_be9d8_row0_col3, #T_be9d8_row0_col4, #T_be9d8_row0_col5, #T_be9d8_row0_col6, #T_be9d8_row1_col0, #T_be9d8_row1_col1, #T_be9d8_row1_col2, #T_be9d8_row1_col3, #T_be9d8_row1_col4, #T_be9d8_row1_col5, #T_be9d8_row1_col6, #T_be9d8_row2_col0, #T_be9d8_row2_col1, #T_be9d8_row2_col2, #T_be9d8_row2_col3, #T_be9d8_row2_col4, #T_be9d8_row2_col5, #T_be9d8_row2_col6 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_be9d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be9d8_level0_col0" class="col_heading level0 col0" >distance_km</th>
#       <th id="T_be9d8_level0_col1" class="col_heading level0 col1" >sprint_distance_m</th>
#       <th id="T_be9d8_level0_col2" class="col_heading level0 col2" >power_plays</th>
#       <th id="T_be9d8_level0_col3" class="col_heading level0 col3" >energy_kcal</th>
#       <th id="T_be9d8_level0_col4" class="col_heading level0 col4" >impacts</th>
#       <th id="T_be9d8_level0_col5" class="col_heading level0 col5" >total_accelerations</th>
#       <th id="T_be9d8_level0_col6" class="col_heading level0 col6" >total_decelerations</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be9d8_level0_row0" class="row_heading level0 row0" >Defenders</th>
#       <td id="T_be9d8_row0_col0" class="data row0 col0" >7.670000</td>
#       <td id="T_be9d8_row0_col1" class="data row0 col1" >429.200000</td>
#       <td id="T_be9d8_row0_col2" class="data row0 col2" >37.210000</td>
#       <td id="T_be9d8_row0_col3" class="data row0 col3" >755.240000</td>
#       <td id="T_be9d8_row0_col4" class="data row0 col4" >6.190000</td>
#       <td id="T_be9d8_row0_col5" class="data row0 col5" >369.350000</td>
#       <td id="T_be9d8_row0_col6" class="data row0 col6" >357.060000</td>
#     </tr>
#     <tr>
#       <th id="T_be9d8_level0_row1" class="row_heading level0 row1" >Forwards</th>
#       <td id="T_be9d8_row1_col0" class="data row1 col0" >6.800000</td>
#       <td id="T_be9d8_row1_col1" class="data row1 col1" >487.930000</td>
#       <td id="T_be9d8_row1_col2" class="data row1 col2" >39.570000</td>
#       <td id="T_be9d8_row1_col3" class="data row1 col3" >671.370000</td>
#       <td id="T_be9d8_row1_col4" class="data row1 col4" >4.880000</td>
#       <td id="T_be9d8_row1_col5" class="data row1 col5" >311.780000</td>
#       <td id="T_be9d8_row1_col6" class="data row1 col6" >302.430000</td>
#     </tr>
#     <tr>
#       <th id="T_be9d8_level0_row2" class="row_heading level0 row2" >Midfielders</th>
#       <td id="T_be9d8_row2_col0" class="data row2 col0" >7.680000</td>
#       <td id="T_be9d8_row2_col1" class="data row2 col1" >362.340000</td>
#       <td id="T_be9d8_row2_col2" class="data row2 col2" >36.240000</td>
#       <td id="T_be9d8_row2_col3" class="data row2 col3" >765.900000</td>
#       <td id="T_be9d8_row2_col4" class="data row2 col4" >5.840000</td>
#       <td id="T_be9d8_row2_col5" class="data row2 col5" >377.660000</td>
#       <td id="T_be9d8_row2_col6" class="data row2 col6" >368.700000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate average intensity metrics by general position
avg_intensity_by_position = df.groupby('general_position')[[i for i in intensity_metrics if i not in ['top_speed_kmh','distance_per_min_mmin','max_acceleration_mss','max_deceleration_mss']]].mean()
style_table_for_docs(avg_intensity_by_position)
# Out:
# <style type="text/css">
# #T_e7e18 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e7e18 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e7e18 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_e7e18_row0_col0, #T_e7e18_row0_col1, #T_e7e18_row0_col2, #T_e7e18_row0_col3, #T_e7e18_row0_col4, #T_e7e18_row1_col0, #T_e7e18_row1_col1, #T_e7e18_row1_col2, #T_e7e18_row1_col3, #T_e7e18_row1_col4, #T_e7e18_row2_col0, #T_e7e18_row2_col1, #T_e7e18_row2_col2, #T_e7e18_row2_col3, #T_e7e18_row2_col4 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_e7e18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7e18_level0_col0" class="col_heading level0 col0" >player_load</th>
#       <th id="T_e7e18_level0_col1" class="col_heading level0 col1" >power_score_wkg</th>
#       <th id="T_e7e18_level0_col2" class="col_heading level0 col2" >work_ratio</th>
#       <th id="T_e7e18_level0_col3" class="col_heading level0 col3" >acc_counts_per_min</th>
#       <th id="T_e7e18_level0_col4" class="col_heading level0 col4" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7e18_level0_row0" class="row_heading level0 row0" >Defenders</th>
#       <td id="T_e7e18_row0_col0" class="data row0 col0" >373.319287</td>
#       <td id="T_e7e18_row0_col1" class="data row0 col1" >11.997689</td>
#       <td id="T_e7e18_row0_col2" class="data row0 col2" >60.522370</td>
#       <td id="T_e7e18_row0_col3" class="data row0 col3" >3.738835</td>
#       <td id="T_e7e18_row0_col4" class="data row0 col4" >3.613820</td>
#     </tr>
#     <tr>
#       <th id="T_e7e18_level0_row1" class="row_heading level0 row1" >Forwards</th>
#       <td id="T_e7e18_row1_col0" class="data row1 col0" >330.726552</td>
#       <td id="T_e7e18_row1_col1" class="data row1 col1" >10.719319</td>
#       <td id="T_e7e18_row1_col2" class="data row1 col2" >53.438918</td>
#       <td id="T_e7e18_row1_col3" class="data row1 col3" >3.149409</td>
#       <td id="T_e7e18_row1_col4" class="data row1 col4" >3.055459</td>
#     </tr>
#     <tr>
#       <th id="T_e7e18_level0_row2" class="row_heading level0 row2" >Midfielders</th>
#       <td id="T_e7e18_row2_col0" class="data row2 col0" >380.108835</td>
#       <td id="T_e7e18_row2_col1" class="data row2 col1" >12.079581</td>
#       <td id="T_e7e18_row2_col2" class="data row2 col2" >63.855658</td>
#       <td id="T_e7e18_row2_col3" class="data row2 col3" >3.834374</td>
#       <td id="T_e7e18_row2_col4" class="data row2 col4" >3.743897</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate max metrics by general position
avg_intensity_by_position_ = df.groupby('general_position')[['top_speed_kmh','distance_per_min_mmin','acc_counts_per_min','dec_counts_per_min']].max().round(2)
style_table_for_docs(avg_intensity_by_position_)
# Out:
# <style type="text/css">
# #T_e2ee8 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e2ee8 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e2ee8 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_e2ee8_row0_col0, #T_e2ee8_row0_col1, #T_e2ee8_row0_col2, #T_e2ee8_row0_col3, #T_e2ee8_row1_col0, #T_e2ee8_row1_col1, #T_e2ee8_row1_col2, #T_e2ee8_row1_col3, #T_e2ee8_row2_col0, #T_e2ee8_row2_col1, #T_e2ee8_row2_col2, #T_e2ee8_row2_col3 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_e2ee8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2ee8_level0_col0" class="col_heading level0 col0" >top_speed_kmh</th>
#       <th id="T_e2ee8_level0_col1" class="col_heading level0 col1" >distance_per_min_mmin</th>
#       <th id="T_e2ee8_level0_col2" class="col_heading level0 col2" >acc_counts_per_min</th>
#       <th id="T_e2ee8_level0_col3" class="col_heading level0 col3" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ee8_level0_row0" class="row_heading level0 row0" >Defenders</th>
#       <td id="T_e2ee8_row0_col0" class="data row0 col0" >30.340000</td>
#       <td id="T_e2ee8_row0_col1" class="data row0 col1" >112.930000</td>
#       <td id="T_e2ee8_row0_col2" class="data row0 col2" >5.710000</td>
#       <td id="T_e2ee8_row0_col3" class="data row0 col3" >5.520000</td>
#     </tr>
#     <tr>
#       <th id="T_e2ee8_level0_row1" class="row_heading level0 row1" >Forwards</th>
#       <td id="T_e2ee8_row1_col0" class="data row1 col0" >32.400000</td>
#       <td id="T_e2ee8_row1_col1" class="data row1 col1" >113.500000</td>
#       <td id="T_e2ee8_row1_col2" class="data row1 col2" >5.960000</td>
#       <td id="T_e2ee8_row1_col3" class="data row1 col3" >5.740000</td>
#     </tr>
#     <tr>
#       <th id="T_e2ee8_level0_row2" class="row_heading level0 row2" >Midfielders</th>
#       <td id="T_e2ee8_row2_col0" class="data row2 col0" >30.410000</td>
#       <td id="T_e2ee8_row2_col1" class="data row2 col1" >116.960000</td>
#       <td id="T_e2ee8_row2_col2" class="data row2 col2" >5.980000</td>
#       <td id="T_e2ee8_row2_col3" class="data row2 col3" >5.970000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate mean max metrics by general position
avg_intensity_by_position_ = df.groupby('general_position')[['top_speed_kmh','distance_per_min_mmin','acc_counts_per_min','dec_counts_per_min']].mean().round(2)
style_table_for_docs(avg_intensity_by_position_)
# Out:
# <style type="text/css">
# #T_74deb th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_74deb td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_74deb table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_74deb_row0_col0, #T_74deb_row0_col1, #T_74deb_row0_col2, #T_74deb_row0_col3, #T_74deb_row1_col0, #T_74deb_row1_col1, #T_74deb_row1_col2, #T_74deb_row1_col3, #T_74deb_row2_col0, #T_74deb_row2_col1, #T_74deb_row2_col2, #T_74deb_row2_col3 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_74deb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74deb_level0_col0" class="col_heading level0 col0" >top_speed_kmh</th>
#       <th id="T_74deb_level0_col1" class="col_heading level0 col1" >distance_per_min_mmin</th>
#       <th id="T_74deb_level0_col2" class="col_heading level0 col2" >acc_counts_per_min</th>
#       <th id="T_74deb_level0_col3" class="col_heading level0 col3" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74deb_level0_row0" class="row_heading level0 row0" >Defenders</th>
#       <td id="T_74deb_row0_col0" class="data row0 col0" >25.810000</td>
#       <td id="T_74deb_row0_col1" class="data row0 col1" >77.650000</td>
#       <td id="T_74deb_row0_col2" class="data row0 col2" >3.740000</td>
#       <td id="T_74deb_row0_col3" class="data row0 col3" >3.610000</td>
#     </tr>
#     <tr>
#       <th id="T_74deb_level0_row1" class="row_heading level0 row1" >Forwards</th>
#       <td id="T_74deb_row1_col0" class="data row1 col0" >26.450000</td>
#       <td id="T_74deb_row1_col1" class="data row1 col1" >68.680000</td>
#       <td id="T_74deb_row1_col2" class="data row1 col2" >3.150000</td>
#       <td id="T_74deb_row1_col3" class="data row1 col3" >3.060000</td>
#     </tr>
#     <tr>
#       <th id="T_74deb_level0_row2" class="row_heading level0 row2" >Midfielders</th>
#       <td id="T_74deb_row2_col0" class="data row2 col0" >24.460000</td>
#       <td id="T_74deb_row2_col1" class="data row2 col1" >77.950000</td>
#       <td id="T_74deb_row2_col2" class="data row2 col2" >3.830000</td>
#       <td id="T_74deb_row2_col3" class="data row2 col3" >3.740000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Draw thin horizontal lines with a large circle at the end for each position group, for four metrics in a 2x2 grid

metrics_to_plot = [
    ('top_speed_kmh', 'Top Speed (km/h)'),
    ('distance_per_min_mmin', 'Distance Per Minute (m/min)'),
    ('acc_counts_per_min', 'Acceleration Counts Per Minute'),
    ('dec_counts_per_min', 'Deceleration Counts Per Minute')
]

# Define the order of position groups
position_order = ['Defenders', 'Midfielders', 'Forwards']

fig, axes = plt.subplots(2, 2, figsize=(14, 7), sharey=True)

for ax, (metric, xlabel) in zip(axes.flatten(), metrics_to_plot):
    avg_by_position = df.groupby('general_position')[metric].mean().reindex(position_order)
    n = len(avg_by_position)
    y_positions = np.arange(n)
    palette = sns.color_palette('Set1', n)
    circle_radius = 30

    for y, (pos, val), color in zip(y_positions, avg_by_position.items(), palette):
        ax.hlines(y=y, xmin=0, xmax=val, color=color, linewidth=2)
        ax.plot(val, y, 'o', markeredgecolor=color, markersize=circle_radius, markerfacecolor='white')
        if metric == 'top_speed_kmh':
            text_val = f'{val:.1f}'
        elif metric == 'distance_per_min_mmin':
            text_val = f'{val:.1f}'
        elif metric == 'acc_counts_per_min':
            text_val = f'{val:.1f}'
        else:
            text_val = f'{val:.1f}'
        ax.text(val, y, text_val, va='center', ha='center', fontsize=10, color='black', fontweight='bold')

    yticklabels = [f"{pos}" for pos in position_order]
    ax.set_yticks(y_positions)
    ax.set_yticklabels(yticklabels, color='#E0DCDD')
    ax.set_xlabel(xlabel)
    ax.grid(axis='x', linestyle='--', alpha=0.6)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_position(('data', 0))
    ax.spines['left'].set_color('#E0DCDD')
    ax.spines['bottom'].set_color('#E0DCDD')

axes[0,0].set_ylabel('Position Group')
axes[1,0].set_ylabel('Position Group')
fig.suptitle('Average Top Speed, Distance per Minute, Acceleration and Deceleration Counts Per Minute by Position Group')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Draw thin horizontal lines with a large circle at the end for each position group, for four metrics in a 2x2 grid

metrics_to_plot = [
    ('distance_km', 'Average Distance (km)'),
    ('total_accelerations', 'Average Total Accelerations'),
    ('sprint_distance_m', 'Average Sprint Distance (m)'),
    ('player_load', 'Average Player Load')
]

# Define the order of position groups
position_order = ['Defenders', 'Midfielders', 'Forwards']

fig, axes = plt.subplots(2, 2, figsize=(14, 7), sharey=True)

for ax, (metric, xlabel) in zip(axes.flatten(), metrics_to_plot):
    avg_by_position = df.groupby('general_position')[metric].mean().reindex(position_order)
    n = len(avg_by_position)
    y_positions = np.arange(n)
    palette = sns.color_palette('Set1', n)
    circle_radius = 30

    for y, (pos, val), color in zip(y_positions, avg_by_position.items(), palette):
        ax.hlines(y=y, xmin=0, xmax=val, color=color, linewidth=2)
        ax.plot(val, y, 'o', markeredgecolor=color, markersize=circle_radius, markerfacecolor='white')
        if metric == 'distance_km':
            text_val = f'{val:.1f}'
        elif metric == 'sprint_distance_m':
            text_val = f'{val:.0f}'
        elif metric == 'player_load':
            text_val = f'{val:.0f}'
        else:
            text_val = f'{val:.0f}'
        ax.text(val, y, text_val, va='center', ha='center', fontsize=10, color='black', fontweight='bold')

    yticklabels = [f"{pos}" for pos in position_order]
    ax.set_yticks(y_positions)
    ax.set_yticklabels(yticklabels, color='#E0DCDD')
    ax.set_xlabel(xlabel)
    ax.grid(axis='x', linestyle='--', alpha=0.6)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_position(('data', 0))
    ax.spines['left'].set_color('#E0DCDD')
    ax.spines['bottom'].set_color('#E0DCDD')

axes[0,0].set_ylabel('Position Group')
axes[1,0].set_ylabel('Position Group')
fig.suptitle('Average Distance, Sprint Distance, Player Load, and Total Accelerations by Position Group')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ### Comparison by Location

# %%
# Calculate average volume metrics by location
avg_volume_by_location = df.groupby('location')[volume_metrics].mean().round(2)
style_table_for_docs(avg_volume_by_location)
# Out:
# <style type="text/css">
# #T_fe478 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_fe478 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_fe478 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_fe478_row0_col0, #T_fe478_row0_col1, #T_fe478_row0_col2, #T_fe478_row0_col3, #T_fe478_row0_col4, #T_fe478_row0_col5, #T_fe478_row0_col6, #T_fe478_row1_col0, #T_fe478_row1_col1, #T_fe478_row1_col2, #T_fe478_row1_col3, #T_fe478_row1_col4, #T_fe478_row1_col5, #T_fe478_row1_col6 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_fe478">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe478_level0_col0" class="col_heading level0 col0" >distance_km</th>
#       <th id="T_fe478_level0_col1" class="col_heading level0 col1" >sprint_distance_m</th>
#       <th id="T_fe478_level0_col2" class="col_heading level0 col2" >power_plays</th>
#       <th id="T_fe478_level0_col3" class="col_heading level0 col3" >energy_kcal</th>
#       <th id="T_fe478_level0_col4" class="col_heading level0 col4" >impacts</th>
#       <th id="T_fe478_level0_col5" class="col_heading level0 col5" >total_accelerations</th>
#       <th id="T_fe478_level0_col6" class="col_heading level0 col6" >total_decelerations</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe478_level0_row0" class="row_heading level0 row0" >Away</th>
#       <td id="T_fe478_row0_col0" class="data row0 col0" >7.490000</td>
#       <td id="T_fe478_row0_col1" class="data row0 col1" >428.280000</td>
#       <td id="T_fe478_row0_col2" class="data row0 col2" >37.970000</td>
#       <td id="T_fe478_row0_col3" class="data row0 col3" >737.510000</td>
#       <td id="T_fe478_row0_col4" class="data row0 col4" >5.670000</td>
#       <td id="T_fe478_row0_col5" class="data row0 col5" >358.540000</td>
#       <td id="T_fe478_row0_col6" class="data row0 col6" >347.690000</td>
#     </tr>
#     <tr>
#       <th id="T_fe478_level0_row1" class="row_heading level0 row1" >Home</th>
#       <td id="T_fe478_row1_col0" class="data row1 col0" >7.310000</td>
#       <td id="T_fe478_row1_col1" class="data row1 col1" >429.190000</td>
#       <td id="T_fe478_row1_col2" class="data row1 col2" >37.440000</td>
#       <td id="T_fe478_row1_col3" class="data row1 col3" >725.760000</td>
#       <td id="T_fe478_row1_col4" class="data row1 col4" >5.670000</td>
#       <td id="T_fe478_row1_col5" class="data row1 col5" >348.450000</td>
#       <td id="T_fe478_row1_col6" class="data row1 col6" >338.490000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate average intensity metrics by location
avg_intensity_by_location = df.groupby('location')[[i for i in intensity_metrics ]].mean()
style_table_for_docs(avg_intensity_by_location)
# Out:
# <style type="text/css">
# #T_4a8a7 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4a8a7 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4a8a7 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_4a8a7_row0_col0, #T_4a8a7_row0_col1, #T_4a8a7_row0_col2, #T_4a8a7_row0_col3, #T_4a8a7_row0_col4, #T_4a8a7_row0_col5, #T_4a8a7_row0_col6, #T_4a8a7_row0_col7, #T_4a8a7_row0_col8, #T_4a8a7_row1_col0, #T_4a8a7_row1_col1, #T_4a8a7_row1_col2, #T_4a8a7_row1_col3, #T_4a8a7_row1_col4, #T_4a8a7_row1_col5, #T_4a8a7_row1_col6, #T_4a8a7_row1_col7, #T_4a8a7_row1_col8 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_4a8a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a8a7_level0_col0" class="col_heading level0 col0" >player_load</th>
#       <th id="T_4a8a7_level0_col1" class="col_heading level0 col1" >top_speed_kmh</th>
#       <th id="T_4a8a7_level0_col2" class="col_heading level0 col2" >distance_per_min_mmin</th>
#       <th id="T_4a8a7_level0_col3" class="col_heading level0 col3" >power_score_wkg</th>
#       <th id="T_4a8a7_level0_col4" class="col_heading level0 col4" >work_ratio</th>
#       <th id="T_4a8a7_level0_col5" class="col_heading level0 col5" >max_acceleration_mss</th>
#       <th id="T_4a8a7_level0_col6" class="col_heading level0 col6" >max_deceleration_mss</th>
#       <th id="T_4a8a7_level0_col7" class="col_heading level0 col7" >acc_counts_per_min</th>
#       <th id="T_4a8a7_level0_col8" class="col_heading level0 col8" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a8a7_level0_row0" class="row_heading level0 row0" >Away</th>
#       <td id="T_4a8a7_row0_col0" class="data row0 col0" >365.330626</td>
#       <td id="T_4a8a7_row0_col1" class="data row0 col1" >25.601661</td>
#       <td id="T_4a8a7_row0_col2" class="data row0 col2" >75.813402</td>
#       <td id="T_4a8a7_row0_col3" class="data row0 col3" >11.765009</td>
#       <td id="T_4a8a7_row0_col4" class="data row0 col4" >60.094710</td>
#       <td id="T_4a8a7_row0_col5" class="data row0 col5" >5.253208</td>
#       <td id="T_4a8a7_row0_col6" class="data row0 col6" >6.453951</td>
#       <td id="T_4a8a7_row0_col7" class="data row0 col7" >3.630468</td>
#       <td id="T_4a8a7_row0_col8" class="data row0 col8" >3.520680</td>
#     </tr>
#     <tr>
#       <th id="T_4a8a7_level0_row1" class="row_heading level0 row1" >Home</th>
#       <td id="T_4a8a7_row1_col0" class="data row1 col0" >358.198812</td>
#       <td id="T_4a8a7_row1_col1" class="data row1 col1" >25.645603</td>
#       <td id="T_4a8a7_row1_col2" class="data row1 col2" >73.984771</td>
#       <td id="T_4a8a7_row1_col3" class="data row1 col3" >11.470658</td>
#       <td id="T_4a8a7_row1_col4" class="data row1 col4" >58.410682</td>
#       <td id="T_4a8a7_row1_col5" class="data row1 col5" >5.202563</td>
#       <td id="T_4a8a7_row1_col6" class="data row1 col6" >6.422387</td>
#       <td id="T_4a8a7_row1_col7" class="data row1 col7" >3.528500</td>
#       <td id="T_4a8a7_row1_col8" class="data row1 col8" >3.427764</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate max metrics by location
avg_intensity_by_location_ = df.groupby('location')[['top_speed_kmh','distance_per_min_mmin']].max().round(2)
style_table_for_docs(avg_intensity_by_location_)
# Out:
# <style type="text/css">
# #T_a8647 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a8647 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a8647 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_a8647_row0_col0, #T_a8647_row0_col1, #T_a8647_row1_col0, #T_a8647_row1_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_a8647">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8647_level0_col0" class="col_heading level0 col0" >top_speed_kmh</th>
#       <th id="T_a8647_level0_col1" class="col_heading level0 col1" >distance_per_min_mmin</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8647_level0_row0" class="row_heading level0 row0" >Away</th>
#       <td id="T_a8647_row0_col0" class="data row0 col0" >32.400000</td>
#       <td id="T_a8647_row0_col1" class="data row0 col1" >115.150000</td>
#     </tr>
#     <tr>
#       <th id="T_a8647_level0_row1" class="row_heading level0 row1" >Home</th>
#       <td id="T_a8647_row1_col0" class="data row1 col0" >31.170000</td>
#       <td id="T_a8647_row1_col1" class="data row1 col1" >116.960000</td>
#     </tr>
#   </tbody>
# </table>

# %%
def plot_home_away_top_speed(avg_volume_by_location, color='#003b59', min_radius=0.8, max_radius=1.1):
    """
    Plot a semicircle comparison of top speed (km/h) for Home vs Away using avg_volume_by_location DataFrame.
    """
    home_speed = avg_volume_by_location.loc['Home', 'distance_km']
    away_speed = avg_volume_by_location.loc['Away', 'distance_km']

    speeds = np.array([home_speed, away_speed])
    norm_radii = min_radius + (speeds - speeds.min()) / (speeds.max() - speeds.min()) * (max_radius - min_radius)
    home_radius, away_radius = norm_radii

    fig, ax = plt.subplots(figsize=(3, 3))
    ax.set_aspect('equal')
    ax.axis('off')

    # Draw right (Home) semicircle
    theta_home = np.linspace(-np.pi/2, np.pi/2, 100)
    x_home = home_radius * np.cos(theta_home)
    y_home = home_radius * np.sin(theta_home)
    ax.plot(x_home, y_home, color=color, linewidth=0.5)
    if home_radius < away_radius:
        ax.fill_betweenx(y_home, 0, x_home, color=color, alpha=0.5)

    # Draw left (Away) semicircle
    theta_away = np.linspace(np.pi/2, 3*np.pi/2, 100)
    x_away = away_radius * np.cos(theta_away)
    y_away = away_radius * np.sin(theta_away)
    ax.plot(x_away, y_away, color=color, linewidth=0.5)
    if away_radius < home_radius:
        ax.fill_betweenx(y_away, x_away, 0, color=color, alpha=0.5)

    # Draw the separating line
    ax.plot([0, 0], [-max(home_radius+0.5, away_radius+0.5), max(home_radius+0.5, away_radius+0.5)], color=color, linewidth=0.5, zorder=3)

    # Place values inside semicircles
    ax.text(home_radius * 0.5, 0, f"{home_speed:.2f}\nHome", ha='center', va='center', fontsize=10, color='#fff', fontweight='normal')
    ax.text(-away_radius * 0.5, 0, f"{away_speed:.2f}\nAway", ha='center', va='center', fontsize=10, color='#000', fontweight='normal')

    plt.title('Distance (km)', fontsize=12)
    plt.show()
plot_home_away_top_speed(avg_volume_by_location)

# %% [markdown]
# ### Metric Distribution

# %%
plt.figure(figsize=(16, 16))
for i, col in enumerate(num_cols):
    plt.subplot(5, 3, i + 1)
    sns.histplot(df[col], bins=30, kde=True)
    # Format title and x-label: replace _ with space, capitalize, add units if present
    label = col.replace('_', ' ').title()
    # Add units for specific columns
    if col == 'distance_km':
        label = 'Distance (km)'
    elif col == 'sprint_distance_m':
        label = 'Sprint Distance (m)'
    elif col == 'top_speed_kmh':
        label = 'Top Speed (km/h)'
    elif col == 'distance_per_min_mmin':
        label = 'Distance per Min (m/min)'
    elif col == 'power_score_wkg':
        label = 'Power Score (W/kg)'
    elif col == 'max_acceleration_mss':
        label = 'Max Acceleration (m/s²)'
    elif col == 'max_deceleration_mss':
        label = 'Max Deceleration (m/s²)'
    elif col == 'acc_counts_per_min':
        label = 'Acc. Counts per Min'
    elif col == 'dec_counts_per_min':
        label = 'Dec. Counts per Min'
    
    plt.title(f'Distribution of {label}')
    plt.xlabel(label)
    plt.xticks(rotation=90)
    # Remove top and right spines
    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Trend Analysis

# %%
avg_volume_per_matchday = df.groupby('match_day')[volume_metrics + intensity_metrics].mean().reset_index()
# Ensure 'match_day' is a categorical variable with the correct order
avg_volume_per_matchday['match_day'] = pd.Categorical(
    avg_volume_per_matchday['match_day'],
    categories=matchday_order,
    ordered=True
)
avg_volume_per_matchday = avg_volume_per_matchday.sort_values(by='match_day').round(2)
style_table_for_docs(avg_volume_per_matchday)
# Out:
# <style type="text/css">
# #T_76c1a th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_76c1a td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_76c1a table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_76c1a_row0_col0, #T_76c1a_row0_col1, #T_76c1a_row0_col2, #T_76c1a_row0_col3, #T_76c1a_row0_col4, #T_76c1a_row0_col5, #T_76c1a_row0_col6, #T_76c1a_row0_col7, #T_76c1a_row0_col8, #T_76c1a_row0_col9, #T_76c1a_row0_col10, #T_76c1a_row0_col11, #T_76c1a_row0_col12, #T_76c1a_row0_col13, #T_76c1a_row0_col14, #T_76c1a_row0_col15, #T_76c1a_row0_col16, #T_76c1a_row1_col0, #T_76c1a_row1_col1, #T_76c1a_row1_col2, #T_76c1a_row1_col3, #T_76c1a_row1_col4, #T_76c1a_row1_col5, #T_76c1a_row1_col6, #T_76c1a_row1_col7, #T_76c1a_row1_col8, #T_76c1a_row1_col9, #T_76c1a_row1_col10, #T_76c1a_row1_col11, #T_76c1a_row1_col12, #T_76c1a_row1_col13, #T_76c1a_row1_col14, #T_76c1a_row1_col15, #T_76c1a_row1_col16, #T_76c1a_row2_col0, #T_76c1a_row2_col1, #T_76c1a_row2_col2, #T_76c1a_row2_col3, #T_76c1a_row2_col4, #T_76c1a_row2_col5, #T_76c1a_row2_col6, #T_76c1a_row2_col7, #T_76c1a_row2_col8, #T_76c1a_row2_col9, #T_76c1a_row2_col10, #T_76c1a_row2_col11, #T_76c1a_row2_col12, #T_76c1a_row2_col13, #T_76c1a_row2_col14, #T_76c1a_row2_col15, #T_76c1a_row2_col16, #T_76c1a_row3_col0, #T_76c1a_row3_col1, #T_76c1a_row3_col2, #T_76c1a_row3_col3, #T_76c1a_row3_col4, #T_76c1a_row3_col5, #T_76c1a_row3_col6, #T_76c1a_row3_col7, #T_76c1a_row3_col8, #T_76c1a_row3_col9, #T_76c1a_row3_col10, #T_76c1a_row3_col11, #T_76c1a_row3_col12, #T_76c1a_row3_col13, #T_76c1a_row3_col14, #T_76c1a_row3_col15, #T_76c1a_row3_col16, #T_76c1a_row4_col0, #T_76c1a_row4_col1, #T_76c1a_row4_col2, #T_76c1a_row4_col3, #T_76c1a_row4_col4, #T_76c1a_row4_col5, #T_76c1a_row4_col6, #T_76c1a_row4_col7, #T_76c1a_row4_col8, #T_76c1a_row4_col9, #T_76c1a_row4_col10, #T_76c1a_row4_col11, #T_76c1a_row4_col12, #T_76c1a_row4_col13, #T_76c1a_row4_col14, #T_76c1a_row4_col15, #T_76c1a_row4_col16, #T_76c1a_row5_col0, #T_76c1a_row5_col1, #T_76c1a_row5_col2, #T_76c1a_row5_col3, #T_76c1a_row5_col4, #T_76c1a_row5_col5, #T_76c1a_row5_col6, #T_76c1a_row5_col7, #T_76c1a_row5_col8, #T_76c1a_row5_col9, #T_76c1a_row5_col10, #T_76c1a_row5_col11, #T_76c1a_row5_col12, #T_76c1a_row5_col13, #T_76c1a_row5_col14, #T_76c1a_row5_col15, #T_76c1a_row5_col16, #T_76c1a_row6_col0, #T_76c1a_row6_col1, #T_76c1a_row6_col2, #T_76c1a_row6_col3, #T_76c1a_row6_col4, #T_76c1a_row6_col5, #T_76c1a_row6_col6, #T_76c1a_row6_col7, #T_76c1a_row6_col8, #T_76c1a_row6_col9, #T_76c1a_row6_col10, #T_76c1a_row6_col11, #T_76c1a_row6_col12, #T_76c1a_row6_col13, #T_76c1a_row6_col14, #T_76c1a_row6_col15, #T_76c1a_row6_col16, #T_76c1a_row7_col0, #T_76c1a_row7_col1, #T_76c1a_row7_col2, #T_76c1a_row7_col3, #T_76c1a_row7_col4, #T_76c1a_row7_col5, #T_76c1a_row7_col6, #T_76c1a_row7_col7, #T_76c1a_row7_col8, #T_76c1a_row7_col9, #T_76c1a_row7_col10, #T_76c1a_row7_col11, #T_76c1a_row7_col12, #T_76c1a_row7_col13, #T_76c1a_row7_col14, #T_76c1a_row7_col15, #T_76c1a_row7_col16, #T_76c1a_row8_col0, #T_76c1a_row8_col1, #T_76c1a_row8_col2, #T_76c1a_row8_col3, #T_76c1a_row8_col4, #T_76c1a_row8_col5, #T_76c1a_row8_col6, #T_76c1a_row8_col7, #T_76c1a_row8_col8, #T_76c1a_row8_col9, #T_76c1a_row8_col10, #T_76c1a_row8_col11, #T_76c1a_row8_col12, #T_76c1a_row8_col13, #T_76c1a_row8_col14, #T_76c1a_row8_col15, #T_76c1a_row8_col16, #T_76c1a_row9_col0, #T_76c1a_row9_col1, #T_76c1a_row9_col2, #T_76c1a_row9_col3, #T_76c1a_row9_col4, #T_76c1a_row9_col5, #T_76c1a_row9_col6, #T_76c1a_row9_col7, #T_76c1a_row9_col8, #T_76c1a_row9_col9, #T_76c1a_row9_col10, #T_76c1a_row9_col11, #T_76c1a_row9_col12, #T_76c1a_row9_col13, #T_76c1a_row9_col14, #T_76c1a_row9_col15, #T_76c1a_row9_col16, #T_76c1a_row10_col0, #T_76c1a_row10_col1, #T_76c1a_row10_col2, #T_76c1a_row10_col3, #T_76c1a_row10_col4, #T_76c1a_row10_col5, #T_76c1a_row10_col6, #T_76c1a_row10_col7, #T_76c1a_row10_col8, #T_76c1a_row10_col9, #T_76c1a_row10_col10, #T_76c1a_row10_col11, #T_76c1a_row10_col12, #T_76c1a_row10_col13, #T_76c1a_row10_col14, #T_76c1a_row10_col15, #T_76c1a_row10_col16, #T_76c1a_row11_col0, #T_76c1a_row11_col1, #T_76c1a_row11_col2, #T_76c1a_row11_col3, #T_76c1a_row11_col4, #T_76c1a_row11_col5, #T_76c1a_row11_col6, #T_76c1a_row11_col7 ...

# %%
# Sort by match_day using the correct order
df['match_day'] = pd.Categorical(df['match_day'], categories=matchday_order, ordered=True)
df_sorted = df.sort_values('match_day')

# Compute rolling mean for each metric per match day
rolling_avg = (
    df_sorted.groupby('match_day', observed=True)[volume_metrics + intensity_metrics]
    .mean()
    .rolling(window=3, min_periods=1)
    .mean()
    .reset_index()
)

rolling_avg['match_day'] = pd.Categorical(rolling_avg['match_day'], categories=matchday_order, ordered=True)
rolling_avg = rolling_avg.sort_values(by='match_day').round(2)
style_table_for_docs(rolling_avg)
# Out:
# <style type="text/css">
# #T_bd34f th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_bd34f td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_bd34f table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_bd34f_row0_col0, #T_bd34f_row0_col1, #T_bd34f_row0_col2, #T_bd34f_row0_col3, #T_bd34f_row0_col4, #T_bd34f_row0_col5, #T_bd34f_row0_col6, #T_bd34f_row0_col7, #T_bd34f_row0_col8, #T_bd34f_row0_col9, #T_bd34f_row0_col10, #T_bd34f_row0_col11, #T_bd34f_row0_col12, #T_bd34f_row0_col13, #T_bd34f_row0_col14, #T_bd34f_row0_col15, #T_bd34f_row0_col16, #T_bd34f_row1_col0, #T_bd34f_row1_col1, #T_bd34f_row1_col2, #T_bd34f_row1_col3, #T_bd34f_row1_col4, #T_bd34f_row1_col5, #T_bd34f_row1_col6, #T_bd34f_row1_col7, #T_bd34f_row1_col8, #T_bd34f_row1_col9, #T_bd34f_row1_col10, #T_bd34f_row1_col11, #T_bd34f_row1_col12, #T_bd34f_row1_col13, #T_bd34f_row1_col14, #T_bd34f_row1_col15, #T_bd34f_row1_col16, #T_bd34f_row2_col0, #T_bd34f_row2_col1, #T_bd34f_row2_col2, #T_bd34f_row2_col3, #T_bd34f_row2_col4, #T_bd34f_row2_col5, #T_bd34f_row2_col6, #T_bd34f_row2_col7, #T_bd34f_row2_col8, #T_bd34f_row2_col9, #T_bd34f_row2_col10, #T_bd34f_row2_col11, #T_bd34f_row2_col12, #T_bd34f_row2_col13, #T_bd34f_row2_col14, #T_bd34f_row2_col15, #T_bd34f_row2_col16, #T_bd34f_row3_col0, #T_bd34f_row3_col1, #T_bd34f_row3_col2, #T_bd34f_row3_col3, #T_bd34f_row3_col4, #T_bd34f_row3_col5, #T_bd34f_row3_col6, #T_bd34f_row3_col7, #T_bd34f_row3_col8, #T_bd34f_row3_col9, #T_bd34f_row3_col10, #T_bd34f_row3_col11, #T_bd34f_row3_col12, #T_bd34f_row3_col13, #T_bd34f_row3_col14, #T_bd34f_row3_col15, #T_bd34f_row3_col16, #T_bd34f_row4_col0, #T_bd34f_row4_col1, #T_bd34f_row4_col2, #T_bd34f_row4_col3, #T_bd34f_row4_col4, #T_bd34f_row4_col5, #T_bd34f_row4_col6, #T_bd34f_row4_col7, #T_bd34f_row4_col8, #T_bd34f_row4_col9, #T_bd34f_row4_col10, #T_bd34f_row4_col11, #T_bd34f_row4_col12, #T_bd34f_row4_col13, #T_bd34f_row4_col14, #T_bd34f_row4_col15, #T_bd34f_row4_col16, #T_bd34f_row5_col0, #T_bd34f_row5_col1, #T_bd34f_row5_col2, #T_bd34f_row5_col3, #T_bd34f_row5_col4, #T_bd34f_row5_col5, #T_bd34f_row5_col6, #T_bd34f_row5_col7, #T_bd34f_row5_col8, #T_bd34f_row5_col9, #T_bd34f_row5_col10, #T_bd34f_row5_col11, #T_bd34f_row5_col12, #T_bd34f_row5_col13, #T_bd34f_row5_col14, #T_bd34f_row5_col15, #T_bd34f_row5_col16, #T_bd34f_row6_col0, #T_bd34f_row6_col1, #T_bd34f_row6_col2, #T_bd34f_row6_col3, #T_bd34f_row6_col4, #T_bd34f_row6_col5, #T_bd34f_row6_col6, #T_bd34f_row6_col7, #T_bd34f_row6_col8, #T_bd34f_row6_col9, #T_bd34f_row6_col10, #T_bd34f_row6_col11, #T_bd34f_row6_col12, #T_bd34f_row6_col13, #T_bd34f_row6_col14, #T_bd34f_row6_col15, #T_bd34f_row6_col16, #T_bd34f_row7_col0, #T_bd34f_row7_col1, #T_bd34f_row7_col2, #T_bd34f_row7_col3, #T_bd34f_row7_col4, #T_bd34f_row7_col5, #T_bd34f_row7_col6, #T_bd34f_row7_col7, #T_bd34f_row7_col8, #T_bd34f_row7_col9, #T_bd34f_row7_col10, #T_bd34f_row7_col11, #T_bd34f_row7_col12, #T_bd34f_row7_col13, #T_bd34f_row7_col14, #T_bd34f_row7_col15, #T_bd34f_row7_col16, #T_bd34f_row8_col0, #T_bd34f_row8_col1, #T_bd34f_row8_col2, #T_bd34f_row8_col3, #T_bd34f_row8_col4, #T_bd34f_row8_col5, #T_bd34f_row8_col6, #T_bd34f_row8_col7, #T_bd34f_row8_col8, #T_bd34f_row8_col9, #T_bd34f_row8_col10, #T_bd34f_row8_col11, #T_bd34f_row8_col12, #T_bd34f_row8_col13, #T_bd34f_row8_col14, #T_bd34f_row8_col15, #T_bd34f_row8_col16, #T_bd34f_row9_col0, #T_bd34f_row9_col1, #T_bd34f_row9_col2, #T_bd34f_row9_col3, #T_bd34f_row9_col4, #T_bd34f_row9_col5, #T_bd34f_row9_col6, #T_bd34f_row9_col7, #T_bd34f_row9_col8, #T_bd34f_row9_col9, #T_bd34f_row9_col10, #T_bd34f_row9_col11, #T_bd34f_row9_col12, #T_bd34f_row9_col13, #T_bd34f_row9_col14, #T_bd34f_row9_col15, #T_bd34f_row9_col16, #T_bd34f_row10_col0, #T_bd34f_row10_col1, #T_bd34f_row10_col2, #T_bd34f_row10_col3, #T_bd34f_row10_col4, #T_bd34f_row10_col5, #T_bd34f_row10_col6, #T_bd34f_row10_col7, #T_bd34f_row10_col8, #T_bd34f_row10_col9, #T_bd34f_row10_col10, #T_bd34f_row10_col11, #T_bd34f_row10_col12, #T_bd34f_row10_col13, #T_bd34f_row10_col14, #T_bd34f_row10_col15, #T_bd34f_row10_col16, #T_bd34f_row11_col0, #T_bd34f_row11_col1, #T_bd34f_row11_col2, #T_bd34f_row11_col3, #T_bd34f_row11_col4, #T_bd34f_row11_col5, #T_bd34f_row11_col6, #T_bd34f_row11_col7 ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
metrics = [
    ('distance_km', 'Distance (km)'),
    ('sprint_distance_m', 'Sprint Distance (m)'),
    ('player_load', 'Player Load'),
    ('top_speed_kmh', 'Top Speed (km/h)')
]

# Get valid match days (non-NaN)
valid_matchdays = rolling_avg['match_day'].dropna().tolist()
MD11_idx = valid_matchdays.index('MD11') if 'MD11' in valid_matchdays else None
last_idx = len(valid_matchdays) - 1

for ax, (col, label) in zip(axes.flatten(), metrics):
    sns.lineplot(
        data=rolling_avg,
        x='match_day',
        y=col,
        marker='o',
        ax=ax,
        label=f'Average {label}'
    )
    avg_value = rolling_avg[col].mean()
    ax.axhline(avg_value, color='red', linestyle='--', label=f'Season Average: {avg_value:.2f}')
    # Draw vertical line at MD11
    ax.axvline(MD11_idx, color='black', linestyle=':', linewidth=1)
    # Shade area before MD11 (First Round)
    ax.axvspan(-0.5, MD11_idx - 0.5, color='skyblue', alpha=0.35)
    # Shade area from MD11 to last matchday (Second Round)
    ax.axvspan(MD11_idx - 0.5, last_idx + 0.5, color='lightgreen', alpha=0.35)
    xticklabels = [str(Wmd).replace('MD', 'MD ') for Wmd in valid_matchdays]
    ax.set_xticks(range(len(valid_matchdays)))
    ax.set_xticklabels(xticklabels, rotation=90)
    ax.set_title(f'{label} Across Match Days')
    ax.set_xlabel('Match Day')
    ax.set_ylabel(label)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    legend = ax.legend(frameon=False)
    ymin, ymax = ax.get_ylim()
    ax.text(MD11_idx/2, avg_value - (ymax-ymin)*0.12, 'First Round', color='blue', fontsize=12, ha='center', va='top', alpha=0.7)
    ax.text(MD11_idx + (last_idx-MD11_idx)/2, avg_value + (ymax-ymin)*0.08, 'Second Round', color='green', fontsize=12, ha='center', va='bottom', alpha=0.7)

plt.tight_layout(rect=[0, 0.01, 1, 1])
plt.figtext(0.5, 0.01, "Note: All values are from a 3-match rolling average.", ha='center', fontsize=12, style='italic')
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
cols_to_corr = [col for col in num_cols if col != 'duration']
cols_to_corr.extend(['acc_counts_per_min','dec_counts_per_min','total_accelerations','total_decelerations'])
corr = df[cols_to_corr].corr(method='pearson')

# Mapping for pretty axis labels
pretty_labels = {
    'distance_km': 'Distance (km)',
    'sprint_distance_m': 'Sprint Distance (m)',
    'power_plays': 'Power Plays',
    'energy_kcal': 'Energy (kcal)',
    'impacts': 'Impacts',
    'player_load': 'Player Load',
    'top_speed_kmh': 'Top Speed (km/h)',
    'distance_per_min_mmin': 'Distance per Min (m/min)',
    'power_score_wkg': 'Power Score (W/kg)',
    'work_ratio': 'Work Ratio',
    'max_acceleration_mss': 'Max Acceleration (m/s²)',
    'max_deceleration_mss': 'Max Deceleration (m/s²)',
    'acc_counts_per_min':'Acceleration Counts Per Minute',
    'dec_counts_per_min':'Deceleration Counts Per Minute',
    'total_accelerations': 'Total Accelerations',
    'total_decelerations': 'Total Decelerations'
}

# Re-label the correlation matrix
corr = corr.rename(index=pretty_labels, columns=pretty_labels)

mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(8, 6))
sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5,
    mask=mask,
    annot_kws={"fontsize":8, "fontfamily":"serif"}
)
plt.title("Correlation Between Physical Performance Metrics", fontsize=12, fontfamily="serif")
plt.xticks(fontsize=8, fontfamily="serif", fontstyle="italic")
plt.yticks(fontsize=8, fontfamily="serif", fontstyle="italic")
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot 1: All players, no hue
ax1 = axes[0]
sns.scatterplot(data=df, x='distance_km', y='sprint_distance_m', alpha=0.5, ax=ax1)
sns.regplot(data=df, x='distance_km', y='sprint_distance_m', scatter=False, ax=ax1, color='red', line_kws={'linewidth':1})
ax1.set_xlabel('Distance (km)')
ax1.set_ylabel('Sprint Distance (m)')
ax1.set_title('All Players')
ax1.grid(False)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_color('#E0DCDD')
ax1.spines['bottom'].set_color('#E0DCDD')

# Plot 2: Hue by player position, trend lines for each group
ax2 = axes[1]
sns.scatterplot(data=df, x='distance_km', y='sprint_distance_m', hue='general_position', alpha=0.2, ax=ax2)
for pos in df['general_position'].dropna().unique():
    sns.regplot(
        data=df[df['general_position'] == pos],
        x='distance_km',
        y='sprint_distance_m',
        scatter=False,
        ax=ax2,
        label=f"{pos} Trend",
        line_kws={'linewidth':1}
    )
ax2.set_xlabel('Distance (km)')
ax2.set_ylabel('Sprint Distance (m)')
ax2.set_title('By Player Position')
ax2.grid(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_color('#E0DCDD')
ax2.spines['bottom'].set_color('#E0DCDD')
ax2.legend(title='Position')

plt.suptitle('Relationship Between Total Distance and Sprint Distance')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ## Other Requests

# %% [markdown]
# ### Pairwise Performance

# %%
# Calculate and display the average distance covered by players of both teams when they play each other, for all pairs

clubs = sorted(df['club_for'].unique())
single_matchday_metric = []

for i, club1 in enumerate(clubs):
    for club2 in clubs[i+1:]:
        # Find all matchdays where these two clubs played each other
        matchdays = df[
            ((df['club_for'] == club1) & (df['club_against'] == club2)) |
            ((df['club_for'] == club2) & (df['club_against'] == club1))
        ]['match_day'].unique()
        for md in matchdays:
            # Filter for only this pair and this matchday
            mask = (
                (((df['club_for'] == club1) & (df['club_against'] == club2)) |
                 ((df['club_for'] == club2) & (df['club_against'] == club1))) &
                (df['match_day'] == md)
            )
            relevant_rows = df[mask]
            if not relevant_rows.empty:
                avg_metrics = relevant_rows[intensity_metrics+volume_metrics].mean()
                row = {
                    'Team A': club1,
                    'Team B': club2,
                    'match_day': md
                }
                row.update(avg_metrics.to_dict())
                single_matchday_metric.append(row)

single_matchday_metric_df = pd.DataFrame(single_matchday_metric)
single_matchday_metric_df = single_matchday_metric_df[
    (single_matchday_metric_df['top_speed_kmh'] > 20)
][['Team A', 'Team B', 'match_day', 'top_speed_kmh', 'player_load','distance_km']]
single_matchday_metric_df = single_matchday_metric_df[(single_matchday_metric_df['distance_km'] > 8)]
single_matchday_metric_df = single_matchday_metric_df[(single_matchday_metric_df['player_load'] > 300)]
single_matchday_metric_df = single_matchday_metric_df.sort_values(by='player_load', ascending=False).reset_index(drop=True)

style_table_for_docs(single_matchday_metric_df.head(10))
# Out:
# <style type="text/css">
# #T_8fb23 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_8fb23 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_8fb23 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_8fb23_row0_col0, #T_8fb23_row0_col1, #T_8fb23_row0_col2, #T_8fb23_row0_col3, #T_8fb23_row0_col4, #T_8fb23_row0_col5, #T_8fb23_row1_col0, #T_8fb23_row1_col1, #T_8fb23_row1_col2, #T_8fb23_row1_col3, #T_8fb23_row1_col4, #T_8fb23_row1_col5, #T_8fb23_row2_col0, #T_8fb23_row2_col1, #T_8fb23_row2_col2, #T_8fb23_row2_col3, #T_8fb23_row2_col4, #T_8fb23_row2_col5, #T_8fb23_row3_col0, #T_8fb23_row3_col1, #T_8fb23_row3_col2, #T_8fb23_row3_col3, #T_8fb23_row3_col4, #T_8fb23_row3_col5, #T_8fb23_row4_col0, #T_8fb23_row4_col1, #T_8fb23_row4_col2, #T_8fb23_row4_col3, #T_8fb23_row4_col4, #T_8fb23_row4_col5, #T_8fb23_row5_col0, #T_8fb23_row5_col1, #T_8fb23_row5_col2, #T_8fb23_row5_col3, #T_8fb23_row5_col4, #T_8fb23_row5_col5, #T_8fb23_row6_col0, #T_8fb23_row6_col1, #T_8fb23_row6_col2, #T_8fb23_row6_col3, #T_8fb23_row6_col4, #T_8fb23_row6_col5, #T_8fb23_row7_col0, #T_8fb23_row7_col1, #T_8fb23_row7_col2, #T_8fb23_row7_col3, #T_8fb23_row7_col4, #T_8fb23_row7_col5, #T_8fb23_row8_col0, #T_8fb23_row8_col1, #T_8fb23_row8_col2, #T_8fb23_row8_col3, #T_8fb23_row8_col4, #T_8fb23_row8_col5, #T_8fb23_row9_col0, #T_8fb23_row9_col1, #T_8fb23_row9_col2, #T_8fb23_row9_col3, #T_8fb23_row9_col4, #T_8fb23_row9_col5 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_8fb23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fb23_level0_col0" class="col_heading level0 col0" >Team A</th>
#       <th id="T_8fb23_level0_col1" class="col_heading level0 col1" >Team B</th>
#       <th id="T_8fb23_level0_col2" class="col_heading level0 col2" >match_day</th>
#       <th id="T_8fb23_level0_col3" class="col_heading level0 col3" >top_speed_kmh</th>
#       <th id="T_8fb23_level0_col4" class="col_heading level0 col4" >player_load</th>
#       <th id="T_8fb23_level0_col5" class="col_heading level0 col5" >distance_km</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fb23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fb23_row0_col0" class="data row0 col0" >Kampala Queens Fc</td>
#       <td id="T_8fb23_row0_col1" class="data row0 col1" >Rines Ss Wfc</td>
#       <td id="T_8fb23_row0_col2" class="data row0 col2" >MD16</td>
#       <td id="T_8fb23_row0_col3" class="data row0 col3" >27.030969</td>
#       <td id="T_8fb23_row0_col4" class="data row0 col4" >444.700046</td>
#       <td id="T_8fb23_row0_col5" class="data row0 col5" >8.958708</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8fb23_row1_col0" class="data row1 col0" >Kampala Queens Fc</td>
#       <td id="T_8fb23_row1_col1" class="data row1 col1" >Olila Hs Wfc</td>
#       <td id="T_8fb23_row1_col2" class="data row1 col2" >MD8</td>
#       <td id="T_8fb23_row1_col3" class="data row1 col3" >25.963200</td>
#       <td id="T_8fb23_row1_col4" class="data row1 col4" >427.608538</td>
#       <td id="T_8fb23_row1_col5" class="data row1 col5" >9.195050</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8fb23_row2_col0" class="data row2 col0" >Amus College Wfc</td>
#       <td id="T_8fb23_row2_col1" class="data row2 col1" >She Corporates Fc</td>
#       <td id="T_8fb23_row2_col2" class="data row2 col2" >MD10</td>
#       <td id="T_8fb23_row2_col3" class="data row2 col3" >26.104200</td>
#       <td id="T_8fb23_row2_col4" class="data row2 col4" >423.586870</td>
#       <td id="T_8fb23_row2_col5" class="data row2 col5" >8.732210</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8fb23_row3_col0" class="data row3 col0" >Amus College Wfc</td>
#       <td id="T_8fb23_row3_col1" class="data row3 col1" >Makerere University Wfc</td>
#       <td id="T_8fb23_row3_col2" class="data row3 col2" >MD8</td>
#       <td id="T_8fb23_row3_col3" class="data row3 col3" >25.534018</td>
#       <td id="T_8fb23_row3_col4" class="data row3 col4" >418.517227</td>
#       <td id="T_8fb23_row3_col5" class="data row3 col5" >8.391909</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8fb23_row4_col0" class="data row4 col0" >Amus College Wfc</td>
#       <td id="T_8fb23_row4_col1" class="data row4 col1" >Wakiso Hill Wfc</td>
#       <td id="T_8fb23_row4_col2" class="data row4 col2" >MD12</td>
#       <td id="T_8fb23_row4_col3" class="data row4 col3" >26.180927</td>
#       <td id="T_8fb23_row4_col4" class="data row4 col4" >418.385305</td>
#       <td id="T_8fb23_row4_col5" class="data row4 col5" >8.241850</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8fb23_row5_col0" class="data row5 col0" >Olila Hs Wfc</td>
#       <td id="T_8fb23_row5_col1" class="data row5 col1" >She Maroons Fc</td>
#       <td id="T_8fb23_row5_col2" class="data row5 col2" >MD12</td>
#       <td id="T_8fb23_row5_col3" class="data row5 col3" >25.843494</td>
#       <td id="T_8fb23_row5_col4" class="data row5 col4" >415.442500</td>
#       <td id="T_8fb23_row5_col5" class="data row5 col5" >8.888224</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8fb23_row6_col0" class="data row6 col0" >Amus College Wfc</td>
#       <td id="T_8fb23_row6_col1" class="data row6 col1" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_8fb23_row6_col2" class="data row6 col2" >MD7</td>
#       <td id="T_8fb23_row6_col3" class="data row6 col3" >26.387109</td>
#       <td id="T_8fb23_row6_col4" class="data row6 col4" >412.792914</td>
#       <td id="T_8fb23_row6_col5" class="data row6 col5" >8.489127</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8fb23_row7_col0" class="data row7 col0" >Makerere University Wfc</td>
#       <td id="T_8fb23_row7_col1" class="data row7 col1" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_8fb23_row7_col2" class="data row7 col2" >MD22</td>
#       <td id="T_8fb23_row7_col3" class="data row7 col3" >26.079400</td>
#       <td id="T_8fb23_row7_col4" class="data row7 col4" >411.464290</td>
#       <td id="T_8fb23_row7_col5" class="data row7 col5" >8.274180</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8fb23_row8_col0" class="data row8 col0" >Olila Hs Wfc</td>
#       <td id="T_8fb23_row8_col1" class="data row8 col1" >Wakiso Hill Wfc</td>
#       <td id="T_8fb23_row8_col2" class="data row8 col2" >MD11</td>
#       <td id="T_8fb23_row8_col3" class="data row8 col3" >25.481141</td>
#       <td id="T_8fb23_row8_col4" class="data row8 col4" >411.198259</td>
#       <td id="T_8fb23_row8_col5" class="data row8 col5" >8.612788</td>
#     </tr>
#     <tr>
#       <th id="T_8fb23_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8fb23_row9_col0" class="data row9 col0" >Makerere University Wfc</td>
#       <td id="T_8fb23_row9_col1" class="data row9 col1" >Rines Ss Wfc</td>
#       <td id="T_8fb23_row9_col2" class="data row9 col2" >MD18</td>
#       <td id="T_8fb23_row9_col3" class="data row9 col3" >25.413847</td>
#       <td id="T_8fb23_row9_col4" class="data row9 col4" >404.534300</td>
#       <td id="T_8fb23_row9_col5" class="data row9 col5" >8.320912</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate and display the average distance covered by players of both teams when they play each other, for all pairs

clubs = sorted(df['club_for'].unique())
single_matchday_metric = []

for i, club1 in enumerate(clubs):
    for club2 in clubs[i+1:]:
        # Find all matchdays where these two clubs played each other
        matchdays = df[
            ((df['club_for'] == club1) & (df['club_against'] == club2)) |
            ((df['club_for'] == club2) & (df['club_against'] == club1))
        ]['match_day'].unique()
        for md in matchdays:
            # Filter for only this pair and this matchday
            mask = (
                (((df['club_for'] == club1) & (df['club_against'] == club2)) |
                 ((df['club_for'] == club2) & (df['club_against'] == club1))) &
                (df['match_day'] == md)
            )
            relevant_rows = df[mask]
            if not relevant_rows.empty:
                avg_metrics = relevant_rows[intensity_metrics+volume_metrics].mean()
                row = {
                    'Team A': club1,
                    'Team B': club2,
                    'match_day': md
                }
                row.update(avg_metrics.to_dict())
                single_matchday_metric.append(row)

single_matchday_metric_df = pd.DataFrame(single_matchday_metric)
single_matchday_metric_df = single_matchday_metric_df[
    (single_matchday_metric_df['top_speed_kmh'] > 0)
][['Team A', 'Team B', 'match_day', 'top_speed_kmh', 'player_load','distance_km']]
single_matchday_metric_df = single_matchday_metric_df[(single_matchday_metric_df['distance_km'] < 9)]
single_matchday_metric_df = single_matchday_metric_df[(single_matchday_metric_df['player_load'] < 400)]
single_matchday_metric_df = single_matchday_metric_df.sort_values(by='distance_km', ascending=True).reset_index(drop=True)

style_table_for_docs(single_matchday_metric_df.head(10))
# Out:
# <style type="text/css">
# #T_ab48c th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_ab48c td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_ab48c table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_ab48c_row0_col0, #T_ab48c_row0_col1, #T_ab48c_row0_col2, #T_ab48c_row0_col3, #T_ab48c_row0_col4, #T_ab48c_row0_col5, #T_ab48c_row1_col0, #T_ab48c_row1_col1, #T_ab48c_row1_col2, #T_ab48c_row1_col3, #T_ab48c_row1_col4, #T_ab48c_row1_col5, #T_ab48c_row2_col0, #T_ab48c_row2_col1, #T_ab48c_row2_col2, #T_ab48c_row2_col3, #T_ab48c_row2_col4, #T_ab48c_row2_col5, #T_ab48c_row3_col0, #T_ab48c_row3_col1, #T_ab48c_row3_col2, #T_ab48c_row3_col3, #T_ab48c_row3_col4, #T_ab48c_row3_col5, #T_ab48c_row4_col0, #T_ab48c_row4_col1, #T_ab48c_row4_col2, #T_ab48c_row4_col3, #T_ab48c_row4_col4, #T_ab48c_row4_col5, #T_ab48c_row5_col0, #T_ab48c_row5_col1, #T_ab48c_row5_col2, #T_ab48c_row5_col3, #T_ab48c_row5_col4, #T_ab48c_row5_col5, #T_ab48c_row6_col0, #T_ab48c_row6_col1, #T_ab48c_row6_col2, #T_ab48c_row6_col3, #T_ab48c_row6_col4, #T_ab48c_row6_col5, #T_ab48c_row7_col0, #T_ab48c_row7_col1, #T_ab48c_row7_col2, #T_ab48c_row7_col3, #T_ab48c_row7_col4, #T_ab48c_row7_col5, #T_ab48c_row8_col0, #T_ab48c_row8_col1, #T_ab48c_row8_col2, #T_ab48c_row8_col3, #T_ab48c_row8_col4, #T_ab48c_row8_col5, #T_ab48c_row9_col0, #T_ab48c_row9_col1, #T_ab48c_row9_col2, #T_ab48c_row9_col3, #T_ab48c_row9_col4, #T_ab48c_row9_col5 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_ab48c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab48c_level0_col0" class="col_heading level0 col0" >Team A</th>
#       <th id="T_ab48c_level0_col1" class="col_heading level0 col1" >Team B</th>
#       <th id="T_ab48c_level0_col2" class="col_heading level0 col2" >match_day</th>
#       <th id="T_ab48c_level0_col3" class="col_heading level0 col3" >top_speed_kmh</th>
#       <th id="T_ab48c_level0_col4" class="col_heading level0 col4" >player_load</th>
#       <th id="T_ab48c_level0_col5" class="col_heading level0 col5" >distance_km</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab48c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab48c_row0_col0" class="data row0 col0" >She Corporates Fc</td>
#       <td id="T_ab48c_row0_col1" class="data row0 col1" >She Maroons Fc</td>
#       <td id="T_ab48c_row0_col2" class="data row0 col2" >MD6</td>
#       <td id="T_ab48c_row0_col3" class="data row0 col3" >25.959127</td>
#       <td id="T_ab48c_row0_col4" class="data row0 col4" >274.452033</td>
#       <td id="T_ab48c_row0_col5" class="data row0 col5" >5.578953</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ab48c_row1_col0" class="data row1 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_ab48c_row1_col1" class="data row1 col1" >She Corporates Fc</td>
#       <td id="T_ab48c_row1_col2" class="data row1 col2" >MD22</td>
#       <td id="T_ab48c_row1_col3" class="data row1 col3" >26.170046</td>
#       <td id="T_ab48c_row1_col4" class="data row1 col4" >271.764177</td>
#       <td id="T_ab48c_row1_col5" class="data row1 col5" >5.817169</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ab48c_row2_col0" class="data row2 col0" >She Maroons Fc</td>
#       <td id="T_ab48c_row2_col1" class="data row2 col1" >Wakiso Hill Wfc</td>
#       <td id="T_ab48c_row2_col2" class="data row2 col2" >MD18</td>
#       <td id="T_ab48c_row2_col3" class="data row2 col3" >25.259109</td>
#       <td id="T_ab48c_row2_col4" class="data row2 col4" >336.385818</td>
#       <td id="T_ab48c_row2_col5" class="data row2 col5" >5.867764</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ab48c_row3_col0" class="data row3 col0" >Rines Ss Wfc</td>
#       <td id="T_ab48c_row3_col1" class="data row3 col1" >She Maroons Fc</td>
#       <td id="T_ab48c_row3_col2" class="data row3 col2" >MD19</td>
#       <td id="T_ab48c_row3_col3" class="data row3 col3" >26.171277</td>
#       <td id="T_ab48c_row3_col4" class="data row3 col4" >296.060931</td>
#       <td id="T_ab48c_row3_col5" class="data row3 col5" >6.092869</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ab48c_row4_col0" class="data row4 col0" >She Corporates Fc</td>
#       <td id="T_ab48c_row4_col1" class="data row4 col1" >She Maroons Fc</td>
#       <td id="T_ab48c_row4_col2" class="data row4 col2" >MD17</td>
#       <td id="T_ab48c_row4_col3" class="data row4 col3" >24.938662</td>
#       <td id="T_ab48c_row4_col4" class="data row4 col4" >293.460292</td>
#       <td id="T_ab48c_row4_col5" class="data row4 col5" >6.095869</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ab48c_row5_col0" class="data row5 col0" >Rines Ss Wfc</td>
#       <td id="T_ab48c_row5_col1" class="data row5 col1" >She Maroons Fc</td>
#       <td id="T_ab48c_row5_col2" class="data row5 col2" >MD8</td>
#       <td id="T_ab48c_row5_col3" class="data row5 col3" >24.765152</td>
#       <td id="T_ab48c_row5_col4" class="data row5 col4" >312.910986</td>
#       <td id="T_ab48c_row5_col5" class="data row5 col5" >6.278890</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ab48c_row6_col0" class="data row6 col0" >Kawempe Muslim Lfc</td>
#       <td id="T_ab48c_row6_col1" class="data row6 col1" >Wakiso Hill Wfc</td>
#       <td id="T_ab48c_row6_col2" class="data row6 col2" >MD2</td>
#       <td id="T_ab48c_row6_col3" class="data row6 col3" >24.823585</td>
#       <td id="T_ab48c_row6_col4" class="data row6 col4" >341.490669</td>
#       <td id="T_ab48c_row6_col5" class="data row6 col5" >6.304523</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ab48c_row7_col0" class="data row7 col0" >Amus College Wfc</td>
#       <td id="T_ab48c_row7_col1" class="data row7 col1" >Lady Doves Fc</td>
#       <td id="T_ab48c_row7_col2" class="data row7 col2" >MD2</td>
#       <td id="T_ab48c_row7_col3" class="data row7 col3" >23.875400</td>
#       <td id="T_ab48c_row7_col4" class="data row7 col4" >328.484500</td>
#       <td id="T_ab48c_row7_col5" class="data row7 col5" >6.425540</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ab48c_row8_col0" class="data row8 col0" >Kampala Queens Fc</td>
#       <td id="T_ab48c_row8_col1" class="data row8 col1" >Wakiso Hill Wfc</td>
#       <td id="T_ab48c_row8_col2" class="data row8 col2" >MD1</td>
#       <td id="T_ab48c_row8_col3" class="data row8 col3" >24.906760</td>
#       <td id="T_ab48c_row8_col4" class="data row8 col4" >341.887644</td>
#       <td id="T_ab48c_row8_col5" class="data row8 col5" >6.599260</td>
#     </tr>
#     <tr>
#       <th id="T_ab48c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ab48c_row9_col0" class="data row9 col0" >Lady Doves Fc</td>
#       <td id="T_ab48c_row9_col1" class="data row9 col1" >She Maroons Fc</td>
#       <td id="T_ab48c_row9_col2" class="data row9 col2" >MD21</td>
#       <td id="T_ab48c_row9_col3" class="data row9 col3" >26.456771</td>
#       <td id="T_ab48c_row9_col4" class="data row9 col4" >320.427700</td>
#       <td id="T_ab48c_row9_col5" class="data row9 col5" >6.626550</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a DataFrame showing the averages of all intensity metrics for each team A when they play team B
clubs = sorted(df['club_for'].unique())
avg_intensity_vs_opponent = []

for club1 in clubs:
    for club2 in clubs:
        if club1 == club2:
            continue  # skip self
        mask = (
            ((df['club_for'] == club1) & (df['club_against'] == club2))
        )
        club1_rows = df[mask]
        if not club1_rows.empty:
            avg_metrics = club1_rows[intensity_metrics].mean()
            row = {'Team A': club1, 'Team B': club2}
            row.update(avg_metrics.to_dict())
            avg_intensity_vs_opponent.append(row)

avg_intensity_vs_opponent_df = pd.DataFrame(avg_intensity_vs_opponent)
avg_intensity_vs_opponent_df = avg_intensity_vs_opponent_df.sort_values(by='top_speed_kmh', ascending=False).reset_index(drop=True)
style_table_for_docs(avg_intensity_vs_opponent_df.head(10))
# Out:
# <style type="text/css">
# #T_12a42 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_12a42 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_12a42 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_12a42_row0_col0, #T_12a42_row0_col1, #T_12a42_row0_col2, #T_12a42_row0_col3, #T_12a42_row0_col4, #T_12a42_row0_col5, #T_12a42_row0_col6, #T_12a42_row0_col7, #T_12a42_row0_col8, #T_12a42_row0_col9, #T_12a42_row0_col10, #T_12a42_row1_col0, #T_12a42_row1_col1, #T_12a42_row1_col2, #T_12a42_row1_col3, #T_12a42_row1_col4, #T_12a42_row1_col5, #T_12a42_row1_col6, #T_12a42_row1_col7, #T_12a42_row1_col8, #T_12a42_row1_col9, #T_12a42_row1_col10, #T_12a42_row2_col0, #T_12a42_row2_col1, #T_12a42_row2_col2, #T_12a42_row2_col3, #T_12a42_row2_col4, #T_12a42_row2_col5, #T_12a42_row2_col6, #T_12a42_row2_col7, #T_12a42_row2_col8, #T_12a42_row2_col9, #T_12a42_row2_col10, #T_12a42_row3_col0, #T_12a42_row3_col1, #T_12a42_row3_col2, #T_12a42_row3_col3, #T_12a42_row3_col4, #T_12a42_row3_col5, #T_12a42_row3_col6, #T_12a42_row3_col7, #T_12a42_row3_col8, #T_12a42_row3_col9, #T_12a42_row3_col10, #T_12a42_row4_col0, #T_12a42_row4_col1, #T_12a42_row4_col2, #T_12a42_row4_col3, #T_12a42_row4_col4, #T_12a42_row4_col5, #T_12a42_row4_col6, #T_12a42_row4_col7, #T_12a42_row4_col8, #T_12a42_row4_col9, #T_12a42_row4_col10, #T_12a42_row5_col0, #T_12a42_row5_col1, #T_12a42_row5_col2, #T_12a42_row5_col3, #T_12a42_row5_col4, #T_12a42_row5_col5, #T_12a42_row5_col6, #T_12a42_row5_col7, #T_12a42_row5_col8, #T_12a42_row5_col9, #T_12a42_row5_col10, #T_12a42_row6_col0, #T_12a42_row6_col1, #T_12a42_row6_col2, #T_12a42_row6_col3, #T_12a42_row6_col4, #T_12a42_row6_col5, #T_12a42_row6_col6, #T_12a42_row6_col7, #T_12a42_row6_col8, #T_12a42_row6_col9, #T_12a42_row6_col10, #T_12a42_row7_col0, #T_12a42_row7_col1, #T_12a42_row7_col2, #T_12a42_row7_col3, #T_12a42_row7_col4, #T_12a42_row7_col5, #T_12a42_row7_col6, #T_12a42_row7_col7, #T_12a42_row7_col8, #T_12a42_row7_col9, #T_12a42_row7_col10, #T_12a42_row8_col0, #T_12a42_row8_col1, #T_12a42_row8_col2, #T_12a42_row8_col3, #T_12a42_row8_col4, #T_12a42_row8_col5, #T_12a42_row8_col6, #T_12a42_row8_col7, #T_12a42_row8_col8, #T_12a42_row8_col9, #T_12a42_row8_col10, #T_12a42_row9_col0, #T_12a42_row9_col1, #T_12a42_row9_col2, #T_12a42_row9_col3, #T_12a42_row9_col4, #T_12a42_row9_col5, #T_12a42_row9_col6, #T_12a42_row9_col7, #T_12a42_row9_col8, #T_12a42_row9_col9, #T_12a42_row9_col10 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_12a42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12a42_level0_col0" class="col_heading level0 col0" >Team A</th>
#       <th id="T_12a42_level0_col1" class="col_heading level0 col1" >Team B</th>
#       <th id="T_12a42_level0_col2" class="col_heading level0 col2" >player_load</th>
#       <th id="T_12a42_level0_col3" class="col_heading level0 col3" >top_speed_kmh</th>
#       <th id="T_12a42_level0_col4" class="col_heading level0 col4" >distance_per_min_mmin</th>
#       <th id="T_12a42_level0_col5" class="col_heading level0 col5" >power_score_wkg</th>
#       <th id="T_12a42_level0_col6" class="col_heading level0 col6" >work_ratio</th>
#       <th id="T_12a42_level0_col7" class="col_heading level0 col7" >max_acceleration_mss</th>
#       <th id="T_12a42_level0_col8" class="col_heading level0 col8" >max_deceleration_mss</th>
#       <th id="T_12a42_level0_col9" class="col_heading level0 col9" >acc_counts_per_min</th>
#       <th id="T_12a42_level0_col10" class="col_heading level0 col10" >dec_counts_per_min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12a42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12a42_row0_col0" class="data row0 col0" >Kampala Queens Fc</td>
#       <td id="T_12a42_row0_col1" class="data row0 col1" >Amus College Wfc</td>
#       <td id="T_12a42_row0_col2" class="data row0 col2" >415.512030</td>
#       <td id="T_12a42_row0_col3" class="data row0 col3" >27.742610</td>
#       <td id="T_12a42_row0_col4" class="data row0 col4" >85.613032</td>
#       <td id="T_12a42_row0_col5" class="data row0 col5" >13.109120</td>
#       <td id="T_12a42_row0_col6" class="data row0 col6" >67.084010</td>
#       <td id="T_12a42_row0_col7" class="data row0 col7" >5.369040</td>
#       <td id="T_12a42_row0_col8" class="data row0 col8" >6.704800</td>
#       <td id="T_12a42_row0_col9" class="data row0 col9" >3.797518</td>
#       <td id="T_12a42_row0_col10" class="data row0 col10" >3.700710</td>
#     </tr>
#     <tr>
#       <th id="T_12a42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12a42_row1_col0" class="data row1 col0" >Olila Hs Wfc</td>
#       <td id="T_12a42_row1_col1" class="data row1 col1" >Amus College Wfc</td>
#       <td id="T_12a42_row1_col2" class="data row1 col2" >365.784020</td>
#       <td id="T_12a42_row1_col3" class="data row1 col3" >27.577800</td>
#       <td id="T_12a42_row1_col4" class="data row1 col4" >86.598609</td>
#       <td id="T_12a42_row1_col5" class="data row1 col5" >13.277020</td>
#       <td id="T_12a42_row1_col6" class="data row1 col6" >68.818760</td>
#       <td id="T_12a42_row1_col7" class="data row1 col7" >4.990500</td>
#       <td id="T_12a42_row1_col8" class="data row1 col8" >6.525400</td>
#       <td id="T_12a42_row1_col9" class="data row1 col9" >3.451246</td>
#       <td id="T_12a42_row1_col10" class="data row1 col10" >3.268102</td>
#     </tr>
#     <tr>
#       <th id="T_12a42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12a42_row2_col0" class="data row2 col0" >Lady Doves Fc</td>
#       <td id="T_12a42_row2_col1" class="data row2 col1" >Kawempe Muslim Lfc</td>
#       <td id="T_12a42_row2_col2" class="data row2 col2" >421.761333</td>
#       <td id="T_12a42_row2_col3" class="data row2 col3" >27.253533</td>
#       <td id="T_12a42_row2_col4" class="data row2 col4" >86.255845</td>
#       <td id="T_12a42_row2_col5" class="data row2 col5" >13.408667</td>
#       <td id="T_12a42_row2_col6" class="data row2 col6" >65.194533</td>
#       <td id="T_12a42_row2_col7" class="data row2 col7" >5.479467</td>
#       <td id="T_12a42_row2_col8" class="data row2 col8" >7.408683</td>
#       <td id="T_12a42_row2_col9" class="data row2 col9" >3.653323</td>
#       <td id="T_12a42_row2_col10" class="data row2 col10" >3.681110</td>
#     </tr>
#     <tr>
#       <th id="T_12a42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12a42_row3_col0" class="data row3 col0" >Amus College Wfc</td>
#       <td id="T_12a42_row3_col1" class="data row3 col1" >Uganda Martyrs Lubaga Wfc</td>
#       <td id="T_12a42_row3_col2" class="data row3 col2" >409.786018</td>
#       <td id="T_12a42_row3_col3" class="data row3 col3" >27.151473</td>
#       <td id="T_12a42_row3_col4" class="data row3 col4" >78.968276</td>
#       <td id="T_12a42_row3_col5" class="data row3 col5" >12.371882</td>
#       <td id="T_12a42_row3_col6" class="data row3 col6" >64.720173</td>
#       <td id="T_12a42_row3_col7" class="data row3 col7" >5.395100</td>
#       <td id="T_12a42_row3_col8" class="data row3 col8" >7.282218</td>
#       <td id="T_12a42_row3_col9" class="data row3 col9" >3.684974</td>
#       <td id="T_12a42_row3_col10" class="data row3 col10" >3.503326</td>
#     </tr>
#     <tr>
#       <th id="T_12a42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12a42_row4_col0" class="data row4 col0" >Lady Doves Fc</td>
#       <td id="T_12a42_row4_col1" class="data row4 col1" >Kampala Queens Fc</td>
#       <td id="T_12a42_row4_col2" class="data row4 col2" >389.544592</td>
#       <td id="T_12a42_row4_col3" class="data row4 col3" >26.913533</td>
#       <td id="T_12a42_row4_col4" class="data row4 col4" >80.042286</td>
#       <td id="T_12a42_row4_col5" class="data row4 col5" >12.052783</td>
#       <td id="T_12a42_row4_col6" class="data row4 col6" >60.053217</td>
#       <td id="T_12a42_row4_col7" class="data row4 col7" >5.453717</td>
#       <td id="T_12a42_row4_col8" class="data row4 col8" >6.

# %%
# Create a DataFrame showing the averages of all volume metrics for each team A when they play team B
clubs = sorted(df['club_for'].unique())
avg_volume_vs_opponent = []

for club1 in clubs:
    for club2 in clubs:
        if club1 == club2:
            continue  # skip self
        mask = (
            ((df['club_for'] == club1) & (df['club_against'] == club2))
        )
        club1_rows = df[mask]
        if not club1_rows.empty:
            avg_metrics = club1_rows[volume_metrics].mean()
            row = {'Team A': club1, 'Team B': club2}
            row.update(avg_metrics.to_dict())
            avg_volume_vs_opponent.append(row)

avg_volume_vs_opponent_df = pd.DataFrame(avg_volume_vs_opponent)
avg_volume_vs_opponent_df = avg_volume_vs_opponent_df.sort_values(by='distance_km', ascending=False).reset_index(drop=True)
style_table_for_docs(avg_volume_vs_opponent_df.head(10))
# Out:
# <style type="text/css">
# #T_a1ab4 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a1ab4 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a1ab4 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_a1ab4_row0_col0, #T_a1ab4_row0_col1, #T_a1ab4_row0_col2, #T_a1ab4_row0_col3, #T_a1ab4_row0_col4, #T_a1ab4_row0_col5, #T_a1ab4_row0_col6, #T_a1ab4_row0_col7, #T_a1ab4_row0_col8, #T_a1ab4_row1_col0, #T_a1ab4_row1_col1, #T_a1ab4_row1_col2, #T_a1ab4_row1_col3, #T_a1ab4_row1_col4, #T_a1ab4_row1_col5, #T_a1ab4_row1_col6, #T_a1ab4_row1_col7, #T_a1ab4_row1_col8, #T_a1ab4_row2_col0, #T_a1ab4_row2_col1, #T_a1ab4_row2_col2, #T_a1ab4_row2_col3, #T_a1ab4_row2_col4, #T_a1ab4_row2_col5, #T_a1ab4_row2_col6, #T_a1ab4_row2_col7, #T_a1ab4_row2_col8, #T_a1ab4_row3_col0, #T_a1ab4_row3_col1, #T_a1ab4_row3_col2, #T_a1ab4_row3_col3, #T_a1ab4_row3_col4, #T_a1ab4_row3_col5, #T_a1ab4_row3_col6, #T_a1ab4_row3_col7, #T_a1ab4_row3_col8, #T_a1ab4_row4_col0, #T_a1ab4_row4_col1, #T_a1ab4_row4_col2, #T_a1ab4_row4_col3, #T_a1ab4_row4_col4, #T_a1ab4_row4_col5, #T_a1ab4_row4_col6, #T_a1ab4_row4_col7, #T_a1ab4_row4_col8, #T_a1ab4_row5_col0, #T_a1ab4_row5_col1, #T_a1ab4_row5_col2, #T_a1ab4_row5_col3, #T_a1ab4_row5_col4, #T_a1ab4_row5_col5, #T_a1ab4_row5_col6, #T_a1ab4_row5_col7, #T_a1ab4_row5_col8, #T_a1ab4_row6_col0, #T_a1ab4_row6_col1, #T_a1ab4_row6_col2, #T_a1ab4_row6_col3, #T_a1ab4_row6_col4, #T_a1ab4_row6_col5, #T_a1ab4_row6_col6, #T_a1ab4_row6_col7, #T_a1ab4_row6_col8, #T_a1ab4_row7_col0, #T_a1ab4_row7_col1, #T_a1ab4_row7_col2, #T_a1ab4_row7_col3, #T_a1ab4_row7_col4, #T_a1ab4_row7_col5, #T_a1ab4_row7_col6, #T_a1ab4_row7_col7, #T_a1ab4_row7_col8, #T_a1ab4_row8_col0, #T_a1ab4_row8_col1, #T_a1ab4_row8_col2, #T_a1ab4_row8_col3, #T_a1ab4_row8_col4, #T_a1ab4_row8_col5, #T_a1ab4_row8_col6, #T_a1ab4_row8_col7, #T_a1ab4_row8_col8, #T_a1ab4_row9_col0, #T_a1ab4_row9_col1, #T_a1ab4_row9_col2, #T_a1ab4_row9_col3, #T_a1ab4_row9_col4, #T_a1ab4_row9_col5, #T_a1ab4_row9_col6, #T_a1ab4_row9_col7, #T_a1ab4_row9_col8 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_a1ab4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1ab4_level0_col0" class="col_heading level0 col0" >Team A</th>
#       <th id="T_a1ab4_level0_col1" class="col_heading level0 col1" >Team B</th>
#       <th id="T_a1ab4_level0_col2" class="col_heading level0 col2" >distance_km</th>
#       <th id="T_a1ab4_level0_col3" class="col_heading level0 col3" >sprint_distance_m</th>
#       <th id="T_a1ab4_level0_col4" class="col_heading level0 col4" >power_plays</th>
#       <th id="T_a1ab4_level0_col5" class="col_heading level0 col5" >energy_kcal</th>
#       <th id="T_a1ab4_level0_col6" class="col_heading level0 col6" >impacts</th>
#       <th id="T_a1ab4_level0_col7" class="col_heading level0 col7" >total_accelerations</th>
#       <th id="T_a1ab4_level0_col8" class="col_heading level0 col8" >total_decelerations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1ab4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1ab4_row0_col0" class="data row0 col0" >Olila Hs Wfc</td>
#       <td id="T_a1ab4_row0_col1" class="data row0 col1" >Kampala Queens Fc</td>
#       <td id="T_a1ab4_row0_col2" class="data row0 col2" >9.195050</td>
#       <td id="T_a1ab4_row0_col3" class="data row0 col3" >549.515250</td>
#       <td id="T_a1ab4_row0_col4" class="data row0 col4" >49.625000</td>
#       <td id="T_a1ab4_row0_col5" class="data row0 col5" >880.174487</td>
#       <td id="T_a1ab4_row0_col6" class="data row0 col6" >4.750000</td>
#       <td id="T_a1ab4_row0_col7" class="data row0 col7" >470.125000</td>
#       <td id="T_a1ab4_row0_col8" class="data row0 col8" >452.250000</td>
#     </tr>
#     <tr>
#       <th id="T_a1ab4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1ab4_row1_col0" class="data row1 col0" >Olila Hs Wfc</td>
#       <td id="T_a1ab4_row1_col1" class="data row1 col1" >She Maroons Fc</td>
#       <td id="T_a1ab4_row1_col2" class="data row1 col2" >9.084929</td>
#       <td id="T_a1ab4_row1_col3" class="data row1 col3" >580.320143</td>
#       <td id="T_a1ab4_row1_col4" class="data row1 col4" >51.142857</td>
#       <td id="T_a1ab4_row1_col5" class="data row1 col5" >923.210871</td>
#       <td id="T_a1ab4_row1_col6" class="data row1 col6" >2.000000</td>
#       <td id="T_a1ab4_row1_col7" class="data row1 col7" >420.428571</td>
#       <td id="T_a1ab4_row1_col8" class="data row1 col8" >401.857143</td>
#     </tr>
#     <tr>
#       <th id="T_a1ab4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1ab4_row2_col0" class="data row2 col0" >Kampala Queens Fc</td>
#       <td id="T_a1ab4_row2_col1" class="data row2 col1" >Rines Ss Wfc</td>
#       <td id="T_a1ab4_row2_col2" class="data row2 col2" >8.939480</td>
#       <td id="T_a1ab4_row2_col3" class="data row2 col3" >492.476200</td>
#       <td id="T_a1ab4_row2_col4" class="data row2 col4" >48.400000</td>
#       <td id="T_a1ab4_row2_col5" class="data row2 col5" >891.730320</td>
#       <td id="T_a1ab4_row2_col6" class="data row2 col6" >5.000000</td>
#       <td id="T_a1ab4_row2_col7" class="data row2 col7" >455.000000</td>
#       <td id="T_a1ab4_row2_col8" class="data row2 col8" >444.400000</td>
#     </tr>
#     <tr>
#       <th id="T_a1ab4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1ab4_row3_col0" class="data row3 col0" >Lady Doves Fc</td>
#       <td id="T_a1ab4_row3_col1" class="data row3 col1" >Wakiso Hill Wfc</td>
#       <td id="T_a1ab4_row3_col2" class="data row3 col2" >8.901257</td>
#       <td id="T_a1ab4_row3_col3" class="data row3 col3" >598.118714</td>
#       <td id="T_a1ab4_row3_col4" class="data row3 col4" >46.571429</td>
#       <td id="T_a1ab4_row3_col5" class="data row3 col5" >806.509214</td>
#       <td id="T_a1ab4_row3_col6" class="data row3 col6" >8.142857</td>
#       <td id="T_a1ab4_row3_col7" class="data row3 col7" >363.000000</td>
#       <td id="T_a1ab4_row3_col8" class="data row3 col8" >363.857143</td>
#     </tr>
#     <tr>
#       <th id="T_a1ab4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1ab4_row4_col0" class="data row4 col0" >Amus College Wfc</td>
#       <td id="T_a1ab4_row4_col1" class="data row4 col1" >She Maroons Fc</td>
#       <td id="T_a1ab4_row4_col2" class="data row4 col2" >8.816042</td>
#       <td id="T_a1ab4_row4_col3" class="data row4 col3" >632.711684</td>
#       <td id="T_a1ab4_row4_col4" class="data row4 col4" >52.631579</td>
#       <td id="T_a1ab4_row4_col5" class="data row4 col5" >867.006989</td>
#       <td id="T_a1ab4_row4_col6" class="data row4 col6" >7.684211</td>
#       <td id="T_a1ab4_row4_col7" class="data row4 col7" >385.842105</td>
#       <td id="T_a1ab4_row4_col8" class="data row4 col8" >375.421053</td>
#     </tr>
#     <tr>
#       <th id="T_a1ab4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1ab4_row5_col0" class="data row5 col0" >Lady Doves Fc</td>
#       <td id="T_a1ab4_row5_col1" class="data row5 col1" >Kawempe Muslim Lfc</td>
#       <td id="T_a1ab4_row5_col2" class="data row5 col2" >8.773567</td>
#       <td id="T_a1ab4_row5_col3" class="data row5 col3" >667.829833</td>
#       <td id="T_a1ab4_row5_col4" class="data row5 col4" >51.166667</td>
#       <td id="T_a1ab4_row5_col5" class="data row5 col5" >792.127517</td>
#       <td id="T_a1ab4_row5_col6" class="data row5 col6" >8.500000</td>
#       <td id="T_a1ab4_row5_col7" class="data row5 col7" >371.666667</td>
#       <td id="T_a1ab4_row5_col8" class="data row5 col8" >374.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a1ab4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1ab4_row6_col0" class="data row6 col0" >Amus College Wfc</td>
#       <td id="T_a1ab4_row6_col1" class="data row6 col1" >She Corporates Fc</td>
#       <td id="T_a1ab4_row6_col2" class="data row6 col2" >8.732210</td>
#       <td id="T_a1ab4_row6_col3" class="data row6 col3" >504.489400</td>
#       <td id="T_a1ab4_row6_

# %% [markdown]
# ### Top Performers for each Metric (Individual/ Team/ Pairwise)

# %%
# Find top 5 players for each metric in volume_metrics and intensity_metrics
top5_players = []

metrics_to_check = volume_metrics + intensity_metrics
for metric in metrics_to_check:
    # Get top 5 rows for this metric
    top_rows = df.nlargest(5, metric)
    for _, row in top_rows.iterrows():
        top5_players.append({
            'metric': metric,
            'player': row['p_name'],
            'club': row['club_for'],
            'value': row[metric],
            'match day': row['match_day']
        })

top5_players_df = pd.DataFrame(top5_players)
# Optionally, sort for display
top5_players_df = top5_players_df.sort_values(['metric', 'value'], ascending=[True, False]).reset_index(drop=True)
style_table_for_docs(top5_players_df)
# Out:
# <style type="text/css">
# #T_3c518 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3c518 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3c518 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3c518_row0_col0, #T_3c518_row0_col1, #T_3c518_row0_col2, #T_3c518_row0_col3, #T_3c518_row0_col4, #T_3c518_row1_col0, #T_3c518_row1_col1, #T_3c518_row1_col2, #T_3c518_row1_col3, #T_3c518_row1_col4, #T_3c518_row2_col0, #T_3c518_row2_col1, #T_3c518_row2_col2, #T_3c518_row2_col3, #T_3c518_row2_col4, #T_3c518_row3_col0, #T_3c518_row3_col1, #T_3c518_row3_col2, #T_3c518_row3_col3, #T_3c518_row3_col4, #T_3c518_row4_col0, #T_3c518_row4_col1, #T_3c518_row4_col2, #T_3c518_row4_col3, #T_3c518_row4_col4, #T_3c518_row5_col0, #T_3c518_row5_col1, #T_3c518_row5_col2, #T_3c518_row5_col3, #T_3c518_row5_col4, #T_3c518_row6_col0, #T_3c518_row6_col1, #T_3c518_row6_col2, #T_3c518_row6_col3, #T_3c518_row6_col4, #T_3c518_row7_col0, #T_3c518_row7_col1, #T_3c518_row7_col2, #T_3c518_row7_col3, #T_3c518_row7_col4, #T_3c518_row8_col0, #T_3c518_row8_col1, #T_3c518_row8_col2, #T_3c518_row8_col3, #T_3c518_row8_col4, #T_3c518_row9_col0, #T_3c518_row9_col1, #T_3c518_row9_col2, #T_3c518_row9_col3, #T_3c518_row9_col4, #T_3c518_row10_col0, #T_3c518_row10_col1, #T_3c518_row10_col2, #T_3c518_row10_col3, #T_3c518_row10_col4, #T_3c518_row11_col0, #T_3c518_row11_col1, #T_3c518_row11_col2, #T_3c518_row11_col3, #T_3c518_row11_col4, #T_3c518_row12_col0, #T_3c518_row12_col1, #T_3c518_row12_col2, #T_3c518_row12_col3, #T_3c518_row12_col4, #T_3c518_row13_col0, #T_3c518_row13_col1, #T_3c518_row13_col2, #T_3c518_row13_col3, #T_3c518_row13_col4, #T_3c518_row14_col0, #T_3c518_row14_col1, #T_3c518_row14_col2, #T_3c518_row14_col3, #T_3c518_row14_col4, #T_3c518_row15_col0, #T_3c518_row15_col1, #T_3c518_row15_col2, #T_3c518_row15_col3, #T_3c518_row15_col4, #T_3c518_row16_col0, #T_3c518_row16_col1, #T_3c518_row16_col2, #T_3c518_row16_col3, #T_3c518_row16_col4, #T_3c518_row17_col0, #T_3c518_row17_col1, #T_3c518_row17_col2, #T_3c518_row17_col3, #T_3c518_row17_col4, #T_3c518_row18_col0, #T_3c518_row18_col1, #T_3c518_row18_col2, #T_3c518_row18_col3, #T_3c518_row18_col4, #T_3c518_row19_col0, #T_3c518_row19_col1, #T_3c518_row19_col2, #T_3c518_row19_col3, #T_3c518_row19_col4, #T_3c518_row20_col0, #T_3c518_row20_col1, #T_3c518_row20_col2, #T_3c518_row20_col3, #T_3c518_row20_col4, #T_3c518_row21_col0, #T_3c518_row21_col1, #T_3c518_row21_col2, #T_3c518_row21_col3, #T_3c518_row21_col4, #T_3c518_row22_col0, #T_3c518_row22_col1, #T_3c518_row22_col2, #T_3c518_row22_col3, #T_3c518_row22_col4, #T_3c518_row23_col0, #T_3c518_row23_col1, #T_3c518_row23_col2, #T_3c518_row23_col3, #T_3c518_row23_col4, #T_3c518_row24_col0, #T_3c518_row24_col1, #T_3c518_row24_col2, #T_3c518_row24_col3, #T_3c518_row24_col4, #T_3c518_row25_col0, #T_3c518_row25_col1, #T_3c518_row25_col2, #T_3c518_row25_col3, #T_3c518_row25_col4, #T_3c518_row26_col0, #T_3c518_row26_col1, #T_3c518_row26_col2, #T_3c518_row26_col3, #T_3c518_row26_col4, #T_3c518_row27_col0, #T_3c518_row27_col1, #T_3c518_row27_col2, #T_3c518_row27_col3, #T_3c518_row27_col4, #T_3c518_row28_col0, #T_3c518_row28_col1, #T_3c518_row28_col2, #T_3c518_row28_col3, #T_3c518_row28_col4, #T_3c518_row29_col0, #T_3c518_row29_col1, #T_3c518_row29_col2, #T_3c518_row29_col3, #T_3c518_row29_col4, #T_3c518_row30_col0, #T_3c518_row30_col1, #T_3c518_row30_col2, #T_3c518_row30_col3, #T_3c518_row30_col4, #T_3c518_row31_col0, #T_3c518_row31_col1, #T_3c518_row31_col2, #T_3c518_row31_col3, #T_3c518_row31_col4, #T_3c518_row32_col0, #T_3c518_row32_col1, #T_3c518_row32_col2, #T_3c518_row32_col3, #T_3c518_row32_col4, #T_3c518_row33_col0, #T_3c518_row33_col1, #T_3c518_row33_col2, #T_3c518_row33_col3, #T_3c518_row33_col4, #T_3c518_row34_col0, #T_3c518_row34_col1, #T_3c518_row34_col2, #T_3c518_row34_col3, #T_3c518_row34_col4, #T_3c518_row35_col0, #T_3c518_row35_col1, #T_3c518_row35_col2, #T_3c518_row35_col3, #T_3c518_row35_col4, #T_3c518_row36_col0, #T_3c518_row36_col1, #T_3c518_row36_col2, #T_3c518_row36_col3, #T_3c518_row36_col4, #T_3c518_row37_col0, #T_3c518_row37_col1, #T_3c518_row37_col2, #T_3c518_row37_col3, #T_3c518_row37_col4, #T_3c518_row38_col0, #T_3c518_row38_col1, #T_3c518_row38_col ...

# %% [markdown]
# ### Best Performers in each position

# %%
# Combine metrics into one list
all_metrics = volume_metrics + intensity_metrics

# Store top 5 players per metric and position
top5_players_by_position = []

for metric in all_metrics:
    for position in df['general_position'].dropna().unique():
        # Get top 5 players for this metric and position
        top_rows = df[df['general_position'] == position].nlargest(5, metric)
        
        for _, row in top_rows.iterrows():
            top5_players_by_position.append({
                'metric': metric,
                'player': row['p_name'],
                'club': row['club_for'],
                'value': row[metric],
                'match day': row['match_day'],
                'position': position
            })

# Convert to DataFrame
top5_players_by_position_df = pd.DataFrame(top5_players_by_position)

# Sort by metric name (alphabetically) and then value (descending)
top5_players_by_position_df = top5_players_by_position_df.sort_values(
    ['metric', 'value'], ascending=[True, False]
).reset_index(drop=True)

# Apply your styling function
style_table_for_docs(top5_players_by_position_df)
# Out:
# <style type="text/css">
# #T_83891 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_83891 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_83891 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_83891_row0_col0, #T_83891_row0_col1, #T_83891_row0_col2, #T_83891_row0_col3, #T_83891_row0_col4, #T_83891_row0_col5, #T_83891_row1_col0, #T_83891_row1_col1, #T_83891_row1_col2, #T_83891_row1_col3, #T_83891_row1_col4, #T_83891_row1_col5, #T_83891_row2_col0, #T_83891_row2_col1, #T_83891_row2_col2, #T_83891_row2_col3, #T_83891_row2_col4, #T_83891_row2_col5, #T_83891_row3_col0, #T_83891_row3_col1, #T_83891_row3_col2, #T_83891_row3_col3, #T_83891_row3_col4, #T_83891_row3_col5, #T_83891_row4_col0, #T_83891_row4_col1, #T_83891_row4_col2, #T_83891_row4_col3, #T_83891_row4_col4, #T_83891_row4_col5, #T_83891_row5_col0, #T_83891_row5_col1, #T_83891_row5_col2, #T_83891_row5_col3, #T_83891_row5_col4, #T_83891_row5_col5, #T_83891_row6_col0, #T_83891_row6_col1, #T_83891_row6_col2, #T_83891_row6_col3, #T_83891_row6_col4, #T_83891_row6_col5, #T_83891_row7_col0, #T_83891_row7_col1, #T_83891_row7_col2, #T_83891_row7_col3, #T_83891_row7_col4, #T_83891_row7_col5, #T_83891_row8_col0, #T_83891_row8_col1, #T_83891_row8_col2, #T_83891_row8_col3, #T_83891_row8_col4, #T_83891_row8_col5, #T_83891_row9_col0, #T_83891_row9_col1, #T_83891_row9_col2, #T_83891_row9_col3, #T_83891_row9_col4, #T_83891_row9_col5, #T_83891_row10_col0, #T_83891_row10_col1, #T_83891_row10_col2, #T_83891_row10_col3, #T_83891_row10_col4, #T_83891_row10_col5, #T_83891_row11_col0, #T_83891_row11_col1, #T_83891_row11_col2, #T_83891_row11_col3, #T_83891_row11_col4, #T_83891_row11_col5, #T_83891_row12_col0, #T_83891_row12_col1, #T_83891_row12_col2, #T_83891_row12_col3, #T_83891_row12_col4, #T_83891_row12_col5, #T_83891_row13_col0, #T_83891_row13_col1, #T_83891_row13_col2, #T_83891_row13_col3, #T_83891_row13_col4, #T_83891_row13_col5, #T_83891_row14_col0, #T_83891_row14_col1, #T_83891_row14_col2, #T_83891_row14_col3, #T_83891_row14_col4, #T_83891_row14_col5, #T_83891_row15_col0, #T_83891_row15_col1, #T_83891_row15_col2, #T_83891_row15_col3, #T_83891_row15_col4, #T_83891_row15_col5, #T_83891_row16_col0, #T_83891_row16_col1, #T_83891_row16_col2, #T_83891_row16_col3, #T_83891_row16_col4, #T_83891_row16_col5, #T_83891_row17_col0, #T_83891_row17_col1, #T_83891_row17_col2, #T_83891_row17_col3, #T_83891_row17_col4, #T_83891_row17_col5, #T_83891_row18_col0, #T_83891_row18_col1, #T_83891_row18_col2, #T_83891_row18_col3, #T_83891_row18_col4, #T_83891_row18_col5, #T_83891_row19_col0, #T_83891_row19_col1, #T_83891_row19_col2, #T_83891_row19_col3, #T_83891_row19_col4, #T_83891_row19_col5, #T_83891_row20_col0, #T_83891_row20_col1, #T_83891_row20_col2, #T_83891_row20_col3, #T_83891_row20_col4, #T_83891_row20_col5, #T_83891_row21_col0, #T_83891_row21_col1, #T_83891_row21_col2, #T_83891_row21_col3, #T_83891_row21_col4, #T_83891_row21_col5, #T_83891_row22_col0, #T_83891_row22_col1, #T_83891_row22_col2, #T_83891_row22_col3, #T_83891_row22_col4, #T_83891_row22_col5, #T_83891_row23_col0, #T_83891_row23_col1, #T_83891_row23_col2, #T_83891_row23_col3, #T_83891_row23_col4, #T_83891_row23_col5, #T_83891_row24_col0, #T_83891_row24_col1, #T_83891_row24_col2, #T_83891_row24_col3, #T_83891_row24_col4, #T_83891_row24_col5, #T_83891_row25_col0, #T_83891_row25_col1, #T_83891_row25_col2, #T_83891_row25_col3, #T_83891_row25_col4, #T_83891_row25_col5, #T_83891_row26_col0, #T_83891_row26_col1, #T_83891_row26_col2, #T_83891_row26_col3, #T_83891_row26_col4, #T_83891_row26_col5, #T_83891_row27_col0, #T_83891_row27_col1, #T_83891_row27_col2, #T_83891_row27_col3, #T_83891_row27_col4, #T_83891_row27_col5, #T_83891_row28_col0, #T_83891_row28_col1, #T_83891_row28_col2, #T_83891_row28_col3, #T_83891_row28_col4, #T_83891_row28_col5, #T_83891_row29_col0, #T_83891_row29_col1, #T_83891_row29_col2, #T_83891_row29_col3, #T_83891_row29_col4, #T_83891_row29_col5, #T_83891_row30_col0, #T_83891_row30_col1, #T_83891_row30_col2, #T_83891_row30_col3, #T_83891_row30_col4, #T_83891_row30_col5, #T_83891_row31_col0, #T_83891_row31_col1, #T_83891_row31_col2, #T_83891_row31_col3, #T_83891_row31_col4, #T_83891_row31_col5, #T_83891_row32_col0, #T_8389 ...

# %%
# Combine metrics into one list
all_metrics = volume_metrics + intensity_metrics

# Group by player and position, then average all metrics
avg_df = df.groupby(['p_name', 'general_position', 'club_for'])[all_metrics].mean().reset_index()

# Store top 5 players per metric and position
top5_players_by_position = []

for metric in all_metrics:
    for position in avg_df['general_position'].dropna().unique():
        # Get top 5 players for this metric and position
        top_rows = avg_df[avg_df['general_position'] == position].nlargest(5, metric)
        
        for _, row in top_rows.iterrows():
            top5_players_by_position.append({
                'metric': metric,
                'player': row['p_name'],
                'club': row['club_for'],
                'value': row[metric],
                'position': position
            })

# Convert to DataFrame
top5_players_by_position_df = pd.DataFrame(top5_players_by_position)

# Sort for display: alphabetically by metric, descending by value
top5_players_by_position_df = top5_players_by_position_df.sort_values(
    ['metric', 'value'], ascending=[True, False]
).reset_index(drop=True)

# Display nicely (assuming this is your custom function)
style_table_for_docs(top5_players_by_position_df)
# Out:
# <style type="text/css">
# #T_97add th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_97add td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_97add table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_97add_row0_col0, #T_97add_row0_col1, #T_97add_row0_col2, #T_97add_row0_col3, #T_97add_row0_col4, #T_97add_row1_col0, #T_97add_row1_col1, #T_97add_row1_col2, #T_97add_row1_col3, #T_97add_row1_col4, #T_97add_row2_col0, #T_97add_row2_col1, #T_97add_row2_col2, #T_97add_row2_col3, #T_97add_row2_col4, #T_97add_row3_col0, #T_97add_row3_col1, #T_97add_row3_col2, #T_97add_row3_col3, #T_97add_row3_col4, #T_97add_row4_col0, #T_97add_row4_col1, #T_97add_row4_col2, #T_97add_row4_col3, #T_97add_row4_col4, #T_97add_row5_col0, #T_97add_row5_col1, #T_97add_row5_col2, #T_97add_row5_col3, #T_97add_row5_col4, #T_97add_row6_col0, #T_97add_row6_col1, #T_97add_row6_col2, #T_97add_row6_col3, #T_97add_row6_col4, #T_97add_row7_col0, #T_97add_row7_col1, #T_97add_row7_col2, #T_97add_row7_col3, #T_97add_row7_col4, #T_97add_row8_col0, #T_97add_row8_col1, #T_97add_row8_col2, #T_97add_row8_col3, #T_97add_row8_col4, #T_97add_row9_col0, #T_97add_row9_col1, #T_97add_row9_col2, #T_97add_row9_col3, #T_97add_row9_col4, #T_97add_row10_col0, #T_97add_row10_col1, #T_97add_row10_col2, #T_97add_row10_col3, #T_97add_row10_col4, #T_97add_row11_col0, #T_97add_row11_col1, #T_97add_row11_col2, #T_97add_row11_col3, #T_97add_row11_col4, #T_97add_row12_col0, #T_97add_row12_col1, #T_97add_row12_col2, #T_97add_row12_col3, #T_97add_row12_col4, #T_97add_row13_col0, #T_97add_row13_col1, #T_97add_row13_col2, #T_97add_row13_col3, #T_97add_row13_col4, #T_97add_row14_col0, #T_97add_row14_col1, #T_97add_row14_col2, #T_97add_row14_col3, #T_97add_row14_col4, #T_97add_row15_col0, #T_97add_row15_col1, #T_97add_row15_col2, #T_97add_row15_col3, #T_97add_row15_col4, #T_97add_row16_col0, #T_97add_row16_col1, #T_97add_row16_col2, #T_97add_row16_col3, #T_97add_row16_col4, #T_97add_row17_col0, #T_97add_row17_col1, #T_97add_row17_col2, #T_97add_row17_col3, #T_97add_row17_col4, #T_97add_row18_col0, #T_97add_row18_col1, #T_97add_row18_col2, #T_97add_row18_col3, #T_97add_row18_col4, #T_97add_row19_col0, #T_97add_row19_col1, #T_97add_row19_col2, #T_97add_row19_col3, #T_97add_row19_col4, #T_97add_row20_col0, #T_97add_row20_col1, #T_97add_row20_col2, #T_97add_row20_col3, #T_97add_row20_col4, #T_97add_row21_col0, #T_97add_row21_col1, #T_97add_row21_col2, #T_97add_row21_col3, #T_97add_row21_col4, #T_97add_row22_col0, #T_97add_row22_col1, #T_97add_row22_col2, #T_97add_row22_col3, #T_97add_row22_col4, #T_97add_row23_col0, #T_97add_row23_col1, #T_97add_row23_col2, #T_97add_row23_col3, #T_97add_row23_col4, #T_97add_row24_col0, #T_97add_row24_col1, #T_97add_row24_col2, #T_97add_row24_col3, #T_97add_row24_col4, #T_97add_row25_col0, #T_97add_row25_col1, #T_97add_row25_col2, #T_97add_row25_col3, #T_97add_row25_col4, #T_97add_row26_col0, #T_97add_row26_col1, #T_97add_row26_col2, #T_97add_row26_col3, #T_97add_row26_col4, #T_97add_row27_col0, #T_97add_row27_col1, #T_97add_row27_col2, #T_97add_row27_col3, #T_97add_row27_col4, #T_97add_row28_col0, #T_97add_row28_col1, #T_97add_row28_col2, #T_97add_row28_col3, #T_97add_row28_col4, #T_97add_row29_col0, #T_97add_row29_col1, #T_97add_row29_col2, #T_97add_row29_col3, #T_97add_row29_col4, #T_97add_row30_col0, #T_97add_row30_col1, #T_97add_row30_col2, #T_97add_row30_col3, #T_97add_row30_col4, #T_97add_row31_col0, #T_97add_row31_col1, #T_97add_row31_col2, #T_97add_row31_col3, #T_97add_row31_col4, #T_97add_row32_col0, #T_97add_row32_col1, #T_97add_row32_col2, #T_97add_row32_col3, #T_97add_row32_col4, #T_97add_row33_col0, #T_97add_row33_col1, #T_97add_row33_col2, #T_97add_row33_col3, #T_97add_row33_col4, #T_97add_row34_col0, #T_97add_row34_col1, #T_97add_row34_col2, #T_97add_row34_col3, #T_97add_row34_col4, #T_97add_row35_col0, #T_97add_row35_col1, #T_97add_row35_col2, #T_97add_row35_col3, #T_97add_row35_col4, #T_97add_row36_col0, #T_97add_row36_col1, #T_97add_row36_col2, #T_97add_row36_col3, #T_97add_row36_col4, #T_97add_row37_col0, #T_97add_row37_col1, #T_97add_row37_col2, #T_97add_row37_col3, #T_97add_row37_col4, #T_97add_row38_col0, #T_97add_row38_col1, #T_97add_row38_col ...

# %%
# Custom position sorting order
position_order = ['Defenders', 'Midfielders', 'Forwards']

# Step 1: Count appearances (unique match days)
appearances_df = df.groupby(['p_name', 'general_position', 'club_for'])['match_day'].nunique().reset_index()
appearances_df = appearances_df.rename(columns={'match_day': 'appearances'})

# Step 2: Calculate mean and std for metrics
metrics_stats_df = df.groupby(['p_name', 'general_position', 'club_for'])[all_metrics].agg(['mean', 'std']).reset_index()

# Step 3: Fix column names: flatten multi-index columns
metrics_stats_df.columns = [
    f"{metric}_{stat}" if stat else metric
    for metric, stat in metrics_stats_df.columns.to_flat_index()
]

# Step 4: Merge with appearances
merged_df = metrics_stats_df.merge(
    appearances_df,
    on=['p_name', 'general_position', 'club_for']
)

# Step 5: Only include players with at least 3 appearances
filtered_df = merged_df[merged_df['appearances'] >= 15]

# Step 6: Extract top 5 players for each metric and position
top5_players_by_position = []

for metric in all_metrics:
    mean_col = f'{metric}_mean'
    std_col = f'{metric}_std'

    for position in position_order:
        group = filtered_df[filtered_df['general_position'] == position]

        # Skip if metric column is missing
        if mean_col not in group.columns:
            continue

        top_rows = group.nlargest(5, mean_col)

        for _, row in top_rows.iterrows():
            top5_players_by_position.append({
                'metric': metric,
                'player': row['p_name'],
                'club': row['club_for'],
                'mean_value': row[mean_col],
                'std_dev': row[std_col],
                'appearances': row['appearances'],
                'position': position
            })

# Step 7: Create and sort final DataFrame
top5_df = pd.DataFrame(top5_players_by_position)

# Sort positions using custom category
top5_df['position'] = pd.Categorical(
    top5_df['position'], categories=position_order, ordered=True
)

# Sort by metric → position → mean value
top5_df = top5_df.sort_values(['metric', 'position', 'mean_value'], ascending=[True, True, False]).reset_index(drop=True)

# Show results
style_table_for_docs(top5_df.round(2))
# Out:
# <style type="text/css">
# #T_a25c7 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a25c7 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a25c7 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_a25c7_row0_col0, #T_a25c7_row0_col1, #T_a25c7_row0_col2, #T_a25c7_row0_col3, #T_a25c7_row0_col4, #T_a25c7_row0_col5, #T_a25c7_row0_col6, #T_a25c7_row1_col0, #T_a25c7_row1_col1, #T_a25c7_row1_col2, #T_a25c7_row1_col3, #T_a25c7_row1_col4, #T_a25c7_row1_col5, #T_a25c7_row1_col6, #T_a25c7_row2_col0, #T_a25c7_row2_col1, #T_a25c7_row2_col2, #T_a25c7_row2_col3, #T_a25c7_row2_col4, #T_a25c7_row2_col5, #T_a25c7_row2_col6, #T_a25c7_row3_col0, #T_a25c7_row3_col1, #T_a25c7_row3_col2, #T_a25c7_row3_col3, #T_a25c7_row3_col4, #T_a25c7_row3_col5, #T_a25c7_row3_col6, #T_a25c7_row4_col0, #T_a25c7_row4_col1, #T_a25c7_row4_col2, #T_a25c7_row4_col3, #T_a25c7_row4_col4, #T_a25c7_row4_col5, #T_a25c7_row4_col6, #T_a25c7_row5_col0, #T_a25c7_row5_col1, #T_a25c7_row5_col2, #T_a25c7_row5_col3, #T_a25c7_row5_col4, #T_a25c7_row5_col5, #T_a25c7_row5_col6, #T_a25c7_row6_col0, #T_a25c7_row6_col1, #T_a25c7_row6_col2, #T_a25c7_row6_col3, #T_a25c7_row6_col4, #T_a25c7_row6_col5, #T_a25c7_row6_col6, #T_a25c7_row7_col0, #T_a25c7_row7_col1, #T_a25c7_row7_col2, #T_a25c7_row7_col3, #T_a25c7_row7_col4, #T_a25c7_row7_col5, #T_a25c7_row7_col6, #T_a25c7_row8_col0, #T_a25c7_row8_col1, #T_a25c7_row8_col2, #T_a25c7_row8_col3, #T_a25c7_row8_col4, #T_a25c7_row8_col5, #T_a25c7_row8_col6, #T_a25c7_row9_col0, #T_a25c7_row9_col1, #T_a25c7_row9_col2, #T_a25c7_row9_col3, #T_a25c7_row9_col4, #T_a25c7_row9_col5, #T_a25c7_row9_col6, #T_a25c7_row10_col0, #T_a25c7_row10_col1, #T_a25c7_row10_col2, #T_a25c7_row10_col3, #T_a25c7_row10_col4, #T_a25c7_row10_col5, #T_a25c7_row10_col6, #T_a25c7_row11_col0, #T_a25c7_row11_col1, #T_a25c7_row11_col2, #T_a25c7_row11_col3, #T_a25c7_row11_col4, #T_a25c7_row11_col5, #T_a25c7_row11_col6, #T_a25c7_row12_col0, #T_a25c7_row12_col1, #T_a25c7_row12_col2, #T_a25c7_row12_col3, #T_a25c7_row12_col4, #T_a25c7_row12_col5, #T_a25c7_row12_col6, #T_a25c7_row13_col0, #T_a25c7_row13_col1, #T_a25c7_row13_col2, #T_a25c7_row13_col3, #T_a25c7_row13_col4, #T_a25c7_row13_col5, #T_a25c7_row13_col6, #T_a25c7_row14_col0, #T_a25c7_row14_col1, #T_a25c7_row14_col2, #T_a25c7_row14_col3, #T_a25c7_row14_col4, #T_a25c7_row14_col5, #T_a25c7_row14_col6, #T_a25c7_row15_col0, #T_a25c7_row15_col1, #T_a25c7_row15_col2, #T_a25c7_row15_col3, #T_a25c7_row15_col4, #T_a25c7_row15_col5, #T_a25c7_row15_col6, #T_a25c7_row16_col0, #T_a25c7_row16_col1, #T_a25c7_row16_col2, #T_a25c7_row16_col3, #T_a25c7_row16_col4, #T_a25c7_row16_col5, #T_a25c7_row16_col6, #T_a25c7_row17_col0, #T_a25c7_row17_col1, #T_a25c7_row17_col2, #T_a25c7_row17_col3, #T_a25c7_row17_col4, #T_a25c7_row17_col5, #T_a25c7_row17_col6, #T_a25c7_row18_col0, #T_a25c7_row18_col1, #T_a25c7_row18_col2, #T_a25c7_row18_col3, #T_a25c7_row18_col4, #T_a25c7_row18_col5, #T_a25c7_row18_col6, #T_a25c7_row19_col0, #T_a25c7_row19_col1, #T_a25c7_row19_col2, #T_a25c7_row19_col3, #T_a25c7_row19_col4, #T_a25c7_row19_col5, #T_a25c7_row19_col6, #T_a25c7_row20_col0, #T_a25c7_row20_col1, #T_a25c7_row20_col2, #T_a25c7_row20_col3, #T_a25c7_row20_col4, #T_a25c7_row20_col5, #T_a25c7_row20_col6, #T_a25c7_row21_col0, #T_a25c7_row21_col1, #T_a25c7_row21_col2, #T_a25c7_row21_col3, #T_a25c7_row21_col4, #T_a25c7_row21_col5, #T_a25c7_row21_col6, #T_a25c7_row22_col0, #T_a25c7_row22_col1, #T_a25c7_row22_col2, #T_a25c7_row22_col3, #T_a25c7_row22_col4, #T_a25c7_row22_col5, #T_a25c7_row22_col6, #T_a25c7_row23_col0, #T_a25c7_row23_col1, #T_a25c7_row23_col2, #T_a25c7_row23_col3, #T_a25c7_row23_col4, #T_a25c7_row23_col5, #T_a25c7_row23_col6, #T_a25c7_row24_col0, #T_a25c7_row24_col1, #T_a25c7_row24_col2, #T_a25c7_row24_col3, #T_a25c7_row24_col4, #T_a25c7_row24_col5, #T_a25c7_row24_col6, #T_a25c7_row25_col0, #T_a25c7_row25_col1, #T_a25c7_row25_col2, #T_a25c7_row25_col3, #T_a25c7_row25_col4, #T_a25c7_row25_col5, #T_a25c7_row25_col6, #T_a25c7_row26_col0, #T_a25c7_row26_col1, #T_a25c7_row26_col2, #T_a25c7_row26_col3, #T_a25c7_row26_col4, #T_a25c7_row26_col5, #T_a25c7_row26_col6, #T_a25c7_row27_col0, #T_a25c7_row27_col1, #T_a25c7_row27_col2, #T_a25c7_row27_col3, #T_a25c7_row27_co ...

# %% [markdown]
# ## Speed Zones

# %% [markdown]
# ### Distance in Speed Zones

# %%
# List of speed zone columns
speed_zone_cols = [
    'distance_in_speed_zone_1_km',
    'distance_in_speed_zone_2_km',
    'distance_in_speed_zone_3_km',
    'distance_in_speed_zone_4_km',
    'distance_in_speed_zone_5_km'
]

# Compute average distance for each speed zone
avg_speed_zone_dist = df[speed_zone_cols].mean()

# Prepare labels (replace _ with space, add zone number)
zone_labels = [f"Zone {i+1}" for i in range(len(speed_zone_cols))]

plt.figure(figsize=(8, 5))


# Create barplot
# plt.figure(figsize=(12,6))
sns.barplot(x=zone_labels,hue=zone_labels, y=avg_speed_zone_dist.values, palette='Blues_d',legend=False)

# Title, subtitle, and axis labels
# plt.ylabel("Average Distance (m)")
plt.xlabel("Speed Zone")
plt.title("Average Distance(m) Covered in Each Speed Zone (All Players)", pad=30)

ax= plt.gca()

# Gridlines for y-axis
ax.yaxis.grid(True, linestyle='--', alpha=0.5)
ax.set_axisbelow(True)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

# Annotate values inside bars
for i, v in enumerate(avg_speed_zone_dist):
    # Convert km to m and format with comma

    ax.annotate(
        f"{int(round(v),):,}",
        xy=(i, v),
        xytext=(0, 1),
        textcoords='offset points',
        ha='center',
        va='bottom',
        fontsize=9,
        bbox=dict(boxstyle="circle,pad=0.15", edgecolor='#4682B4', facecolor='white', linewidth=1)
    )

#remove yaxis ticklabels
ax.set_yticklabels([])
ax.set_yticks([])

plt.show()

# %%
# List of speed zone columns 
speed_zone_cols = [
    'time_in_speed_zone_1_secs',
    'time_in_speed_zone_2_secs',
    'time_in_speed_zone_3_secs',
    'time_in_speed_zone_4_secs',
    'time_in_speed_zone_5_secs'
]

# Compute average time (secs) for each speed zone
avg_time_secs = df[speed_zone_cols].mean()

# Total average time across all zones
total_time = avg_time_secs.sum()

# Prepare labels
zone_labels = [f"Zone {i+1}" for i in range(len(speed_zone_cols))]

plt.figure(figsize=(8, 5))
ax = sns.barplot(
    x=zone_labels,
    y=avg_time_secs.values / 60,      # convert to minutes on the y-axis
    palette='Blues_d',
    dodge=False
)

# Title and axis labels
ax.set_xlabel("Speed Zone")
ax.set_title("Percentage of Total Time Covered in Each Speed Zone (All Players)", pad=20)

# Gridlines
ax.yaxis.grid(True, linestyle='--', alpha=0.5)
ax.set_axisbelow(True)

# Remove top and right spines
sns.despine(ax=ax, top=True, right=True, left=True)

# Annotate with percentages
for i, secs in enumerate(avg_time_secs):
    pct = (secs / total_time) * 100
    ax.text(
        i, 
        (secs / 60) + 0.1,           # place label just above the bar (in minutes)
        f"{pct:.1f}%",               
        ha='center', 
        va='bottom', 
        fontsize=9,
        bbox=dict(boxstyle="circle,pad=0.15", edgecolor='#4682B4', facecolor='white', linewidth=1)
    )

# Optionally remove y-ticks if you only want to show percentage
ax.set_yticks([])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Travail\AppData\Local\Temp\ipykernel_25892\2362410231.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
# Prepare data for 100% stacked bar plot: percentage distance in each speed zone grouped by position
speed_zone_cols = [
    'distance_in_speed_zone_1_km',
    'distance_in_speed_zone_2_km',
    'distance_in_speed_zone_3_km',
    'distance_in_speed_zone_4_km',
    'distance_in_speed_zone_5_km'
]

# Group by position and sum distances (in km)
zone_by_position = df.groupby('general_position')[speed_zone_cols].sum()

# Reorder positions if desired
position_order = ['Defenders', 'Midfielders', 'Forwards']
zone_by_position = zone_by_position.reindex(position_order)

# Prepare labels
zone_labels = [f"Zone {i+1}" for i in range(len(speed_zone_cols))]
zone_by_position.columns = zone_labels

# Convert to percentages row-wise
zone_pct = zone_by_position.div(zone_by_position.sum(axis=1), axis=0) * 100

# Plot
ax = zone_pct.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    color=sns.color_palette('viridis', n_colors=len(zone_labels))
)

# Annotate values inside each bar segment (as percentages, one decimal)
for i, pos in enumerate(zone_pct.index):
    cumulative = 0
    for j, zone in enumerate(zone_labels):
        value = zone_pct.loc[pos, zone]
        height = value
        y = cumulative + height / 2
        if value > 0.05:  # Only annotate if segment is large enough
            ax.text(
                i, y, f"{value:.1f}%",
                ha='center', va='center', fontsize=9, color='black' if j > 1 else 'white', fontweight='bold'
            )
        cumulative += height

plt.xlabel('Position Group')
plt.title('Percentage of Total Distance Covered by Position in Each Speed Zone',pad=30)
plt.xticks(rotation=0)
plt.legend(title='Speed Zone', frameon=False, bbox_to_anchor=(1.01, 1), loc='upper left')
# Remove top, left, and right spines
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color('#E0DCDD')
ax.set_facecolor('#F5F5F5')

# Remove yaxis ticklabels and set y-axis to 0-100%
ax.set_yticklabels([])
ax.set_yticks([])

ax.set_yticks(range(0, 101, 20))
ax.set_ylim(0, 100)

plt.tight_layout()
plt.show()

# %%
from matplotlib.patches import Patch

# Prepare data for 100% stacked bar plot: percentage time in each speed zone grouped by position
speed_zone_cols = [
    'time_in_speed_zone_1_secs',
    'time_in_speed_zone_2_secs',
    'time_in_speed_zone_3_secs',
    'time_in_speed_zone_4_secs',
    'time_in_speed_zone_5_secs'
]

# Group by position and sum times (in secs)
zone_by_position = df.groupby('general_position')[speed_zone_cols].sum()

# Reorder positions if desired
position_order = ['Defenders', 'Midfielders', 'Forwards']
zone_by_position = zone_by_position.reindex(position_order)


# Prepare labels
zone_labels = [f"Zone {i+1}" for i in range(len(speed_zone_cols))]
zone_by_position.columns = zone_labels

# Convert to percentages row-wise
zone_pct = zone_by_position.div(zone_by_position.sum(axis=1), axis=0) * 100

# Plot
ax = zone_pct.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    color=sns.color_palette('viridis', n_colors=len(zone_labels))
)

# Annotate values inside each bar segment (as percentages, one decimal)
for i, pos in enumerate(zone_pct.index):
    cumulative = 0
    for j, zone in enumerate(zone_labels):
        value = zone_pct.loc[pos, zone]
        height = value
        y = cumulative + height / 2
        if value > 0.5:  # Only annotate if segment is large enough
            ax.text(
            i, y, f"{value:.1f}%",
            ha='center', va='center', fontsize=9, color='black' if j > 1 else 'white', fontweight='bold'
            )
        else:
            # Place a callout to the right side of the bar for small segments in Zone 5
            if zone == "Zone 5":
                ax.annotate(
                    f"{value:.2f}%",
                    xy=(i + 0.3, cumulative + height / 2),  # right side of the bar
                    xytext=(15, 0),  # offset to the right
                    textcoords='offset points',
                    ha='left',
                    va='center',
                    fontsize=8,
                    fontweight='bold',
                    color='black',
                    # Use a rounded rectangle for the callout box
                    bbox=dict(boxstyle="round,pad=0.2", facecolor="#8BDB41", linewidth=0.5),
                    arrowprops=dict(arrowstyle='->', color='#8BDB41', lw=0.8)
                )
        cumulative += height

plt.xlabel('Position Group')
plt.title('Percentage of Total time Covered by Position in Each Speed Zone',pad=30)
plt.xticks(rotation=0)
plt.legend(title='Speed Zone', frameon=False, bbox_to_anchor=(1.01, 1), loc='upper left')
# Remove top, left, and right spines
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color('#E0DCDD')
ax.set_facecolor('#F5F5F5')

# Remove yaxis ticklabels and set y-axis to 0-100%
ax.set_yticklabels([])
ax.set_yticks([])

ax.set_yticks(range(0, 101, 20))
ax.set_ylim(0, 100)

plt.tight_layout()
plt.show()
