# %% [markdown]
# ## Preliminary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

df = pd.read_csv('./UPL25_matches1.csv')

# %%
df.shape
# Out:
# (3592, 89)

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns#all numeric columns
num_cols = ['duration','distance_km','sprint_distance_m','power_plays','energy_kcal','impacts',
                   'player_load','top_speed_kmh','distance_per_min_mmin','power_score_wkg','work_ratio','max_acceleration_mss','max_deceleration_mss']# numeric columns of high interest
intensity_metrics =['player_load','top_speed_kmh','distance_per_min_mmin','power_score_wkg','work_ratio','max_acceleration_mss','max_deceleration_mss']
volume_metrics = ['distance_km','sprint_distance_m','power_plays','energy_kcal','impacts']

# %%
from IPython.display import HTML

def style_table_for_docs(df, hide_index=False):
    styled = (
        df.style
        .set_properties(**{
            'color': 'black',
            'background-color': 'white',
            'border': '1px solid black',
            'text-align': 'center',
            'padding': '2px'  # reduces row height
        })
        .set_table_styles([
            {'selector': 'th', 'props': [
                ('color', 'black'), 
                ('border', '1px solid black'),
                ('padding', '2px')  # also reduce header row height
            ]},
            {'selector': 'td', 'props': [
                ('color', 'black'), 
                ('border', '1px solid black'),
                ('padding', '2px')
            ]},
            {'selector': 'table', 'props': [
                ('border', '2px solid black'), 
                ('border-collapse', 'collapse')
            ]}
        ])
    )
    
    if hide_index:
        styled = styled.hide(axis='index')

    return styled

# %%
df['total_accelerations'] = df[
	[
		'accelerations_zone_count:_1__2_mss',
		'accelerations_zone_count:_2__3_mss',
		'accelerations_zone_count:_3__4_mss',
		'accelerations_zone_count:_>_4_mss'
	]
].sum(axis=1)

df['total_decelerations'] = df[
	[
		'deceleration_zone_count:_1__2_mss',
		'deceleration_zone_count:_2__3_mss',
		'deceleration_zone_count:_3__4_mss',
		'deceleration_zone_count:_>_4_mss'
	]
].sum(axis=1)

# %%
volume_metrics.append('total_accelerations')
volume_metrics.append('total_decelerations')

df['acc_counts_per_min'] = df['total_accelerations'] / df['duration']
df['dec_counts_per_min'] = df['total_decelerations'] / df['duration']

intensity_metrics.append('acc_counts_per_min')
intensity_metrics.append('dec_counts_per_min')

# %% [markdown]
# ## Executive Summary

# %%
summary_table_intensity = df[intensity_metrics].agg(['max', 'mean', 'std']).T
style_table_for_docs(summary_table_intensity)
# Out:
# <style type="text/css">
# #T_06a04 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_06a04 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_06a04 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_06a04_row0_col0, #T_06a04_row0_col1, #T_06a04_row0_col2, #T_06a04_row1_col0, #T_06a04_row1_col1, #T_06a04_row1_col2, #T_06a04_row2_col0, #T_06a04_row2_col1, #T_06a04_row2_col2, #T_06a04_row3_col0, #T_06a04_row3_col1, #T_06a04_row3_col2, #T_06a04_row4_col0, #T_06a04_row4_col1, #T_06a04_row4_col2, #T_06a04_row5_col0, #T_06a04_row5_col1, #T_06a04_row5_col2, #T_06a04_row6_col0, #T_06a04_row6_col1, #T_06a04_row6_col2, #T_06a04_row7_col0, #T_06a04_row7_col1, #T_06a04_row7_col2, #T_06a04_row8_col0, #T_06a04_row8_col1, #T_06a04_row8_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_06a04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06a04_level0_col0" class="col_heading level0 col0" >max</th>
#       <th id="T_06a04_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_06a04_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06a04_level0_row0" class="row_heading level0 row0" >player_load</th>
#       <td id="T_06a04_row0_col0" class="data row0 col0" >655.960600</td>
#       <td id="T_06a04_row0_col1" class="data row0 col1" >392.415683</td>
#       <td id="T_06a04_row0_col2" class="data row0 col2" >102.628830</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row1" class="row_heading level0 row1" >top_speed_kmh</th>
#       <td id="T_06a04_row1_col0" class="data row1 col0" >36.416300</td>
#       <td id="T_06a04_row1_col1" class="data row1 col1" >29.580822</td>
#       <td id="T_06a04_row1_col2" class="data row1 col2" >2.314279</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row2" class="row_heading level0 row2" >distance_per_min_mmin</th>
#       <td id="T_06a04_row2_col0" class="data row2 col0" >136.524292</td>
#       <td id="T_06a04_row2_col1" class="data row2 col1" >87.017038</td>
#       <td id="T_06a04_row2_col2" class="data row2 col2" >24.646851</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row3" class="row_heading level0 row3" >power_score_wkg</th>
#       <td id="T_06a04_row3_col0" class="data row3 col0" >21.988900</td>
#       <td id="T_06a04_row3_col1" class="data row3 col1" >14.000183</td>
#       <td id="T_06a04_row3_col2" class="data row3 col2" >4.016899</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row4" class="row_heading level0 row4" >work_ratio</th>
#       <td id="T_06a04_row4_col0" class="data row4 col0" >122.165500</td>
#       <td id="T_06a04_row4_col1" class="data row4 col1" >72.639660</td>
#       <td id="T_06a04_row4_col2" class="data row4 col2" >22.780474</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row5" class="row_heading level0 row5" >max_acceleration_mss</th>
#       <td id="T_06a04_row5_col0" class="data row5 col0" >10.000000</td>
#       <td id="T_06a04_row5_col1" class="data row5 col1" >5.852622</td>
#       <td id="T_06a04_row5_col2" class="data row5 col2" >0.634003</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row6" class="row_heading level0 row6" >max_deceleration_mss</th>
#       <td id="T_06a04_row6_col0" class="data row6 col0" >10.000000</td>
#       <td id="T_06a04_row6_col1" class="data row6 col1" >7.166094</td>
#       <td id="T_06a04_row6_col2" class="data row6 col2" >0.974420</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row7" class="row_heading level0 row7" >acc_counts_per_min</th>
#       <td id="T_06a04_row7_col0" class="data row7 col0" >7.110439</td>
#       <td id="T_06a04_row7_col1" class="data row7 col1" >4.061030</td>
#       <td id="T_06a04_row7_col2" class="data row7 col2" >1.225083</td>
#     </tr>
#     <tr>
#       <th id="T_06a04_level0_row8" class="row_heading level0 row8" >dec_counts_per_min</th>
#       <td id="T_06a04_row8_col0" class="data row8 col0" >6.707629</td>
#       <td id="T_06a04_row8_col1" class="data row8 col1" >3.899201</td>
#       <td id="T_06a04_row8_col2" class="data row8 col2" >1.183214</td>
#     </tr>
#   </tbody>
# </table>

# %%
summary_table_volume = df[volume_metrics].agg(['sum', 'max','mean', 'std']).T
style_table_for_docs(summary_table_volume.round(2))
# Out:
# <style type="text/css">
# #T_c6465 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_c6465 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_c6465 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_c6465_row0_col0, #T_c6465_row0_col1, #T_c6465_row0_col2, #T_c6465_row0_col3, #T_c6465_row1_col0, #T_c6465_row1_col1, #T_c6465_row1_col2, #T_c6465_row1_col3, #T_c6465_row2_col0, #T_c6465_row2_col1, #T_c6465_row2_col2, #T_c6465_row2_col3, #T_c6465_row3_col0, #T_c6465_row3_col1, #T_c6465_row3_col2, #T_c6465_row3_col3, #T_c6465_row4_col0, #T_c6465_row4_col1, #T_c6465_row4_col2, #T_c6465_row4_col3, #T_c6465_row5_col0, #T_c6465_row5_col1, #T_c6465_row5_col2, #T_c6465_row5_col3, #T_c6465_row6_col0, #T_c6465_row6_col1, #T_c6465_row6_col2, #T_c6465_row6_col3 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_c6465">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6465_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_c6465_level0_col1" class="col_heading level0 col1" >max</th>
#       <th id="T_c6465_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_c6465_level0_col3" class="col_heading level0 col3" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6465_level0_row0" class="row_heading level0 row0" >distance_km</th>
#       <td id="T_c6465_row0_col0" class="data row0 col0" >30671.800000</td>
#       <td id="T_c6465_row0_col1" class="data row0 col1" >13.500000</td>
#       <td id="T_c6465_row0_col2" class="data row0 col2" >8.540000</td>
#       <td id="T_c6465_row0_col3" class="data row0 col3" >2.430000</td>
#     </tr>
#     <tr>
#       <th id="T_c6465_level0_row1" class="row_heading level0 row1" >sprint_distance_m</th>
#       <td id="T_c6465_row1_col0" class="data row1 col0" >3044059.670000</td>
#       <td id="T_c6465_row1_col1" class="data row1 col1" >2894.440000</td>
#       <td id="T_c6465_row1_col2" class="data row1 col2" >847.460000</td>
#       <td id="T_c6465_row1_col3" class="data row1 col3" >379.360000</td>
#     </tr>
#     <tr>
#       <th id="T_c6465_level0_row2" class="row_heading level0 row2" >power_plays</th>
#       <td id="T_c6465_row2_col0" class="data row2 col0" >217356.000000</td>
#       <td id="T_c6465_row2_col1" class="data row2 col1" >145.000000</td>
#       <td id="T_c6465_row2_col2" class="data row2 col2" >60.510000</td>
#       <td id="T_c6465_row2_col3" class="data row2 col3" >23.020000</td>
#     </tr>
#     <tr>
#       <th id="T_c6465_level0_row3" class="row_heading level0 row3" >energy_kcal</th>
#       <td id="T_c6465_row3_col0" class="data row3 col0" >3750333.340000</td>
#       <td id="T_c6465_row3_col1" class="data row3 col1" >1771.050000</td>
#       <td id="T_c6465_row3_col2" class="data row3 col2" >1044.080000</td>
#       <td id="T_c6465_row3_col3" class="data row3 col3" >300.910000</td>
#     </tr>
#     <tr>
#       <th id="T_c6465_level0_row4" class="row_heading level0 row4" >impacts</th>
#       <td id="T_c6465_row4_col0" class="data row4 col0" >22585.000000</td>
#       <td id="T_c6465_row4_col1" class="data row4 col1" >46.000000</td>
#       <td id="T_c6465_row4_col2" class="data row4 col2" >6.290000</td>
#       <td id="T_c6465_row4_col3" class="data row4 col3" >4.870000</td>
#     </tr>
#     <tr>
#       <th id="T_c6465_level0_row5" class="row_heading level0 row5" >total_accelerations</th>
#       <td id="T_c6465_row5_col0" class="data row5 col0" >1431297.000000</td>
#       <td id="T_c6465_row5_col1" class="data row5 col1" >705.000000</td>
#       <td id="T_c6465_row5_col2" class="data row5 col2" >398.470000</td>
#       <td id="T_c6465_row5_col3" class="data row5 col3" >120.370000</td>
#     </tr>
#     <tr>
#       <th id="T_c6465_level0_row6" class="row_heading level0 row6" >total_decelerations</th>
#       <td id="T_c6465_row6_col0" class="data row6 col0" >1374209.000000</td>
#       <td id="T_c6465_row6_col1" class="data row6 col1" >656.000000</td>
#       <td id="T_c6465_row6_col2" class="data row6 col2" >382.570000</td>
#       <td id="T_c6465_row6_col3" class="data row6 col3" >116.220000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Data Overview

# %%
unique_players_per_club = df.groupby('club_for')['p_name'].nunique().reset_index()
unique_players_per_club.columns = ['club_for', 'unique_players']
style_table_for_docs(unique_players_per_club.sort_values(by='unique_players', ascending=False))
# Out:
# <style type="text/css">
# #T_3c4ec th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3c4ec td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3c4ec table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3c4ec_row0_col0, #T_3c4ec_row0_col1, #T_3c4ec_row1_col0, #T_3c4ec_row1_col1, #T_3c4ec_row2_col0, #T_3c4ec_row2_col1, #T_3c4ec_row3_col0, #T_3c4ec_row3_col1, #T_3c4ec_row4_col0, #T_3c4ec_row4_col1, #T_3c4ec_row5_col0, #T_3c4ec_row5_col1, #T_3c4ec_row6_col0, #T_3c4ec_row6_col1, #T_3c4ec_row7_col0, #T_3c4ec_row7_col1, #T_3c4ec_row8_col0, #T_3c4ec_row8_col1, #T_3c4ec_row9_col0, #T_3c4ec_row9_col1, #T_3c4ec_row10_col0, #T_3c4ec_row10_col1, #T_3c4ec_row11_col0, #T_3c4ec_row11_col1, #T_3c4ec_row12_col0, #T_3c4ec_row12_col1, #T_3c4ec_row13_col0, #T_3c4ec_row13_col1, #T_3c4ec_row14_col0, #T_3c4ec_row14_col1, #T_3c4ec_row15_col0, #T_3c4ec_row15_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_3c4ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c4ec_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_3c4ec_level0_col1" class="col_heading level0 col1" >unique_players</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c4ec_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_3c4ec_row0_col0" class="data row0 col0" >Mbarara City Fc</td>
#       <td id="T_3c4ec_row0_col1" class="data row0 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_3c4ec_row1_col0" class="data row1 col0" >Wakiso Giants Fc</td>
#       <td id="T_3c4ec_row1_col1" class="data row1 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3c4ec_row2_col0" class="data row2 col0" >Kitara Fc</td>
#       <td id="T_3c4ec_row2_col1" class="data row2 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_3c4ec_row3_col0" class="data row3 col0" >Bul Fc</td>
#       <td id="T_3c4ec_row3_col1" class="data row3 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row4" class="row_heading level0 row4" >14</th>
#       <td id="T_3c4ec_row4_col0" class="data row4 col0" >Vipers Sc</td>
#       <td id="T_3c4ec_row4_col1" class="data row4 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_3c4ec_row5_col0" class="data row5 col0" >Police Fc</td>
#       <td id="T_3c4ec_row5_col1" class="data row5 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_3c4ec_row6_col0" class="data row6 col0" >Lugazi Fc</td>
#       <td id="T_3c4ec_row6_col1" class="data row6 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_3c4ec_row7_col0" class="data row7 col0" >Kcca Fc</td>
#       <td id="T_3c4ec_row7_col1" class="data row7 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_3c4ec_row8_col0" class="data row8 col0" >Ura Fc</td>
#       <td id="T_3c4ec_row8_col1" class="data row8 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_3c4ec_row9_col0" class="data row9 col0" >Nec Fc</td>
#       <td id="T_3c4ec_row9_col1" class="data row9 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_3c4ec_row10_col0" class="data row10 col0" >Maroons Fc</td>
#       <td id="T_3c4ec_row10_col1" class="data row10 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_3c4ec_row11_col0" class="data row11 col0" >Updf Fc</td>
#       <td id="T_3c4ec_row11_col1" class="data row11 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row12" class="row_heading level0 row12" >11</th>
#       <td id="T_3c4ec_row12_col0" class="data row12 col0" >Soltilo Bright Stars Fc</td>
#       <td id="T_3c4ec_row12_col1" class="data row12 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row13" class="row_heading level0 row13" >6</th>
#       <td id="T_3c4ec_row13_col0" class="data row13 col0" >Mbale Heroes Fc</td>
#       <td id="T_3c4ec_row13_col1" class="data row13 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row14" class="row_heading level0 row14" >1</th>
#       <td id="T_3c4ec_row14_col0" class="data row14 col0" >Express Fc</td>
#       <td id="T_3c4ec_row14_col1" class="data row14 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_3c4ec_level0_row15" class="row_heading level0 row15" >10</th>
#       <td id="T_3c4ec_row15_col0" class="data row15 col0" >Sc Villa</td>
#       <td id="T_3c4ec_row15_col1" class="data row15 col1" >17</td>
#     </tr>
#   </tbody>
# </table>

# %%
players_match_days = df.groupby(['p_name', 'player_club_'])['match_day'].nunique().reset_index()
players_match_days.columns = ['p_name', 'player_club_', 'unique_match_days']
style_table_for_docs(players_match_days.sort_values(by='unique_match_days', ascending=False).head(10))
# Out:
# <style type="text/css">
# #T_b8261 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_b8261 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_b8261 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_b8261_row0_col0, #T_b8261_row0_col1, #T_b8261_row0_col2, #T_b8261_row1_col0, #T_b8261_row1_col1, #T_b8261_row1_col2, #T_b8261_row2_col0, #T_b8261_row2_col1, #T_b8261_row2_col2, #T_b8261_row3_col0, #T_b8261_row3_col1, #T_b8261_row3_col2, #T_b8261_row4_col0, #T_b8261_row4_col1, #T_b8261_row4_col2, #T_b8261_row5_col0, #T_b8261_row5_col1, #T_b8261_row5_col2, #T_b8261_row6_col0, #T_b8261_row6_col1, #T_b8261_row6_col2, #T_b8261_row7_col0, #T_b8261_row7_col1, #T_b8261_row7_col2, #T_b8261_row8_col0, #T_b8261_row8_col1, #T_b8261_row8_col2, #T_b8261_row9_col0, #T_b8261_row9_col1, #T_b8261_row9_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_b8261">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8261_level0_col0" class="col_heading level0 col0" >p_name</th>
#       <th id="T_b8261_level0_col1" class="col_heading level0 col1" >player_club_</th>
#       <th id="T_b8261_level0_col2" class="col_heading level0 col2" >unique_match_days</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8261_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_b8261_row0_col0" class="data row0 col0" >Abdulkarim Watambala</td>
#       <td id="T_b8261_row0_col1" class="data row0 col1" >Vipers Sc</td>
#       <td id="T_b8261_row0_col2" class="data row0 col2" >26</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row1" class="row_heading level0 row1" >37</th>
#       <td id="T_b8261_row1_col0" class="data row1 col0" >Ayiko Richard</td>
#       <td id="T_b8261_row1_col1" class="data row1 col1" >Lugazi Fc</td>
#       <td id="T_b8261_row1_col2" class="data row1 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row2" class="row_heading level0 row2" >116</th>
#       <td id="T_b8261_row2_col0" class="data row2 col0" >Francis Odongo</td>
#       <td id="T_b8261_row2_col1" class="data row2 col1" >Mbarara City Fc</td>
#       <td id="T_b8261_row2_col2" class="data row2 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row3" class="row_heading level0 row3" >274</th>
#       <td id="T_b8261_row3_col0" class="data row3 col0" >Nelson Senkatuka</td>
#       <td id="T_b8261_row3_col1" class="data row3 col1" >Soltilo Bright Stars Fc</td>
#       <td id="T_b8261_row3_col2" class="data row3 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row4" class="row_heading level0 row4" >324</th>
#       <td id="T_b8261_row4_col0" class="data row4 col0" >Ronald Otti</td>
#       <td id="T_b8261_row4_col1" class="data row4 col1" >Kitara Fc</td>
#       <td id="T_b8261_row4_col2" class="data row4 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row5" class="row_heading level0 row5" >320</th>
#       <td id="T_b8261_row5_col0" class="data row5 col0" >Rogers Ochaki Torach</td>
#       <td id="T_b8261_row5_col1" class="data row5 col1" >Vipers Sc</td>
#       <td id="T_b8261_row5_col2" class="data row5 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row6" class="row_heading level0 row6" >337</th>
#       <td id="T_b8261_row6_col0" class="data row6 col0" >Seiri Arigumaho</td>
#       <td id="T_b8261_row6_col1" class="data row6 col1" >Mbarara City Fc</td>
#       <td id="T_b8261_row6_col2" class="data row6 col2" >24</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row7" class="row_heading level0 row7" >152</th>
#       <td id="T_b8261_row7_col0" class="data row7 col0" >Hilary Panuel Mukundane</td>
#       <td id="T_b8261_row7_col1" class="data row7 col1" >Vipers Sc</td>
#       <td id="T_b8261_row7_col2" class="data row7 col2" >24</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_b8261_row8_col0" class="data row8 col0" >Ali Arshavin Bayo</td>
#       <td id="T_b8261_row8_col1" class="data row8 col1" >Lugazi Fc</td>
#       <td id="T_b8261_row8_col2" class="data row8 col2" >24</td>
#     </tr>
#     <tr>
#       <th id="T_b8261_level0_row9" class="row_heading level0 row9" >15</th>
#       <td id="T_b8261_row9_col0" class="data row9 col0" >Allan Okello</td>
#       <td id="T_b8261_row9_col1" class="data row9 col1" >Vipers Sc</td>
#       <td id="T_b8261_row9_col2" class="data row9 col2" >24</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate average number of unique players per matchday for each club
players_per_club_day = df.groupby(['club_for', 'match_day'])['p_name'].nunique().reset_index()
avg_players_per_matchday = players_per_club_day.groupby('club_for')['p_name'].mean().reset_index()
avg_players_per_matchday.columns = ['club_for', 'avg_players_per_matchday']
style_table_for_docs(avg_players_per_matchday.sort_values(by='avg_players_per_matchday', ascending=False))
# Out:
# <style type="text/css">
# #T_16463 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_16463 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_16463 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_16463_row0_col0, #T_16463_row0_col1, #T_16463_row1_col0, #T_16463_row1_col1, #T_16463_row2_col0, #T_16463_row2_col1, #T_16463_row3_col0, #T_16463_row3_col1, #T_16463_row4_col0, #T_16463_row4_col1, #T_16463_row5_col0, #T_16463_row5_col1, #T_16463_row6_col0, #T_16463_row6_col1, #T_16463_row7_col0, #T_16463_row7_col1, #T_16463_row8_col0, #T_16463_row8_col1, #T_16463_row9_col0, #T_16463_row9_col1, #T_16463_row10_col0, #T_16463_row10_col1, #T_16463_row11_col0, #T_16463_row11_col1, #T_16463_row12_col0, #T_16463_row12_col1, #T_16463_row13_col0, #T_16463_row13_col1, #T_16463_row14_col0, #T_16463_row14_col1, #T_16463_row15_col0, #T_16463_row15_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_16463">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16463_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_16463_level0_col1" class="col_heading level0 col1" >avg_players_per_matchday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16463_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_16463_row0_col0" class="data row0 col0" >Maroons Fc</td>
#       <td id="T_16463_row0_col1" class="data row0 col1" >11.208333</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_16463_row1_col0" class="data row1 col0" >Wakiso Giants Fc</td>
#       <td id="T_16463_row1_col1" class="data row1 col1" >11.173913</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_16463_row2_col0" class="data row2 col0" >Ura Fc</td>
#       <td id="T_16463_row2_col1" class="data row2 col1" >10.960000</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_16463_row3_col0" class="data row3 col0" >Mbarara City Fc</td>
#       <td id="T_16463_row3_col1" class="data row3 col1" >10.793103</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16463_row4_col0" class="data row4 col0" >Lugazi Fc</td>
#       <td id="T_16463_row4_col1" class="data row4 col1" >10.758621</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_16463_row5_col0" class="data row5 col0" >Nec Fc</td>
#       <td id="T_16463_row5_col1" class="data row5 col1" >10.720000</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_16463_row6_col0" class="data row6 col0" >Kitara Fc</td>
#       <td id="T_16463_row6_col1" class="data row6 col1" >10.444444</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_16463_row7_col0" class="data row7 col0" >Express Fc</td>
#       <td id="T_16463_row7_col1" class="data row7 col1" >10.250000</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row8" class="row_heading level0 row8" >14</th>
#       <td id="T_16463_row8_col0" class="data row8 col0" >Vipers Sc</td>
#       <td id="T_16463_row8_col1" class="data row8 col1" >9.892857</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_16463_row9_col0" class="data row9 col0" >Updf Fc</td>
#       <td id="T_16463_row9_col1" class="data row9 col1" >9.629630</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row10" class="row_heading level0 row10" >2</th>
#       <td id="T_16463_row10_col0" class="data row10 col0" >Kcca Fc</td>
#       <td id="T_16463_row10_col1" class="data row10 col1" >9.230769</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row11" class="row_heading level0 row11" >0</th>
#       <td id="T_16463_row11_col0" class="data row11 col0" >Bul Fc</td>
#       <td id="T_16463_row11_col1" class="data row11 col1" >8.368421</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row12" class="row_heading level0 row12" >6</th>
#       <td id="T_16463_row12_col0" class="data row12 col0" >Mbale Heroes Fc</td>
#       <td id="T_16463_row12_col1" class="data row12 col1" >8.090909</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row13" class="row_heading level0 row13" >11</th>
#       <td id="T_16463_row13_col0" class="data row13 col0" >Soltilo Bright Stars Fc</td>
#       <td id="T_16463_row13_col1" class="data row13 col1" >7.535714</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row14" class="row_heading level0 row14" >9</th>
#       <td id="T_16463_row14_col0" class="data row14 col0" >Police Fc</td>
#       <td id="T_16463_row14_col1" class="data row14 col1" >7.407407</td>
#     </tr>
#     <tr>
#       <th id="T_16463_level0_row15" class="row_heading level0 row15" >10</th>
#       <td id="T_16463_row15_col0" class="data row15 col0" >Sc Villa</td>
#       <td id="T_16463_row15_col1" class="data row15 col1" >6.266667</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Count the number of unique matchdays for each club
unique_matchdays_per_club = df.groupby('club_for')['match_day'].nunique().reset_index()
unique_matchdays_per_club.columns = ['club_for', 'unique_matchdays']
style_table_for_docs(unique_matchdays_per_club.sort_values(by='unique_matchdays', ascending=False))
# Out:
# <style type="text/css">
# #T_3e2bc th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3e2bc td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3e2bc table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3e2bc_row0_col0, #T_3e2bc_row0_col1, #T_3e2bc_row1_col0, #T_3e2bc_row1_col1, #T_3e2bc_row2_col0, #T_3e2bc_row2_col1, #T_3e2bc_row3_col0, #T_3e2bc_row3_col1, #T_3e2bc_row4_col0, #T_3e2bc_row4_col1, #T_3e2bc_row5_col0, #T_3e2bc_row5_col1, #T_3e2bc_row6_col0, #T_3e2bc_row6_col1, #T_3e2bc_row7_col0, #T_3e2bc_row7_col1, #T_3e2bc_row8_col0, #T_3e2bc_row8_col1, #T_3e2bc_row9_col0, #T_3e2bc_row9_col1, #T_3e2bc_row10_col0, #T_3e2bc_row10_col1, #T_3e2bc_row11_col0, #T_3e2bc_row11_col1, #T_3e2bc_row12_col0, #T_3e2bc_row12_col1, #T_3e2bc_row13_col0, #T_3e2bc_row13_col1, #T_3e2bc_row14_col0, #T_3e2bc_row14_col1, #T_3e2bc_row15_col0, #T_3e2bc_row15_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_3e2bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e2bc_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_3e2bc_level0_col1" class="col_heading level0 col1" >unique_matchdays</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e2bc_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_3e2bc_row0_col0" class="data row0 col0" >Mbarara City Fc</td>
#       <td id="T_3e2bc_row0_col1" class="data row0 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_3e2bc_row1_col0" class="data row1 col0" >Lugazi Fc</td>
#       <td id="T_3e2bc_row1_col1" class="data row1 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_3e2bc_row2_col0" class="data row2 col0" >Vipers Sc</td>
#       <td id="T_3e2bc_row2_col1" class="data row2 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_3e2bc_row3_col0" class="data row3 col0" >Soltilo Bright Stars Fc</td>
#       <td id="T_3e2bc_row3_col1" class="data row3 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_3e2bc_row4_col0" class="data row4 col0" >Police Fc</td>
#       <td id="T_3e2bc_row4_col1" class="data row4 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_3e2bc_row5_col0" class="data row5 col0" >Updf Fc</td>
#       <td id="T_3e2bc_row5_col1" class="data row5 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_3e2bc_row6_col0" class="data row6 col0" >Kitara Fc</td>
#       <td id="T_3e2bc_row6_col1" class="data row6 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_3e2bc_row7_col0" class="data row7 col0" >Kcca Fc</td>
#       <td id="T_3e2bc_row7_col1" class="data row7 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_3e2bc_row8_col0" class="data row8 col0" >Ura Fc</td>
#       <td id="T_3e2bc_row8_col1" class="data row8 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_3e2bc_row9_col0" class="data row9 col0" >Nec Fc</td>
#       <td id="T_3e2bc_row9_col1" class="data row9 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row10" class="row_heading level0 row10" >5</th>
#       <td id="T_3e2bc_row10_col0" class="data row10 col0" >Maroons Fc</td>
#       <td id="T_3e2bc_row10_col1" class="data row10 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row11" class="row_heading level0 row11" >15</th>
#       <td id="T_3e2bc_row11_col0" class="data row11 col0" >Wakiso Giants Fc</td>
#       <td id="T_3e2bc_row11_col1" class="data row11 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row12" class="row_heading level0 row12" >0</th>
#       <td id="T_3e2bc_row12_col0" class="data row12 col0" >Bul Fc</td>
#       <td id="T_3e2bc_row12_col1" class="data row12 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row13" class="row_heading level0 row13" >10</th>
#       <td id="T_3e2bc_row13_col0" class="data row13 col0" >Sc Villa</td>
#       <td id="T_3e2bc_row13_col1" class="data row13 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row14" class="row_heading level0 row14" >6</th>
#       <td id="T_3e2bc_row14_col0" class="data row14 col0" >Mbale Heroes Fc</td>
#       <td id="T_3e2bc_row14_col1" class="data row14 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3e2bc_level0_row15" class="row_heading level0 row15" >1</th>
#       <td id="T_3e2bc_row15_col0" class="data row15 col0" >Express Fc</td>
#       <td id="T_3e2bc_row15_col1" class="data row15 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = unique_matchdays_per_club.sort_values(by='unique_matchdays', ascending=False)
sns.barplot(data=data, x='club_for', y='unique_matchdays')
plt.xticks(rotation=90)
plt.title('Number of Matchdays Uploaded Per Club')
plt.xlabel('Club')
plt.ylabel('Matchdays Uploaded')

# Annotate values at the top of each bar
for i, value in enumerate(data['unique_matchdays']):
    plt.text(
        i, value + 0.5, str(value),
        ha='center', va='bottom',
        fontsize=8,
        bbox=dict(boxstyle="circle,pad=0.35", edgecolor='#667898', facecolor='white', linewidth=1)
    )

# Remove the top and right spines
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set xticklabels to uppercase
ax.set_xticklabels([label.get_text().upper() for label in ax.get_xticklabels()])

plt.show()
# Out:
# C:\Users\Travail\AppData\Local\Temp\ipykernel_13076\1326583913.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([label.get_text().upper() for label in ax.get_xticklabels()])

# %%
# Calculate total player entries per matchday across all clubs
total_players_per_matchday = df.groupby('match_day')['p_name'].count().reset_index()
total_players_per_matchday.columns = ['match_day', 'total_player_entries']
# Ensure 'match_day' is a categorical variable with the correct order
matchday_order = [f'Md{i}' for i in range(1, 31)]
total_players_per_matchday['match_day'] = pd.Categorical(
    total_players_per_matchday['match_day'],
    categories=matchday_order,
    ordered=True
)
style_table_for_docs(total_players_per_matchday.sort_values(by='match_day'))
# Out:
# <style type="text/css">
# #T_073f9 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_073f9 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_073f9 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_073f9_row0_col0, #T_073f9_row0_col1, #T_073f9_row1_col0, #T_073f9_row1_col1, #T_073f9_row2_col0, #T_073f9_row2_col1, #T_073f9_row3_col0, #T_073f9_row3_col1, #T_073f9_row4_col0, #T_073f9_row4_col1, #T_073f9_row5_col0, #T_073f9_row5_col1, #T_073f9_row6_col0, #T_073f9_row6_col1, #T_073f9_row7_col0, #T_073f9_row7_col1, #T_073f9_row8_col0, #T_073f9_row8_col1, #T_073f9_row9_col0, #T_073f9_row9_col1, #T_073f9_row10_col0, #T_073f9_row10_col1, #T_073f9_row11_col0, #T_073f9_row11_col1, #T_073f9_row12_col0, #T_073f9_row12_col1, #T_073f9_row13_col0, #T_073f9_row13_col1, #T_073f9_row14_col0, #T_073f9_row14_col1, #T_073f9_row15_col0, #T_073f9_row15_col1, #T_073f9_row16_col0, #T_073f9_row16_col1, #T_073f9_row17_col0, #T_073f9_row17_col1, #T_073f9_row18_col0, #T_073f9_row18_col1, #T_073f9_row19_col0, #T_073f9_row19_col1, #T_073f9_row20_col0, #T_073f9_row20_col1, #T_073f9_row21_col0, #T_073f9_row21_col1, #T_073f9_row22_col0, #T_073f9_row22_col1, #T_073f9_row23_col0, #T_073f9_row23_col1, #T_073f9_row24_col0, #T_073f9_row24_col1, #T_073f9_row25_col0, #T_073f9_row25_col1, #T_073f9_row26_col0, #T_073f9_row26_col1, #T_073f9_row27_col0, #T_073f9_row27_col1, #T_073f9_row28_col0, #T_073f9_row28_col1, #T_073f9_row29_col0, #T_073f9_row29_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_073f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_073f9_level0_col0" class="col_heading level0 col0" >match_day</th>
#       <th id="T_073f9_level0_col1" class="col_heading level0 col1" >total_player_entries</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_073f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_073f9_row0_col0" class="data row0 col0" >Md1</td>
#       <td id="T_073f9_row0_col1" class="data row0 col1" >120</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_073f9_row1_col0" class="data row1 col0" >Md2</td>
#       <td id="T_073f9_row1_col1" class="data row1 col1" >145</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row2" class="row_heading level0 row2" >22</th>
#       <td id="T_073f9_row2_col0" class="data row2 col0" >Md3</td>
#       <td id="T_073f9_row2_col1" class="data row2 col1" >143</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_073f9_row3_col0" class="data row3 col0" >Md4</td>
#       <td id="T_073f9_row3_col1" class="data row3 col1" >146</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_073f9_row4_col0" class="data row4 col0" >Md5</td>
#       <td id="T_073f9_row4_col1" class="data row4 col1" >147</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_073f9_row5_col0" class="data row5 col0" >Md6</td>
#       <td id="T_073f9_row5_col1" class="data row5 col1" >149</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_073f9_row6_col0" class="data row6 col0" >Md7</td>
#       <td id="T_073f9_row6_col1" class="data row6 col1" >134</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_073f9_row7_col0" class="data row7 col0" >Md8</td>
#       <td id="T_073f9_row7_col1" class="data row7 col1" >145</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_073f9_row8_col0" class="data row8 col0" >Md9</td>
#       <td id="T_073f9_row8_col1" class="data row8 col1" >96</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_073f9_row9_col0" class="data row9 col0" >Md10</td>
#       <td id="T_073f9_row9_col1" class="data row9 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row10" class="row_heading level0 row10" >2</th>
#       <td id="T_073f9_row10_col0" class="data row10 col0" >Md11</td>
#       <td id="T_073f9_row10_col1" class="data row10 col1" >130</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row11" class="row_heading level0 row11" >3</th>
#       <td id="T_073f9_row11_col0" class="data row11 col0" >Md12</td>
#       <td id="T_073f9_row11_col1" class="data row11 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_073f9_row12_col0" class="data row12 col0" >Md13</td>
#       <td id="T_073f9_row12_col1" class="data row12 col1" >126</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row13" class="row_heading level0 row13" >5</th>
#       <td id="T_073f9_row13_col0" class="data row13 col0" >Md14</td>
#       <td id="T_073f9_row13_col1" class="data row13 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row14" class="row_heading level0 row14" >6</th>
#       <td id="T_073f9_row14_col0" class="data row14 col0" >Md15</td>
#       <td id="T_073f9_row14_col1" class="data row14 col1" >138</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row15" class="row_heading level0 row15" >7</th>
#       <td id="T_073f9_row15_col0" class="data row15 col0" >Md16</td>
#       <td id="T_073f9_row15_col1" class="data row15 col1" >119</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row16" class="row_heading level0 row16" >8</th>
#       <td id="T_073f9_row16_col0" class="data row16 col0" >Md17</td>
#       <td id="T_073f9_row16_col1" class="data row16 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row17" class="row_heading level0 row17" >9</th>
#       <td id="T_073f9_row17_col0" class="data row17 col0" >Md18</td>
#       <td id="T_073f9_row17_col1" class="data row17 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row18" class="row_heading level0 row18" >10</th>
#       <td id="T_073f9_row18_col0" class="data row18 col0" >Md19</td>
#       <td id="T_073f9_row18_col1" class="data row18 col1" >119</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row19" class="row_heading level0 row19" >12</th>
#       <td id="T_073f9_row19_col0" class="data row19 col0" >Md20</td>
#       <td id="T_073f9_row19_col1" class="data row19 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row20" class="row_heading level0 row20" >13</th>
#       <td id="T_073f9_row20_col0" class="data row20 col0" >Md21</td>
#       <td id="T_073f9_row20_col1" class="data row20 col1" >124</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row21" class="row_heading level0 row21" >14</th>
#       <td id="T_073f9_row21_col0" class="data row21 col0" >Md22</td>
#       <td id="T_073f9_row21_col1" class="data row21 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row22" class="row_heading level0 row22" >15</th>
#       <td id="T_073f9_row22_col0" class="data row22 col0" >Md23</td>
#       <td id="T_073f9_row22_col1" class="data row22 col1" >110</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row23" class="row_heading level0 row23" >16</th>
#       <td id="T_073f9_row23_col0" class="data row23 col0" >Md24</td>
#       <td id="T_073f9_row23_col1" class="data row23 col1" >136</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row24" class="row_heading level0 row24" >17</th>
#       <td id="T_073f9_row24_col0" class="data row24 col0" >Md25</td>
#       <td id="T_073f9_row24_col1" class="data row24 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row25" class="row_heading level0 row25" >18</th>
#       <td id="T_073f9_row25_col0" class="data row25 col0" >Md26</td>
#       <td id="T_073f9_row25_col1" class="data row25 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_073f9_level0_row26" class="row_heading level0 row26" >19</th>
#       <td

# %%
# Count the number of unique clubs that submitted data per matchday
clubs_per_matchday = df.groupby('match_day')['club_for'].nunique().reset_index()
clubs_per_matchday.columns = ['match_day', 'num_clubs']
# Ensure 'match_day' is a categorical variable with the correct order
matchday_order = [f'Md{i}' for i in range(1, 31)]
clubs_per_matchday['match_day'] = pd.Categorical(
    clubs_per_matchday['match_day'],
    categories=matchday_order,
    ordered=True
)
style_table_for_docs(clubs_per_matchday.sort_values(by='match_day'))
# Out:
# <style type="text/css">
# #T_e03a8 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e03a8 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e03a8 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_e03a8_row0_col0, #T_e03a8_row0_col1, #T_e03a8_row1_col0, #T_e03a8_row1_col1, #T_e03a8_row2_col0, #T_e03a8_row2_col1, #T_e03a8_row3_col0, #T_e03a8_row3_col1, #T_e03a8_row4_col0, #T_e03a8_row4_col1, #T_e03a8_row5_col0, #T_e03a8_row5_col1, #T_e03a8_row6_col0, #T_e03a8_row6_col1, #T_e03a8_row7_col0, #T_e03a8_row7_col1, #T_e03a8_row8_col0, #T_e03a8_row8_col1, #T_e03a8_row9_col0, #T_e03a8_row9_col1, #T_e03a8_row10_col0, #T_e03a8_row10_col1, #T_e03a8_row11_col0, #T_e03a8_row11_col1, #T_e03a8_row12_col0, #T_e03a8_row12_col1, #T_e03a8_row13_col0, #T_e03a8_row13_col1, #T_e03a8_row14_col0, #T_e03a8_row14_col1, #T_e03a8_row15_col0, #T_e03a8_row15_col1, #T_e03a8_row16_col0, #T_e03a8_row16_col1, #T_e03a8_row17_col0, #T_e03a8_row17_col1, #T_e03a8_row18_col0, #T_e03a8_row18_col1, #T_e03a8_row19_col0, #T_e03a8_row19_col1, #T_e03a8_row20_col0, #T_e03a8_row20_col1, #T_e03a8_row21_col0, #T_e03a8_row21_col1, #T_e03a8_row22_col0, #T_e03a8_row22_col1, #T_e03a8_row23_col0, #T_e03a8_row23_col1, #T_e03a8_row24_col0, #T_e03a8_row24_col1, #T_e03a8_row25_col0, #T_e03a8_row25_col1, #T_e03a8_row26_col0, #T_e03a8_row26_col1, #T_e03a8_row27_col0, #T_e03a8_row27_col1, #T_e03a8_row28_col0, #T_e03a8_row28_col1, #T_e03a8_row29_col0, #T_e03a8_row29_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_e03a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e03a8_level0_col0" class="col_heading level0 col0" >match_day</th>
#       <th id="T_e03a8_level0_col1" class="col_heading level0 col1" >num_clubs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e03a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e03a8_row0_col0" class="data row0 col0" >Md1</td>
#       <td id="T_e03a8_row0_col1" class="data row0 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_e03a8_row1_col0" class="data row1 col0" >Md2</td>
#       <td id="T_e03a8_row1_col1" class="data row1 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row2" class="row_heading level0 row2" >22</th>
#       <td id="T_e03a8_row2_col0" class="data row2 col0" >Md3</td>
#       <td id="T_e03a8_row2_col1" class="data row2 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_e03a8_row3_col0" class="data row3 col0" >Md4</td>
#       <td id="T_e03a8_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_e03a8_row4_col0" class="data row4 col0" >Md5</td>
#       <td id="T_e03a8_row4_col1" class="data row4 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_e03a8_row5_col0" class="data row5 col0" >Md6</td>
#       <td id="T_e03a8_row5_col1" class="data row5 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_e03a8_row6_col0" class="data row6 col0" >Md7</td>
#       <td id="T_e03a8_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_e03a8_row7_col0" class="data row7 col0" >Md8</td>
#       <td id="T_e03a8_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_e03a8_row8_col0" class="data row8 col0" >Md9</td>
#       <td id="T_e03a8_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_e03a8_row9_col0" class="data row9 col0" >Md10</td>
#       <td id="T_e03a8_row9_col1" class="data row9 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row10" class="row_heading level0 row10" >2</th>
#       <td id="T_e03a8_row10_col0" class="data row10 col0" >Md11</td>
#       <td id="T_e03a8_row10_col1" class="data row10 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row11" class="row_heading level0 row11" >3</th>
#       <td id="T_e03a8_row11_col0" class="data row11 col0" >Md12</td>
#       <td id="T_e03a8_row11_col1" class="data row11 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_e03a8_row12_col0" class="data row12 col0" >Md13</td>
#       <td id="T_e03a8_row12_col1" class="data row12 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row13" class="row_heading level0 row13" >5</th>
#       <td id="T_e03a8_row13_col0" class="data row13 col0" >Md14</td>
#       <td id="T_e03a8_row13_col1" class="data row13 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row14" class="row_heading level0 row14" >6</th>
#       <td id="T_e03a8_row14_col0" class="data row14 col0" >Md15</td>
#       <td id="T_e03a8_row14_col1" class="data row14 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row15" class="row_heading level0 row15" >7</th>
#       <td id="T_e03a8_row15_col0" class="data row15 col0" >Md16</td>
#       <td id="T_e03a8_row15_col1" class="data row15 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row16" class="row_heading level0 row16" >8</th>
#       <td id="T_e03a8_row16_col0" class="data row16 col0" >Md17</td>
#       <td id="T_e03a8_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row17" class="row_heading level0 row17" >9</th>
#       <td id="T_e03a8_row17_col0" class="data row17 col0" >Md18</td>
#       <td id="T_e03a8_row17_col1" class="data row17 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row18" class="row_heading level0 row18" >10</th>
#       <td id="T_e03a8_row18_col0" class="data row18 col0" >Md19</td>
#       <td id="T_e03a8_row18_col1" class="data row18 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row19" class="row_heading level0 row19" >12</th>
#       <td id="T_e03a8_row19_col0" class="data row19 col0" >Md20</td>
#       <td id="T_e03a8_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row20" class="row_heading level0 row20" >13</th>
#       <td id="T_e03a8_row20_col0" class="data row20 col0" >Md21</td>
#       <td id="T_e03a8_row20_col1" class="data row20 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row21" class="row_heading level0 row21" >14</th>
#       <td id="T_e03a8_row21_col0" class="data row21 col0" >Md22</td>
#       <td id="T_e03a8_row21_col1" class="data row21 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row22" class="row_heading level0 row22" >15</th>
#       <td id="T_e03a8_row22_col0" class="data row22 col0" >Md23</td>
#       <td id="T_e03a8_row22_col1" class="data row22 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row23" class="row_heading level0 row23" >16</th>
#       <td id="T_e03a8_row23_col0" class="data row23 col0" >Md24</td>
#       <td id="T_e03a8_row23_col1" class="data row23 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row24" class="row_heading level0 row24" >17</th>
#       <td id="T_e03a8_row24_col0" class="data row24 col0" >Md25</td>
#       <td id="T_e03a8_row24_col1" class="data row24 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row25" class="row_heading level0 row25" >18</th>
#       <td id="T_e03a8_row25_col0" class="data row25 col0" >Md26</td>
#       <td id="T_e03a8_row25_col1" class="data row25 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_e03a8_level0_row26" class="row_heading level0 row26" >19</th>
#       <td id="T_e03a8_row26_col0" class="data

# %%
def plot_line_with_values(data, x_col, y_col, title=None, x_label=None,y_label=None, figsize=(10, 6)):
    # Create figure and axis
    plt.figure(figsize=figsize)
    
    # Plot the line
    sns.lineplot(data=data, x=x_col, y=y_col, marker='o', color='orange', linewidth=2)

    
    # Get current axis
    ax = plt.gca()
    
    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Set spine and tick colors to light gray
    gray_color = '#808080'
    ax.spines['bottom'].set_color(gray_color)
    ax.spines['left'].set_color(gray_color)
    

    if x_col == 'match_day':
        # Ensure match_day is ordered as per matchday_order
        data[x_col] = pd.Categorical(data[x_col], categories=matchday_order, ordered=True)
        data_sorted = data.sort_values(by=x_col)
        xticklabels = [str(md).replace('Md', 'MD ') for md in data_sorted[x_col]]
        ax.set_xticks(range(len(data_sorted[x_col])))
        ax.set_xticklabels(xticklabels, rotation=90)
        # Re-plot with sorted data to ensure correct order
        
        sns.lineplot(data=data_sorted, x=x_col, y=y_col, marker='o', color='orange', linewidth=2)
        
    # Add value labels above each point
    for i, (x, y) in enumerate(zip(data[x_col], data[y_col])):
        ax.annotate(
            f'{y}', 
            (x, y),
            textcoords="offset points", 
            xytext=(0, 10), 
            ha='center',
            fontsize=8,
            bbox=dict(boxstyle="circle,pad=0.35", edgecolor='#FE912A', facecolor='white', linewidth=1)
        )
    
    # Set title
    if title is None:
        title = f'{y_col} vs {x_col}'
    plt.title(title)

    # #start the y-axis at 0
    ax.set_ylim(bottom=60,top=180)  # Adjust the top limit as needed
    

    # Set labels
    if x_label is None:
        x_label = x_col.replace('_', ' ').title()
    plt.xlabel(x_label)
    if y_label is None:
        y_label = y_col.replace('_', ' ').title()
    plt.ylabel(y_label)
    plt.grid(axis='y', linestyle='--', linewidth=0.5, color='#E0DCDD', alpha=0.7)
    # Adjust layout
    plt.tight_layout()
    
    return ax

# %%
plot_line_with_values(clubs_per_matchday, 'match_day', 'num_clubs', title='Number of Clubs that Uploaded Data Per Matchday',x_label='Match Day', y_label='Number of Clubs');

# %%
plot_line_with_values(total_players_per_matchday, 'match_day', 'total_player_entries', title='Total Player Entries Per Matchday', x_label='Match Day', y_label='Total Player Entries');

# %%
# Count number and percentage of entries based on 'location'
location_counts = df['location'].value_counts().reset_index()
location_counts.columns = ['location', 'count']
location_counts['percentage'] = (location_counts['count'] / len(df)) * 100

style_table_for_docs(location_counts)
# Out:
# <style type="text/css">
# #T_a2b7a th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a2b7a td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_a2b7a table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_a2b7a_row0_col0, #T_a2b7a_row0_col1, #T_a2b7a_row0_col2, #T_a2b7a_row1_col0, #T_a2b7a_row1_col1, #T_a2b7a_row1_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_a2b7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2b7a_level0_col0" class="col_heading level0 col0" >location</th>
#       <th id="T_a2b7a_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_a2b7a_level0_col2" class="col_heading level0 col2" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2b7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2b7a_row0_col0" class="data row0 col0" >Away</td>
#       <td id="T_a2b7a_row0_col1" class="data row0 col1" >1855</td>
#       <td id="T_a2b7a_row0_col2" class="data row0 col2" >51.642539</td>
#     </tr>
#     <tr>
#       <th id="T_a2b7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2b7a_row1_col0" class="data row1 col0" >Home</td>
#       <td id="T_a2b7a_row1_col1" class="data row1 col1" >1737</td>
#       <td id="T_a2b7a_row1_col2" class="data row1 col2" >48.357461</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Count number and percentage of entries based on 'result'
location_counts = df['result'].value_counts().reset_index()
location_counts.columns = ['result', 'count']
location_counts['percentage'] = (location_counts['count'] / len(df)) * 100

style_table_for_docs(location_counts)
# Out:
# <style type="text/css">
# #T_1bd13 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_1bd13 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_1bd13 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_1bd13_row0_col0, #T_1bd13_row0_col1, #T_1bd13_row0_col2, #T_1bd13_row1_col0, #T_1bd13_row1_col1, #T_1bd13_row1_col2, #T_1bd13_row2_col0, #T_1bd13_row2_col1, #T_1bd13_row2_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_1bd13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bd13_level0_col0" class="col_heading level0 col0" >result</th>
#       <th id="T_1bd13_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_1bd13_level0_col2" class="col_heading level0 col2" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bd13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bd13_row0_col0" class="data row0 col0" >Loss</td>
#       <td id="T_1bd13_row0_col1" class="data row0 col1" >1325</td>
#       <td id="T_1bd13_row0_col2" class="data row0 col2" >36.887528</td>
#     </tr>
#     <tr>
#       <th id="T_1bd13_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1bd13_row1_col0" class="data row1 col0" >Win</td>
#       <td id="T_1bd13_row1_col1" class="data row1 col1" >1267</td>
#       <td id="T_1bd13_row1_col2" class="data row1 col2" >35.272829</td>
#     </tr>
#     <tr>
#       <th id="T_1bd13_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1bd13_row2_col0" class="data row2 col0" >Draw</td>
#       <td id="T_1bd13_row2_col1" class="data row2 col1" >1000</td>
#       <td id="T_1bd13_row2_col2" class="data row2 col2" >27.839644</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate Win-Draw-Loss counts for each club using unique match days
matchday_results = df.groupby(['club_for', 'match_day'])['result'].first().reset_index()
wld_counts = matchday_results.groupby(['club_for', 'result']).size().unstack(fill_value=0)
wld_counts = wld_counts[['Win', 'Draw', 'Loss']]  # Ensure order if all present

style_table_for_docs(wld_counts.sort_values(by='Win', ascending=False))
# Out:
# <style type="text/css">
# #T_96744 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_96744 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_96744 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_96744_row0_col0, #T_96744_row0_col1, #T_96744_row0_col2, #T_96744_row1_col0, #T_96744_row1_col1, #T_96744_row1_col2, #T_96744_row2_col0, #T_96744_row2_col1, #T_96744_row2_col2, #T_96744_row3_col0, #T_96744_row3_col1, #T_96744_row3_col2, #T_96744_row4_col0, #T_96744_row4_col1, #T_96744_row4_col2, #T_96744_row5_col0, #T_96744_row5_col1, #T_96744_row5_col2, #T_96744_row6_col0, #T_96744_row6_col1, #T_96744_row6_col2, #T_96744_row7_col0, #T_96744_row7_col1, #T_96744_row7_col2, #T_96744_row8_col0, #T_96744_row8_col1, #T_96744_row8_col2, #T_96744_row9_col0, #T_96744_row9_col1, #T_96744_row9_col2, #T_96744_row10_col0, #T_96744_row10_col1, #T_96744_row10_col2, #T_96744_row11_col0, #T_96744_row11_col1, #T_96744_row11_col2, #T_96744_row12_col0, #T_96744_row12_col1, #T_96744_row12_col2, #T_96744_row13_col0, #T_96744_row13_col1, #T_96744_row13_col2, #T_96744_row14_col0, #T_96744_row14_col1, #T_96744_row14_col2, #T_96744_row15_col0, #T_96744_row15_col1, #T_96744_row15_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_96744">
#   <thead>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th id="T_96744_level0_col0" class="col_heading level0 col0" >Win</th>
#       <th id="T_96744_level0_col1" class="col_heading level0 col1" >Draw</th>
#       <th id="T_96744_level0_col2" class="col_heading level0 col2" >Loss</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >club_for</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96744_level0_row0" class="row_heading level0 row0" >Vipers Sc</th>
#       <td id="T_96744_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_96744_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_96744_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row1" class="row_heading level0 row1" >Nec Fc</th>
#       <td id="T_96744_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_96744_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_96744_row1_col2" class="data row1 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row2" class="row_heading level0 row2" >Ura Fc</th>
#       <td id="T_96744_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_96744_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_96744_row2_col2" class="data row2 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row3" class="row_heading level0 row3" >Kcca Fc</th>
#       <td id="T_96744_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_96744_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_96744_row3_col2" class="data row3 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row4" class="row_heading level0 row4" >Maroons Fc</th>
#       <td id="T_96744_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_96744_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_96744_row4_col2" class="data row4 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row5" class="row_heading level0 row5" >Kitara Fc</th>
#       <td id="T_96744_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_96744_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_96744_row5_col2" class="data row5 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row6" class="row_heading level0 row6" >Mbarara City Fc</th>
#       <td id="T_96744_row6_col0" class="data row6 col0" >8</td>
#       <td id="T_96744_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_96744_row6_col2" class="data row6 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row7" class="row_heading level0 row7" >Lugazi Fc</th>
#       <td id="T_96744_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_96744_row7_col1" class="data row7 col1" >9</td>
#       <td id="T_96744_row7_col2" class="data row7 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row8" class="row_heading level0 row8" >Updf Fc</th>
#       <td id="T_96744_row8_col0" class="data row8 col0" >7</td>
#       <td id="T_96744_row8_col1" class="data row8 col1" >8</td>
#       <td id="T_96744_row8_col2" class="data row8 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row9" class="row_heading level0 row9" >Police Fc</th>
#       <td id="T_96744_row9_col0" class="data row9 col0" >7</td>
#       <td id="T_96744_row9_col1" class="data row9 col1" >11</td>
#       <td id="T_96744_row9_col2" class="data row9 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row10" class="row_heading level0 row10" >Bul Fc</th>
#       <td id="T_96744_row10_col0" class="data row10 col0" >7</td>
#       <td id="T_96744_row10_col1" class="data row10 col1" >8</td>
#       <td id="T_96744_row10_col2" class="data row10 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row11" class="row_heading level0 row11" >Sc Villa</th>
#       <td id="T_96744_row11_col0" class="data row11 col0" >5</td>
#       <td id="T_96744_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_96744_row11_col2" class="data row11 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row12" class="row_heading level0 row12" >Soltilo Bright Stars Fc</th>
#       <td id="T_96744_row12_col0" class="data row12 col0" >4</td>
#       <td id="T_96744_row12_col1" class="data row12 col1" >9</td>
#       <td id="T_96744_row12_col2" class="data row12 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row13" class="row_heading level0 row13" >Express Fc</th>
#       <td id="T_96744_row13_col0" class="data row13 col0" >3</td>
#       <td id="T_96744_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_96744_row13_col2" class="data row13 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row14" class="row_heading level0 row14" >Mbale Heroes Fc</th>
#       <td id="T_96744_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_96744_row14_col1" class="data row14 col1" >3</td>
#       <td id="T_96744_row14_col2" class="data row14 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_96744_level0_row15" class="row_heading level0 row15" >Wakiso Giants Fc</th>
#       <td id="T_96744_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_96744_row15_col1" class="data row15 col1" >10</td>
#       <td id="T_96744_row15_col2" class="data row15 col2" >11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Max Metrics

# %%
speed_table = df[['top_speed_kmh','distance_per_min_mmin','max_acceleration_mss','max_deceleration_mss']].agg(['max', 'mean', 'std']).T
style_table_for_docs(speed_table)
# Out:
# <style type="text/css">
# #T_13c29 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_13c29 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_13c29 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_13c29_row0_col0, #T_13c29_row0_col1, #T_13c29_row0_col2, #T_13c29_row1_col0, #T_13c29_row1_col1, #T_13c29_row1_col2, #T_13c29_row2_col0, #T_13c29_row2_col1, #T_13c29_row2_col2, #T_13c29_row3_col0, #T_13c29_row3_col1, #T_13c29_row3_col2 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_13c29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13c29_level0_col0" class="col_heading level0 col0" >max</th>
#       <th id="T_13c29_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_13c29_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13c29_level0_row0" class="row_heading level0 row0" >top_speed_kmh</th>
#       <td id="T_13c29_row0_col0" class="data row0 col0" >36.416300</td>
#       <td id="T_13c29_row0_col1" class="data row0 col1" >29.580822</td>
#       <td id="T_13c29_row0_col2" class="data row0 col2" >2.314279</td>
#     </tr>
#     <tr>
#       <th id="T_13c29_level0_row1" class="row_heading level0 row1" >distance_per_min_mmin</th>
#       <td id="T_13c29_row1_col0" class="data row1 col0" >136.524292</td>
#       <td id="T_13c29_row1_col1" class="data row1 col1" >87.017038</td>
#       <td id="T_13c29_row1_col2" class="data row1 col2" >24.646851</td>
#     </tr>
#     <tr>
#       <th id="T_13c29_level0_row2" class="row_heading level0 row2" >max_acceleration_mss</th>
#       <td id="T_13c29_row2_col0" class="data row2 col0" >10.000000</td>
#       <td id="T_13c29_row2_col1" class="data row2 col1" >5.852622</td>
#       <td id="T_13c29_row2_col2" class="data row2 col2" >0.634003</td>
#     </tr>
#     <tr>
#       <th id="T_13c29_level0_row3" class="row_heading level0 row3" >max_deceleration_mss</th>
#       <td id="T_13c29_row3_col0" class="data row3 col0" >10.000000</td>
#       <td id="T_13c29_row3_col1" class="data row3 col1" >7.166094</td>
#       <td id="T_13c29_row3_col2" class="data row3 col2" >0.974420</td>
#     </tr>
#   </tbody>
# </table>

# %%
distance_speed_zones = ['distance_in_speed_zone_1_km', 'distance_in_speed_zone_2_km', 'distance_in_speed_zone_3_km','distance_in_speed_zone_4_km','distance_in_speed_zone_5_km']
for i in distance_speed_zones:
    df[i] = df[i] * 1000  # Convert from km to m

speed_zone_dist= df[distance_speed_zones].agg(['sum','max', 'mean', 'std']).T.round(2)
style_table_for_docs(speed_zone_dist)
# Out:
# <style type="text/css">
# #T_3e02e th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3e02e td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3e02e table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3e02e_row0_col0, #T_3e02e_row0_col1, #T_3e02e_row0_col2, #T_3e02e_row0_col3, #T_3e02e_row1_col0, #T_3e02e_row1_col1, #T_3e02e_row1_col2, #T_3e02e_row1_col3, #T_3e02e_row2_col0, #T_3e02e_row2_col1, #T_3e02e_row2_col2, #T_3e02e_row2_col3, #T_3e02e_row3_col0, #T_3e02e_row3_col1, #T_3e02e_row3_col2, #T_3e02e_row3_col3, #T_3e02e_row4_col0, #T_3e02e_row4_col1, #T_3e02e_row4_col2, #T_3e02e_row4_col3 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_3e02e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e02e_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_3e02e_level0_col1" class="col_heading level0 col1" >max</th>
#       <th id="T_3e02e_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_3e02e_level0_col3" class="col_heading level0 col3" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e02e_level0_row0" class="row_heading level0 row0" >distance_in_speed_zone_1_km</th>
#       <td id="T_3e02e_row0_col0" class="data row0 col0" >3015250.700000</td>
#       <td id="T_3e02e_row0_col1" class="data row0 col1" >2099.000000</td>
#       <td id="T_3e02e_row0_col2" class="data row0 col2" >839.440000</td>
#       <td id="T_3e02e_row0_col3" class="data row0 col3" >243.100000</td>
#     </tr>
#     <tr>
#       <th id="T_3e02e_level0_row1" class="row_heading level0 row1" >distance_in_speed_zone_2_km</th>
#       <td id="T_3e02e_row1_col0" class="data row1 col0" >14971900.700000</td>
#       <td id="T_3e02e_row1_col1" class="data row1 col1" >6290.400000</td>
#       <td id="T_3e02e_row1_col2" class="data row1 col2" >4168.120000</td>
#       <td id="T_3e02e_row1_col3" class="data row1 col3" >1205.710000</td>
#     </tr>
#     <tr>
#       <th id="T_3e02e_level0_row2" class="row_heading level0 row2" >distance_in_speed_zone_3_km</th>
#       <td id="T_3e02e_row2_col0" class="data row2 col0" >9640575.300000</td>
#       <td id="T_3e02e_row2_col1" class="data row2 col1" >6135.200000</td>
#       <td id="T_3e02e_row2_col2" class="data row2 col2" >2683.900000</td>
#       <td id="T_3e02e_row2_col3" class="data row2 col3" >998.360000</td>
#     </tr>
#     <tr>
#       <th id="T_3e02e_level0_row3" class="row_heading level0 row3" >distance_in_speed_zone_4_km</th>
#       <td id="T_3e02e_row3_col0" class="data row3 col0" >2634255.200000</td>
#       <td id="T_3e02e_row3_col1" class="data row3 col1" >2349.500000</td>
#       <td id="T_3e02e_row3_col2" class="data row3 col2" >733.370000</td>
#       <td id="T_3e02e_row3_col3" class="data row3 col3" >317.050000</td>
#     </tr>
#     <tr>
#       <th id="T_3e02e_level0_row4" class="row_heading level0 row4" >distance_in_speed_zone_5_km</th>
#       <td id="T_3e02e_row4_col0" class="data row4 col0" >409803.500000</td>
#       <td id="T_3e02e_row4_col1" class="data row4 col1" >643.600000</td>
#       <td id="T_3e02e_row4_col2" class="data row4 col2" >114.090000</td>
#       <td id="T_3e02e_row4_col3" class="data row4 col3" >94.240000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Club Comparison

# %%
club_volume_mean = (
    df.groupby(['club_for', 'match_day'],observed=False)[volume_metrics].mean()
    .groupby('club_for').mean()
    .rename(columns=lambda x: f'avg_{x}')
    .sort_values(by='avg_distance_km', ascending=False)
    .reset_index()
)
club_volume_mean.round(2)
style_table_for_docs(club_volume_mean)
# Out:
# <style type="text/css">
# #T_8645b th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_8645b td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_8645b table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_8645b_row0_col0, #T_8645b_row0_col1, #T_8645b_row0_col2, #T_8645b_row0_col3, #T_8645b_row0_col4, #T_8645b_row0_col5, #T_8645b_row0_col6, #T_8645b_row0_col7, #T_8645b_row1_col0, #T_8645b_row1_col1, #T_8645b_row1_col2, #T_8645b_row1_col3, #T_8645b_row1_col4, #T_8645b_row1_col5, #T_8645b_row1_col6, #T_8645b_row1_col7, #T_8645b_row2_col0, #T_8645b_row2_col1, #T_8645b_row2_col2, #T_8645b_row2_col3, #T_8645b_row2_col4, #T_8645b_row2_col5, #T_8645b_row2_col6, #T_8645b_row2_col7, #T_8645b_row3_col0, #T_8645b_row3_col1, #T_8645b_row3_col2, #T_8645b_row3_col3, #T_8645b_row3_col4, #T_8645b_row3_col5, #T_8645b_row3_col6, #T_8645b_row3_col7, #T_8645b_row4_col0, #T_8645b_row4_col1, #T_8645b_row4_col2, #T_8645b_row4_col3, #T_8645b_row4_col4, #T_8645b_row4_col5, #T_8645b_row4_col6, #T_8645b_row4_col7, #T_8645b_row5_col0, #T_8645b_row5_col1, #T_8645b_row5_col2, #T_8645b_row5_col3, #T_8645b_row5_col4, #T_8645b_row5_col5, #T_8645b_row5_col6, #T_8645b_row5_col7, #T_8645b_row6_col0, #T_8645b_row6_col1, #T_8645b_row6_col2, #T_8645b_row6_col3, #T_8645b_row6_col4, #T_8645b_row6_col5, #T_8645b_row6_col6, #T_8645b_row6_col7, #T_8645b_row7_col0, #T_8645b_row7_col1, #T_8645b_row7_col2, #T_8645b_row7_col3, #T_8645b_row7_col4, #T_8645b_row7_col5, #T_8645b_row7_col6, #T_8645b_row7_col7, #T_8645b_row8_col0, #T_8645b_row8_col1, #T_8645b_row8_col2, #T_8645b_row8_col3, #T_8645b_row8_col4, #T_8645b_row8_col5, #T_8645b_row8_col6, #T_8645b_row8_col7, #T_8645b_row9_col0, #T_8645b_row9_col1, #T_8645b_row9_col2, #T_8645b_row9_col3, #T_8645b_row9_col4, #T_8645b_row9_col5, #T_8645b_row9_col6, #T_8645b_row9_col7, #T_8645b_row10_col0, #T_8645b_row10_col1, #T_8645b_row10_col2, #T_8645b_row10_col3, #T_8645b_row10_col4, #T_8645b_row10_col5, #T_8645b_row10_col6, #T_8645b_row10_col7, #T_8645b_row11_col0, #T_8645b_row11_col1, #T_8645b_row11_col2, #T_8645b_row11_col3, #T_8645b_row11_col4, #T_8645b_row11_col5, #T_8645b_row11_col6, #T_8645b_row11_col7, #T_8645b_row12_col0, #T_8645b_row12_col1, #T_8645b_row12_col2, #T_8645b_row12_col3, #T_8645b_row12_col4, #T_8645b_row12_col5, #T_8645b_row12_col6, #T_8645b_row12_col7, #T_8645b_row13_col0, #T_8645b_row13_col1, #T_8645b_row13_col2, #T_8645b_row13_col3, #T_8645b_row13_col4, #T_8645b_row13_col5, #T_8645b_row13_col6, #T_8645b_row13_col7, #T_8645b_row14_col0, #T_8645b_row14_col1, #T_8645b_row14_col2, #T_8645b_row14_col3, #T_8645b_row14_col4, #T_8645b_row14_col5, #T_8645b_row14_col6, #T_8645b_row14_col7, #T_8645b_row15_col0, #T_8645b_row15_col1, #T_8645b_row15_col2, #T_8645b_row15_col3, #T_8645b_row15_col4, #T_8645b_row15_col5, #T_8645b_row15_col6, #T_8645b_row15_col7 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_8645b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8645b_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_8645b_level0_col1" class="col_heading level0 col1" >avg_distance_km</th>
#       <th id="T_8645b_level0_col2" class="col_heading level0 col2" >avg_sprint_distance_m</th>
#       <th id="T_8645b_level0_col3" class="col_heading level0 col3" >avg_power_plays</th>
#       <th id="T_8645b_level0_col4" class="col_heading level0 col4" >avg_energy_kcal</th>
#       <th id="T_8645b_level0_col5" class="col_heading level0 col5" >avg_impacts</th>
#       <th id="T_8645b_level0_col6" class="col_heading level0 col6" >avg_total_accelerations</th>
#       <th id="T_8645b_level0_col7" class="col_heading level0 col7" >avg_total_decelerations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8645b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8645b_row0_col0" class="data row0 col0" >Sc Villa</td>
#       <td id="T_8645b_row0_col1" class="data row0 col1" >10.086886</td>
#       <td id="T_8645b_row0_col2" class="data row0 col2" >1080.263981</td>
#       <td id="T_8645b_row0_col3" class="data row0 col3" >72.126376</td>
#       <td id="T_8645b_row0_col4" class="data row0 col4" >1221.870866</td>
#       <td id="T_8645b_row0_col5" class="data row0 col5" >7.131587</td>
#       <td id="T_8645b_row0_col6" class="data row0 col6" >449.715000</td>
#       <td id="T_8645b_row0_col7" class="data row0 col7" >428.014444</td>
#     </tr>
#     <tr>
#       <th id="T_8645b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8645b_row1_col0" class="data row1 col0" >Soltilo Bright Stars Fc</td>
#       <td id="T_8645b_row1_col1" class="data row1 col1" >9.704213</td>
#       <td id="T_8645b_row1_col2" class="data row1 col2" >862.143439</td>
#       <td id="T_8645b_row1_col3" class="data row1 col3" >64.896820</td>
#       <td id="T_8645b_row1_col4" class="data row1 col4" >1164.405773</td>
#       <td id="T_8645b_row1_col5" class="data row1 col5" >7.851212</td>
#       <td id="T_8645b_row1_col6" class="data row1 col6" >447.380439</td>
#       <td id="T_8645b_row1_col7" class="data row1 col7" >432.345644</td>
#     </tr>
#     <tr>
#       <th id="T_8645b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8645b_row2_col0" class="data row2 col0" >Kcca Fc</td>
#       <td id="T_8645b_row2_col1" class="data row2 col1" >9.117836</td>
#       <td id="T_8645b_row2_col2" class="data row2 col2" >1000.611918</td>
#       <td id="T_8645b_row2_col3" class="data row2 col3" >69.973506</td>
#       <td id="T_8645b_row2_col4" class="data row2 col4" >1116.806316</td>
#       <td id="T_8645b_row2_col5" class="data row2 col5" >5.741976</td>
#       <td id="T_8645b_row2_col6" class="data row2 col6" >427.647525</td>
#       <td id="T_8645b_row2_col7" class="data row2 col7" >409.698496</td>
#     </tr>
#     <tr>
#       <th id="T_8645b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8645b_row3_col0" class="data row3 col0" >Maroons Fc</td>
#       <td id="T_8645b_row3_col1" class="data row3 col1" >9.007664</td>
#       <td id="T_8645b_row3_col2" class="data row3 col2" >980.269357</td>
#       <td id="T_8645b_row3_col3" class="data row3 col3" >68.178226</td>
#       <td id="T_8645b_row3_col4" class="data row3 col4" >1109.227100</td>
#       <td id="T_8645b_row3_col5" class="data row3 col5" >4.849710</td>
#       <td id="T_8645b_row3_col6" class="data row3 col6" >420.601710</td>
#       <td id="T_8645b_row3_col7" class="data row3 col7" >404.935301</td>
#     </tr>
#     <tr>
#       <th id="T_8645b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8645b_row4_col0" class="data row4 col0" >Bul Fc</td>
#       <td id="T_8645b_row4_col1" class="data row4 col1" >8.894690</td>
#       <td id="T_8645b_row4_col2" class="data row4 col2" >778.056201</td>
#       <td id="T_8645b_row4_col3" class="data row4 col3" >57.985870</td>
#       <td id="T_8645b_row4_col4" class="data row4 col4" >1126.760822</td>
#       <td id="T_8645b_row4_col5" class="data row4 col5" >5.784067</td>
#       <td id="T_8645b_row4_col6" class="data row4 col6" >417.803385</td>
#       <td id="T_8645b_row4_col7" class="data row4 col7" >399.762999</td>
#     </tr>
#     <tr>
#       <th id="T_8645b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8645b_row5_col0" class="data row5 col0" >Vipers Sc</td>
#       <td id="T_8645b_row5_col1" class="data row5 col1" >8.867177</td>
#       <td id="T_8645b_row5_col2" class="data row5 col2" >919.170262</td>
#       <td id="T_8645b_row5_col3" class="data row5 col3" >65.189906</td>
#       <td id="T_8645b_row5_col4" class="data row5 col4" >1084.968068</td>
#       <td id="T_8645b_row5_col5" class="data row5 col5" >8.050488</td>
#       <td id="T_8645b_row5_col6" class="data row5 col6" >414.407243</td>
#       <td id="T_8645b_row5_col7" class="data row5 col7" >396.613944</td>
#     </tr>
#     <tr>
#       <th id="T_8645b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8645b_row6_col0" class="data row6 c

# %%
club_intensity_mean = (
    df.groupby(['club_for', 'match_day'])[[i for i in intensity_metrics if i not in ['top_speed_kmh','distance_per_min_mmin','max_acceleration_mss','max_deceleration_mss']]].mean()
    .groupby('club_for').mean()
    .rename(columns=lambda x: f'avg_{x}')
    .sort_values(by='avg_work_ratio', ascending=False)
    .reset_index()
)
style_table_for_docs(club_intensity_mean)
# Out:
# <style type="text/css">
# #T_145a5 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_145a5 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_145a5 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_145a5_row0_col0, #T_145a5_row0_col1, #T_145a5_row0_col2, #T_145a5_row0_col3, #T_145a5_row0_col4, #T_145a5_row0_col5, #T_145a5_row1_col0, #T_145a5_row1_col1, #T_145a5_row1_col2, #T_145a5_row1_col3, #T_145a5_row1_col4, #T_145a5_row1_col5, #T_145a5_row2_col0, #T_145a5_row2_col1, #T_145a5_row2_col2, #T_145a5_row2_col3, #T_145a5_row2_col4, #T_145a5_row2_col5, #T_145a5_row3_col0, #T_145a5_row3_col1, #T_145a5_row3_col2, #T_145a5_row3_col3, #T_145a5_row3_col4, #T_145a5_row3_col5, #T_145a5_row4_col0, #T_145a5_row4_col1, #T_145a5_row4_col2, #T_145a5_row4_col3, #T_145a5_row4_col4, #T_145a5_row4_col5, #T_145a5_row5_col0, #T_145a5_row5_col1, #T_145a5_row5_col2, #T_145a5_row5_col3, #T_145a5_row5_col4, #T_145a5_row5_col5, #T_145a5_row6_col0, #T_145a5_row6_col1, #T_145a5_row6_col2, #T_145a5_row6_col3, #T_145a5_row6_col4, #T_145a5_row6_col5, #T_145a5_row7_col0, #T_145a5_row7_col1, #T_145a5_row7_col2, #T_145a5_row7_col3, #T_145a5_row7_col4, #T_145a5_row7_col5, #T_145a5_row8_col0, #T_145a5_row8_col1, #T_145a5_row8_col2, #T_145a5_row8_col3, #T_145a5_row8_col4, #T_145a5_row8_col5, #T_145a5_row9_col0, #T_145a5_row9_col1, #T_145a5_row9_col2, #T_145a5_row9_col3, #T_145a5_row9_col4, #T_145a5_row9_col5, #T_145a5_row10_col0, #T_145a5_row10_col1, #T_145a5_row10_col2, #T_145a5_row10_col3, #T_145a5_row10_col4, #T_145a5_row10_col5, #T_145a5_row11_col0, #T_145a5_row11_col1, #T_145a5_row11_col2, #T_145a5_row11_col3, #T_145a5_row11_col4, #T_145a5_row11_col5, #T_145a5_row12_col0, #T_145a5_row12_col1, #T_145a5_row12_col2, #T_145a5_row12_col3, #T_145a5_row12_col4, #T_145a5_row12_col5, #T_145a5_row13_col0, #T_145a5_row13_col1, #T_145a5_row13_col2, #T_145a5_row13_col3, #T_145a5_row13_col4, #T_145a5_row13_col5, #T_145a5_row14_col0, #T_145a5_row14_col1, #T_145a5_row14_col2, #T_145a5_row14_col3, #T_145a5_row14_col4, #T_145a5_row14_col5, #T_145a5_row15_col0, #T_145a5_row15_col1, #T_145a5_row15_col2, #T_145a5_row15_col3, #T_145a5_row15_col4, #T_145a5_row15_col5 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_145a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_145a5_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_145a5_level0_col1" class="col_heading level0 col1" >avg_player_load</th>
#       <th id="T_145a5_level0_col2" class="col_heading level0 col2" >avg_power_score_wkg</th>
#       <th id="T_145a5_level0_col3" class="col_heading level0 col3" >avg_work_ratio</th>
#       <th id="T_145a5_level0_col4" class="col_heading level0 col4" >avg_acc_counts_per_min</th>
#       <th id="T_145a5_level0_col5" class="col_heading level0 col5" >avg_dec_counts_per_min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_145a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_145a5_row0_col0" class="data row0 col0" >Sc Villa</td>
#       <td id="T_145a5_row0_col1" class="data row0 col1" >456.488766</td>
#       <td id="T_145a5_row0_col2" class="data row0 col2" >16.521405</td>
#       <td id="T_145a5_row0_col3" class="data row0 col3" >88.427938</td>
#       <td id="T_145a5_row0_col4" class="data row0 col4" >4.579135</td>
#       <td id="T_145a5_row0_col5" class="data row0 col5" >4.356419</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_145a5_row1_col0" class="data row1 col0" >Soltilo Bright Stars Fc</td>
#       <td id="T_145a5_row1_col1" class="data row1 col1" >453.127819</td>
#       <td id="T_145a5_row1_col2" class="data row1 col2" >15.713335</td>
#       <td id="T_145a5_row1_col3" class="data row1 col3" >81.829293</td>
#       <td id="T_145a5_row1_col4" class="data row1 col4" >4.550860</td>
#       <td id="T_145a5_row1_col5" class="data row1 col5" >4.398021</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_145a5_row2_col0" class="data row2 col0" >Kcca Fc</td>
#       <td id="T_145a5_row2_col1" class="data row2 col1" >408.456675</td>
#       <td id="T_145a5_row2_col2" class="data row2 col2" >14.955091</td>
#       <td id="T_145a5_row2_col3" class="data row2 col3" >78.625811</td>
#       <td id="T_145a5_row2_col4" class="data row2 col4" >4.317860</td>
#       <td id="T_145a5_row2_col5" class="data row2 col5" >4.136784</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_145a5_row3_col0" class="data row3 col0" >Maroons Fc</td>
#       <td id="T_145a5_row3_col1" class="data row3 col1" >411.400553</td>
#       <td id="T_145a5_row3_col2" class="data row3 col2" >14.962113</td>
#       <td id="T_145a5_row3_col3" class="data row3 col3" >78.488633</td>
#       <td id="T_145a5_row3_col4" class="data row3 col4" >4.325050</td>
#       <td id="T_145a5_row3_col5" class="data row3 col5" >4.164129</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_145a5_row4_col0" class="data row4 col0" >Express Fc</td>
#       <td id="T_145a5_row4_col1" class="data row4 col1" >419.483847</td>
#       <td id="T_145a5_row4_col2" class="data row4 col2" >14.411045</td>
#       <td id="T_145a5_row4_col3" class="data row4 col3" >74.298349</td>
#       <td id="T_145a5_row4_col4" class="data row4 col4" >4.486373</td>
#       <td id="T_145a5_row4_col5" class="data row4 col5" >4.296817</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_145a5_row5_col0" class="data row5 col0" >Bul Fc</td>
#       <td id="T_145a5_row5_col1" class="data row5 col1" >403.108979</td>
#       <td id="T_145a5_row5_col2" class="data row5 col2" >14.326917</td>
#       <td id="T_145a5_row5_col3" class="data row5 col3" >73.620771</td>
#       <td id="T_145a5_row5_col4" class="data row5 col4" >4.210155</td>
#       <td id="T_145a5_row5_col5" class="data row5 col5" >4.029277</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_145a5_row6_col0" class="data row6 col0" >Mbarara City Fc</td>
#       <td id="T_145a5_row6_col1" class="data row6 col1" >391.754241</td>
#       <td id="T_145a5_row6_col2" class="data row6 col2" >13.738329</td>
#       <td id="T_145a5_row6_col3" class="data row6 col3" >72.952407</td>
#       <td id="T_145a5_row6_col4" class="data row6 col4" >4.087759</td>
#       <td id="T_145a5_row6_col5" class="data row6 col5" >3.932918</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_145a5_row7_col0" class="data row7 col0" >Ura Fc</td>
#       <td id="T_145a5_row7_col1" class="data row7 col1" >392.628714</td>
#       <td id="T_145a5_row7_col2" class="data row7 col2" >14.016739</td>
#       <td id="T_145a5_row7_col3" class="data row7 col3" >72.532409</td>
#       <td id="T_145a5_row7_col4" class="data row7 col4" >4.148828</td>
#       <td id="T_145a5_row7_col5" class="data row7 col5" >3.986525</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_145a5_row8_col0" class="data row8 col0" >Lugazi Fc</td>
#       <td id="T_145a5_row8_col1" class="data row8 col1" >381.267064</td>
#       <td id="T_145a5_row8_col2" class="data row8 col2" >13.800766</td>
#       <td id="T_145a5_row8_col3" class="data row8 col3" >72.081063</td>
#       <td id="T_145a5_row8_col4" class="data row8 col4" >4.012825</td>
#       <td id="T_145a5_row8_col5" class="data row8 col5" >3.832416</td>
#     </tr>
#     <tr>
#       <th id="T_145a5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_145a5_row9_col0" class="data row9 col0" >Vipers Sc</td>
#       <td id="T_145a5_row9_col1" class="data row9 col1" >409.698832</td>
#       <td id="T_145a5_row9_col2" class="data row9

# %%
club_intensity_max = (
    df.groupby('club_for')[['top_speed_kmh', 'distance_per_min_mmin', 'max_acceleration_mss', 'max_deceleration_mss']]
    .max()
    .rename(columns=lambda x: f'max_{x}')
    .sort_values(by='max_top_speed_kmh', ascending=False)
    .reset_index()
)
style_table_for_docs(club_intensity_max)
# Out:
# <style type="text/css">
# #T_5cd36 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_5cd36 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_5cd36 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_5cd36_row0_col0, #T_5cd36_row0_col1, #T_5cd36_row0_col2, #T_5cd36_row0_col3, #T_5cd36_row0_col4, #T_5cd36_row1_col0, #T_5cd36_row1_col1, #T_5cd36_row1_col2, #T_5cd36_row1_col3, #T_5cd36_row1_col4, #T_5cd36_row2_col0, #T_5cd36_row2_col1, #T_5cd36_row2_col2, #T_5cd36_row2_col3, #T_5cd36_row2_col4, #T_5cd36_row3_col0, #T_5cd36_row3_col1, #T_5cd36_row3_col2, #T_5cd36_row3_col3, #T_5cd36_row3_col4, #T_5cd36_row4_col0, #T_5cd36_row4_col1, #T_5cd36_row4_col2, #T_5cd36_row4_col3, #T_5cd36_row4_col4, #T_5cd36_row5_col0, #T_5cd36_row5_col1, #T_5cd36_row5_col2, #T_5cd36_row5_col3, #T_5cd36_row5_col4, #T_5cd36_row6_col0, #T_5cd36_row6_col1, #T_5cd36_row6_col2, #T_5cd36_row6_col3, #T_5cd36_row6_col4, #T_5cd36_row7_col0, #T_5cd36_row7_col1, #T_5cd36_row7_col2, #T_5cd36_row7_col3, #T_5cd36_row7_col4, #T_5cd36_row8_col0, #T_5cd36_row8_col1, #T_5cd36_row8_col2, #T_5cd36_row8_col3, #T_5cd36_row8_col4, #T_5cd36_row9_col0, #T_5cd36_row9_col1, #T_5cd36_row9_col2, #T_5cd36_row9_col3, #T_5cd36_row9_col4, #T_5cd36_row10_col0, #T_5cd36_row10_col1, #T_5cd36_row10_col2, #T_5cd36_row10_col3, #T_5cd36_row10_col4, #T_5cd36_row11_col0, #T_5cd36_row11_col1, #T_5cd36_row11_col2, #T_5cd36_row11_col3, #T_5cd36_row11_col4, #T_5cd36_row12_col0, #T_5cd36_row12_col1, #T_5cd36_row12_col2, #T_5cd36_row12_col3, #T_5cd36_row12_col4, #T_5cd36_row13_col0, #T_5cd36_row13_col1, #T_5cd36_row13_col2, #T_5cd36_row13_col3, #T_5cd36_row13_col4, #T_5cd36_row14_col0, #T_5cd36_row14_col1, #T_5cd36_row14_col2, #T_5cd36_row14_col3, #T_5cd36_row14_col4, #T_5cd36_row15_col0, #T_5cd36_row15_col1, #T_5cd36_row15_col2, #T_5cd36_row15_col3, #T_5cd36_row15_col4 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_5cd36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cd36_level0_col0" class="col_heading level0 col0" >club_for</th>
#       <th id="T_5cd36_level0_col1" class="col_heading level0 col1" >max_top_speed_kmh</th>
#       <th id="T_5cd36_level0_col2" class="col_heading level0 col2" >max_distance_per_min_mmin</th>
#       <th id="T_5cd36_level0_col3" class="col_heading level0 col3" >max_max_acceleration_mss</th>
#       <th id="T_5cd36_level0_col4" class="col_heading level0 col4" >max_max_deceleration_mss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cd36_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cd36_row0_col0" class="data row0 col0" >Bul Fc</td>
#       <td id="T_5cd36_row0_col1" class="data row0 col1" >36.416300</td>
#       <td id="T_5cd36_row0_col2" class="data row0 col2" >123.209469</td>
#       <td id="T_5cd36_row0_col3" class="data row0 col3" >7.711200</td>
#       <td id="T_5cd36_row0_col4" class="data row0 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5cd36_row1_col0" class="data row1 col0" >Ura Fc</td>
#       <td id="T_5cd36_row1_col1" class="data row1 col1" >36.224300</td>
#       <td id="T_5cd36_row1_col2" class="data row1 col2" >128.651725</td>
#       <td id="T_5cd36_row1_col3" class="data row1 col3" >10.000000</td>
#       <td id="T_5cd36_row1_col4" class="data row1 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5cd36_row2_col0" class="data row2 col0" >Lugazi Fc</td>
#       <td id="T_5cd36_row2_col1" class="data row2 col1" >36.208300</td>
#       <td id="T_5cd36_row2_col2" class="data row2 col2" >126.420948</td>
#       <td id="T_5cd36_row2_col3" class="data row2 col3" >9.724500</td>
#       <td id="T_5cd36_row2_col4" class="data row2 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5cd36_row3_col0" class="data row3 col0" >Nec Fc</td>
#       <td id="T_5cd36_row3_col1" class="data row3 col1" >36.016300</td>
#       <td id="T_5cd36_row3_col2" class="data row3 col2" >127.241957</td>
#       <td id="T_5cd36_row3_col3" class="data row3 col3" >9.814200</td>
#       <td id="T_5cd36_row3_col4" class="data row3 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5cd36_row4_col0" class="data row4 col0" >Sc Villa</td>
#       <td id="T_5cd36_row4_col1" class="data row4 col1" >36.016300</td>
#       <td id="T_5cd36_row4_col2" class="data row4 col2" >136.524292</td>
#       <td id="T_5cd36_row4_col3" class="data row4 col3" >7.496400</td>
#       <td id="T_5cd36_row4_col4" class="data row4 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5cd36_row5_col0" class="data row5 col0" >Vipers Sc</td>
#       <td id="T_5cd36_row5_col1" class="data row5 col1" >35.840300</td>
#       <td id="T_5cd36_row5_col2" class="data row5 col2" >121.878974</td>
#       <td id="T_5cd36_row5_col3" class="data row5 col3" >7.937100</td>
#       <td id="T_5cd36_row5_col4" class="data row5 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5cd36_row6_col0" class="data row6 col0" >Mbarara City Fc</td>
#       <td id="T_5cd36_row6_col1" class="data row6 col1" >35.728300</td>
#       <td id="T_5cd36_row6_col2" class="data row6 col2" >124.947769</td>
#       <td id="T_5cd36_row6_col3" class="data row6 col3" >10.000000</td>
#       <td id="T_5cd36_row6_col4" class="data row6 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5cd36_row7_col0" class="data row7 col0" >Kcca Fc</td>
#       <td id="T_5cd36_row7_col1" class="data row7 col1" >35.568300</td>
#       <td id="T_5cd36_row7_col2" class="data row7 col2" >126.309864</td>
#       <td id="T_5cd36_row7_col3" class="data row7 col3" >8.464700</td>
#       <td id="T_5cd36_row7_col4" class="data row7 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5cd36_row8_col0" class="data row8 col0" >Kitara Fc</td>
#       <td id="T_5cd36_row8_col1" class="data row8 col1" >35.296300</td>
#       <td id="T_5cd36_row8_col2" class="data row8 col2" >124.065330</td>
#       <td id="T_5cd36_row8_col3" class="data row8 col3" >9.093400</td>
#       <td id="T_5cd36_row8_col4" class="data row8 col4" >9.809000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5cd36_row9_col0" class="data row9 col0" >Maroons Fc</td>
#       <td id="T_5cd36_row9_col1" class="data row9 col1" >35.136300</td>
#       <td id="T_5cd36_row9_col2" class="data row9 col2" >128.552486</td>
#       <td id="T_5cd36_row9_col3" class="data row9 col3" >7.795600</td>
#       <td id="T_5cd36_row9_col4" class="data row9 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5cd36_row10_col0" class="data row10 col0" >Police Fc</td>
#       <td id="T_5cd36_row10_col1" class="data row10 col1" >34.768300</td>
#       <td id="T_5cd36_row10_col2" class="data row10 col2" >122.893805</td>
#       <td id="T_5cd36_row10_col3" class="data row10 col3" >10.000000</td>
#       <td id="T_5cd36_row10_col4" class="data row10 col4" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5cd36_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5cd36_row11_col0" class="data row11 col0" >Updf Fc</td>
#       <td id="T_5cd36_row11_col1" class="data row11 col1" >34.568300</td>
#       <td id="T_5cd36_row11_col2" class="data row11 col2" >127.681890</td>
#       <td id="T_5cd36_row11_col3" class="data row11 col3" >7.911200</td>
#       <td id="T_5cd36_row11_col4"

# %% [markdown]
# ### Player High Scores

# %%
# For each metric in volume_metrics, find the player with the highest value, the value, and the club
top_players = []
for metric in volume_metrics +intensity_metrics:
    idx = df[metric].idxmax()
    row = df.loc[idx]
    top_players.append({
        'metric': metric,
        'player': row['p_name'],
        'club': row['club_for'],
        'value': row[metric],
        'match day': row['match_day']
    })

top_players_df = pd.DataFrame(top_players)
style_table_for_docs(top_players_df)
# Out:
# <style type="text/css">
# #T_6a806 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_6a806 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_6a806 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_6a806_row0_col0, #T_6a806_row0_col1, #T_6a806_row0_col2, #T_6a806_row0_col3, #T_6a806_row0_col4, #T_6a806_row1_col0, #T_6a806_row1_col1, #T_6a806_row1_col2, #T_6a806_row1_col3, #T_6a806_row1_col4, #T_6a806_row2_col0, #T_6a806_row2_col1, #T_6a806_row2_col2, #T_6a806_row2_col3, #T_6a806_row2_col4, #T_6a806_row3_col0, #T_6a806_row3_col1, #T_6a806_row3_col2, #T_6a806_row3_col3, #T_6a806_row3_col4, #T_6a806_row4_col0, #T_6a806_row4_col1, #T_6a806_row4_col2, #T_6a806_row4_col3, #T_6a806_row4_col4, #T_6a806_row5_col0, #T_6a806_row5_col1, #T_6a806_row5_col2, #T_6a806_row5_col3, #T_6a806_row5_col4, #T_6a806_row6_col0, #T_6a806_row6_col1, #T_6a806_row6_col2, #T_6a806_row6_col3, #T_6a806_row6_col4, #T_6a806_row7_col0, #T_6a806_row7_col1, #T_6a806_row7_col2, #T_6a806_row7_col3, #T_6a806_row7_col4, #T_6a806_row8_col0, #T_6a806_row8_col1, #T_6a806_row8_col2, #T_6a806_row8_col3, #T_6a806_row8_col4, #T_6a806_row9_col0, #T_6a806_row9_col1, #T_6a806_row9_col2, #T_6a806_row9_col3, #T_6a806_row9_col4, #T_6a806_row10_col0, #T_6a806_row10_col1, #T_6a806_row10_col2, #T_6a806_row10_col3, #T_6a806_row10_col4, #T_6a806_row11_col0, #T_6a806_row11_col1, #T_6a806_row11_col2, #T_6a806_row11_col3, #T_6a806_row11_col4, #T_6a806_row12_col0, #T_6a806_row12_col1, #T_6a806_row12_col2, #T_6a806_row12_col3, #T_6a806_row12_col4, #T_6a806_row13_col0, #T_6a806_row13_col1, #T_6a806_row13_col2, #T_6a806_row13_col3, #T_6a806_row13_col4, #T_6a806_row14_col0, #T_6a806_row14_col1, #T_6a806_row14_col2, #T_6a806_row14_col3, #T_6a806_row14_col4, #T_6a806_row15_col0, #T_6a806_row15_col1, #T_6a806_row15_col2, #T_6a806_row15_col3, #T_6a806_row15_col4 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_6a806">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a806_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_6a806_level0_col1" class="col_heading level0 col1" >player</th>
#       <th id="T_6a806_level0_col2" class="col_heading level0 col2" >club</th>
#       <th id="T_6a806_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_6a806_level0_col4" class="col_heading level0 col4" >match day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a806_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a806_row0_col0" class="data row0 col0" >distance_km</td>
#       <td id="T_6a806_row0_col1" class="data row0 col1" >Ronald Ssekiganda</td>
#       <td id="T_6a806_row0_col2" class="data row0 col2" >Sc Villa</td>
#       <td id="T_6a806_row0_col3" class="data row0 col3" >13.499000</td>
#       <td id="T_6a806_row0_col4" class="data row0 col4" >Md7</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a806_row1_col0" class="data row1 col0" >sprint_distance_m</td>
#       <td id="T_6a806_row1_col1" class="data row1 col1" >Innocent Wafula Esimu</td>
#       <td id="T_6a806_row1_col2" class="data row1 col2" >Mbarara City Fc</td>
#       <td id="T_6a806_row1_col3" class="data row1 col3" >2894.443000</td>
#       <td id="T_6a806_row1_col4" class="data row1 col4" >Md1</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a806_row2_col0" class="data row2 col0" >power_plays</td>
#       <td id="T_6a806_row2_col1" class="data row2 col1" >Innocent Wafula Esimu</td>
#       <td id="T_6a806_row2_col2" class="data row2 col2" >Mbarara City Fc</td>
#       <td id="T_6a806_row2_col3" class="data row2 col3" >145.000000</td>
#       <td id="T_6a806_row2_col4" class="data row2 col4" >Md1</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a806_row3_col0" class="data row3 col0" >energy_kcal</td>
#       <td id="T_6a806_row3_col1" class="data row3 col1" >Amos Etoju</td>
#       <td id="T_6a806_row3_col2" class="data row3 col2" >Mbale Heroes Fc</td>
#       <td id="T_6a806_row3_col3" class="data row3 col3" >1771.047900</td>
#       <td id="T_6a806_row3_col4" class="data row3 col4" >Md11</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a806_row4_col0" class="data row4 col0" >impacts</td>
#       <td id="T_6a806_row4_col1" class="data row4 col1" >Blanchar Mulamba</td>
#       <td id="T_6a806_row4_col2" class="data row4 col2" >Wakiso Giants Fc</td>
#       <td id="T_6a806_row4_col3" class="data row4 col3" >46.000000</td>
#       <td id="T_6a806_row4_col4" class="data row4 col4" >Md13</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a806_row5_col0" class="data row5 col0" >total_accelerations</td>
#       <td id="T_6a806_row5_col1" class="data row5 col1" >Felix Okot</td>
#       <td id="T_6a806_row5_col2" class="data row5 col2" >Maroons Fc</td>
#       <td id="T_6a806_row5_col3" class="data row5 col3" >705.000000</td>
#       <td id="T_6a806_row5_col4" class="data row5 col4" >Md29</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a806_row6_col0" class="data row6 col0" >total_decelerations</td>
#       <td id="T_6a806_row6_col1" class="data row6 col1" >Felix Okot</td>
#       <td id="T_6a806_row6_col2" class="data row6 col2" >Maroons Fc</td>
#       <td id="T_6a806_row6_col3" class="data row6 col3" >656.000000</td>
#       <td id="T_6a806_row6_col4" class="data row6 col4" >Md29</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a806_row7_col0" class="data row7 col0" >player_load</td>
#       <td id="T_6a806_row7_col1" class="data row7 col1" >Felix Okot</td>
#       <td id="T_6a806_row7_col2" class="data row7 col2" >Maroons Fc</td>
#       <td id="T_6a806_row7_col3" class="data row7 col3" >655.960600</td>
#       <td id="T_6a806_row7_col4" class="data row7 col4" >Md29</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a806_row8_col0" class="data row8 col0" >top_speed_kmh</td>
#       <td id="T_6a806_row8_col1" class="data row8 col1" >Yafeesi Mubiru</td>
#       <td id="T_6a806_row8_col2" class="data row8 col2" >Bul Fc</td>
#       <td id="T_6a806_row8_col3" class="data row8 col3" >36.416300</td>
#       <td id="T_6a806_row8_col4" class="data row8 col4" >Md11</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a806_row9_col0" class="data row9 col0" >distance_per_min_mmin</td>
#       <td id="T_6a806_row9_col1" class="data row9 col1" >Ronald Ssekiganda</td>
#       <td id="T_6a806_row9_col2" class="data row9 col2" >Sc Villa</td>
#       <td id="T_6a806_row9_col3" class="data row9 col3" >136.524292</td>
#       <td id="T_6a806_row9_col4" class="data row9 col4" >Md1</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6a806_row10_col0" class="data row10 col0" >power_score_wkg</td>
#       <td id="T_6a806_row10_col1" class="data row10 col1" >Ronald Ssekiganda</td>
#       <td id="T_6a806_row10_col2" class="data row10 col2" >Sc Villa</td>
#       <td id="T_6a806_row10_col3" class="data row10 col3" >21.988900</td>
#       <td id="T_6a806_row10_col4" class="data row10 col4" >Md1</td>
#     </tr>
#     <tr>
#       <th id="T_6a806_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6a806_row11_col0" class="data row11 col0" >work_ratio</td>
#       <td id="T_6a806_row11_col1" class="data row11 col1" >Tonny Atukunda</td>
#       <td id="T_6a806_row11_col2" class="data row11 col2" >Sc Villa</td>
#       <td id="T_6a806_row11_col3" class="data row11 col3" >122.165500</td>

# %%
df[df['dec_counts_per_min'] == (df['dec_counts_per_min'].max())]['p_name']
# Out:
# 1164    Frank Tumwesigye
# Name: p_name, dtype: object

# %% [markdown]
# ### Comparison by Position Group

# %%
# Calculate average volume metrics by general position
avg_volume_by_position = df.groupby('general_position')[volume_metrics].mean().round(2)
style_table_for_docs(avg_volume_by_position)
# Out:
# <style type="text/css">
# #T_bfde5 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_bfde5 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_bfde5 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_bfde5_row0_col0, #T_bfde5_row0_col1, #T_bfde5_row0_col2, #T_bfde5_row0_col3, #T_bfde5_row0_col4, #T_bfde5_row0_col5, #T_bfde5_row0_col6, #T_bfde5_row1_col0, #T_bfde5_row1_col1, #T_bfde5_row1_col2, #T_bfde5_row1_col3, #T_bfde5_row1_col4, #T_bfde5_row1_col5, #T_bfde5_row1_col6, #T_bfde5_row2_col0, #T_bfde5_row2_col1, #T_bfde5_row2_col2, #T_bfde5_row2_col3, #T_bfde5_row2_col4, #T_bfde5_row2_col5, #T_bfde5_row2_col6 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_bfde5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfde5_level0_col0" class="col_heading level0 col0" >distance_km</th>
#       <th id="T_bfde5_level0_col1" class="col_heading level0 col1" >sprint_distance_m</th>
#       <th id="T_bfde5_level0_col2" class="col_heading level0 col2" >power_plays</th>
#       <th id="T_bfde5_level0_col3" class="col_heading level0 col3" >energy_kcal</th>
#       <th id="T_bfde5_level0_col4" class="col_heading level0 col4" >impacts</th>
#       <th id="T_bfde5_level0_col5" class="col_heading level0 col5" >total_accelerations</th>
#       <th id="T_bfde5_level0_col6" class="col_heading level0 col6" >total_decelerations</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfde5_level0_row0" class="row_heading level0 row0" >Defender</th>
#       <td id="T_bfde5_row0_col0" class="data row0 col0" >9.050000</td>
#       <td id="T_bfde5_row0_col1" class="data row0 col1" >852.620000</td>
#       <td id="T_bfde5_row0_col2" class="data row0 col2" >60.160000</td>
#       <td id="T_bfde5_row0_col3" class="data row0 col3" >1111.110000</td>
#       <td id="T_bfde5_row0_col4" class="data row0 col4" >6.020000</td>
#       <td id="T_bfde5_row0_col5" class="data row0 col5" >430.090000</td>
#       <td id="T_bfde5_row0_col6" class="data row0 col6" >413.270000</td>
#     </tr>
#     <tr>
#       <th id="T_bfde5_level0_row1" class="row_heading level0 row1" >Forward</th>
#       <td id="T_bfde5_row1_col0" class="data row1 col0" >7.590000</td>
#       <td id="T_bfde5_row1_col1" class="data row1 col1" >876.080000</td>
#       <td id="T_bfde5_row1_col2" class="data row1 col2" >58.300000</td>
#       <td id="T_bfde5_row1_col3" class="data row1 col3" >931.960000</td>
#       <td id="T_bfde5_row1_col4" class="data row1 col4" >7.450000</td>
#       <td id="T_bfde5_row1_col5" class="data row1 col5" >337.060000</td>
#       <td id="T_bfde5_row1_col6" class="data row1 col6" >323.830000</td>
#     </tr>
#     <tr>
#       <th id="T_bfde5_level0_row2" class="row_heading level0 row2" >Midfielder</th>
#       <td id="T_bfde5_row2_col0" class="data row2 col0" >8.720000</td>
#       <td id="T_bfde5_row2_col1" class="data row2 col1" >817.400000</td>
#       <td id="T_bfde5_row2_col2" class="data row2 col2" >62.780000</td>
#       <td id="T_bfde5_row2_col3" class="data row2 col3" >1057.100000</td>
#       <td id="T_bfde5_row2_col4" class="data row2 col4" >5.650000</td>
#       <td id="T_bfde5_row2_col5" class="data row2 col5" >411.710000</td>
#       <td id="T_bfde5_row2_col6" class="data row2 col6" >394.710000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate average intensity metrics by general position
avg_intensity_by_position = df.groupby('general_position')[[i for i in intensity_metrics if i not in ['top_speed_kmh','distance_per_min_mmin','max_acceleration_mss','max_deceleration_mss']]].mean()
style_table_for_docs(avg_intensity_by_position)
# Out:
# <style type="text/css">
# #T_4f71a th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4f71a td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_4f71a table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_4f71a_row0_col0, #T_4f71a_row0_col1, #T_4f71a_row0_col2, #T_4f71a_row0_col3, #T_4f71a_row0_col4, #T_4f71a_row1_col0, #T_4f71a_row1_col1, #T_4f71a_row1_col2, #T_4f71a_row1_col3, #T_4f71a_row1_col4, #T_4f71a_row2_col0, #T_4f71a_row2_col1, #T_4f71a_row2_col2, #T_4f71a_row2_col3, #T_4f71a_row2_col4 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_4f71a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f71a_level0_col0" class="col_heading level0 col0" >player_load</th>
#       <th id="T_4f71a_level0_col1" class="col_heading level0 col1" >power_score_wkg</th>
#       <th id="T_4f71a_level0_col2" class="col_heading level0 col2" >work_ratio</th>
#       <th id="T_4f71a_level0_col3" class="col_heading level0 col3" >acc_counts_per_min</th>
#       <th id="T_4f71a_level0_col4" class="col_heading level0 col4" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f71a_level0_row0" class="row_heading level0 row0" >Defender</th>
#       <td id="T_4f71a_row0_col0" class="data row0 col0" >415.805009</td>
#       <td id="T_4f71a_row0_col1" class="data row0 col1" >14.766578</td>
#       <td id="T_4f71a_row0_col2" class="data row0 col2" >77.056398</td>
#       <td id="T_4f71a_row0_col3" class="data row0 col3" >4.373351</td>
#       <td id="T_4f71a_row0_col4" class="data row0 col4" >4.202145</td>
#     </tr>
#     <tr>
#       <th id="T_4f71a_level0_row1" class="row_heading level0 row1" >Forward</th>
#       <td id="T_4f71a_row1_col0" class="data row1 col0" >351.255837</td>
#       <td id="T_4f71a_row1_col1" class="data row1 col1" >12.584946</td>
#       <td id="T_4f71a_row1_col2" class="data row1 col2" >62.146052</td>
#       <td id="T_4f71a_row1_col3" class="data row1 col3" >3.447049</td>
#       <td id="T_4f71a_row1_col4" class="data row1 col4" >3.312377</td>
#     </tr>
#     <tr>
#       <th id="T_4f71a_level0_row2" class="row_heading level0 row2" >Midfielder</th>
#       <td id="T_4f71a_row2_col0" class="data row2 col0" >398.656000</td>
#       <td id="T_4f71a_row2_col1" class="data row2 col1" >14.260142</td>
#       <td id="T_4f71a_row2_col2" class="data row2 col2" >76.086456</td>
#       <td id="T_4f71a_row2_col3" class="data row2 col3" >4.198015</td>
#       <td id="T_4f71a_row2_col4" class="data row2 col4" >4.024803</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate max metrics by general position
avg_intensity_by_position_ = df.groupby('general_position')[['top_speed_kmh','distance_per_min_mmin','acc_counts_per_min','dec_counts_per_min']].max().round(2)
style_table_for_docs(avg_intensity_by_position_)
# Out:
# <style type="text/css">
# #T_d164c th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_d164c td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_d164c table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_d164c_row0_col0, #T_d164c_row0_col1, #T_d164c_row0_col2, #T_d164c_row0_col3, #T_d164c_row1_col0, #T_d164c_row1_col1, #T_d164c_row1_col2, #T_d164c_row1_col3, #T_d164c_row2_col0, #T_d164c_row2_col1, #T_d164c_row2_col2, #T_d164c_row2_col3 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_d164c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d164c_level0_col0" class="col_heading level0 col0" >top_speed_kmh</th>
#       <th id="T_d164c_level0_col1" class="col_heading level0 col1" >distance_per_min_mmin</th>
#       <th id="T_d164c_level0_col2" class="col_heading level0 col2" >acc_counts_per_min</th>
#       <th id="T_d164c_level0_col3" class="col_heading level0 col3" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d164c_level0_row0" class="row_heading level0 row0" >Defender</th>
#       <td id="T_d164c_row0_col0" class="data row0 col0" >35.840000</td>
#       <td id="T_d164c_row0_col1" class="data row0 col1" >127.680000</td>
#       <td id="T_d164c_row0_col2" class="data row0 col2" >6.580000</td>
#       <td id="T_d164c_row0_col3" class="data row0 col3" >6.490000</td>
#     </tr>
#     <tr>
#       <th id="T_d164c_level0_row1" class="row_heading level0 row1" >Forward</th>
#       <td id="T_d164c_row1_col0" class="data row1 col0" >36.420000</td>
#       <td id="T_d164c_row1_col1" class="data row1 col1" >127.680000</td>
#       <td id="T_d164c_row1_col2" class="data row1 col2" >6.270000</td>
#       <td id="T_d164c_row1_col3" class="data row1 col3" >6.150000</td>
#     </tr>
#     <tr>
#       <th id="T_d164c_level0_row2" class="row_heading level0 row2" >Midfielder</th>
#       <td id="T_d164c_row2_col0" class="data row2 col0" >36.220000</td>
#       <td id="T_d164c_row2_col1" class="data row2 col1" >136.520000</td>
#       <td id="T_d164c_row2_col2" class="data row2 col2" >7.110000</td>
#       <td id="T_d164c_row2_col3" class="data row2 col3" >6.710000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate mean max metrics by general position
avg_intensity_by_position_ = df.groupby('general_position')[['top_speed_kmh','distance_per_min_mmin','acc_counts_per_min','dec_counts_per_min']].mean().round(2)
style_table_for_docs(avg_intensity_by_position_)
# Out:
# <style type="text/css">
# #T_3344d th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3344d td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_3344d table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_3344d_row0_col0, #T_3344d_row0_col1, #T_3344d_row0_col2, #T_3344d_row0_col3, #T_3344d_row1_col0, #T_3344d_row1_col1, #T_3344d_row1_col2, #T_3344d_row1_col3, #T_3344d_row2_col0, #T_3344d_row2_col1, #T_3344d_row2_col2, #T_3344d_row2_col3 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_3344d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3344d_level0_col0" class="col_heading level0 col0" >top_speed_kmh</th>
#       <th id="T_3344d_level0_col1" class="col_heading level0 col1" >distance_per_min_mmin</th>
#       <th id="T_3344d_level0_col2" class="col_heading level0 col2" >acc_counts_per_min</th>
#       <th id="T_3344d_level0_col3" class="col_heading level0 col3" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >general_position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3344d_level0_row0" class="row_heading level0 row0" >Defender</th>
#       <td id="T_3344d_row0_col0" class="data row0 col0" >29.840000</td>
#       <td id="T_3344d_row0_col1" class="data row0 col1" >91.980000</td>
#       <td id="T_3344d_row0_col2" class="data row0 col2" >4.370000</td>
#       <td id="T_3344d_row0_col3" class="data row0 col3" >4.200000</td>
#     </tr>
#     <tr>
#       <th id="T_3344d_level0_row1" class="row_heading level0 row1" >Forward</th>
#       <td id="T_3344d_row1_col0" class="data row1 col0" >30.570000</td>
#       <td id="T_3344d_row1_col1" class="data row1 col1" >77.580000</td>
#       <td id="T_3344d_row1_col2" class="data row1 col2" >3.450000</td>
#       <td id="T_3344d_row1_col3" class="data row1 col3" >3.310000</td>
#     </tr>
#     <tr>
#       <th id="T_3344d_level0_row2" class="row_heading level0 row2" >Midfielder</th>
#       <td id="T_3344d_row2_col0" class="data row2 col0" >28.450000</td>
#       <td id="T_3344d_row2_col1" class="data row2 col1" >88.930000</td>
#       <td id="T_3344d_row2_col2" class="data row2 col2" >4.200000</td>
#       <td id="T_3344d_row2_col3" class="data row2 col3" >4.020000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Draw thin horizontal lines with a large circle at the end for each position group, for four metrics in a 2x2 grid

metrics_to_plot = [
    ('top_speed_kmh', 'Top Speed (km/h)'),
    ('distance_per_min_mmin', 'Distance Per Minute (m/min)'),
    ('acc_counts_per_min', 'Acceleration Counts Per Minute'),
    ('dec_counts_per_min', 'Deceleration Counts Per Minute')
]

# Define the order of position groups
position_order = ['Defender', 'Midfielder', 'Forward']

fig, axes = plt.subplots(2, 2, figsize=(14, 7), sharey=True)

for ax, (metric, xlabel) in zip(axes.flatten(), metrics_to_plot):
    avg_by_position = df.groupby('general_position')[metric].mean().reindex(position_order)
    n = len(avg_by_position)
    y_positions = np.arange(n)
    palette = sns.color_palette('Set1', n)
    circle_radius = 16

    for y, (pos, val), color in zip(y_positions, avg_by_position.items(), palette):
        ax.hlines(y=y, xmin=0, xmax=val, color=color, linewidth=2)
        ax.plot(val, y, 'o', markeredgecolor=color, markersize=circle_radius, markerfacecolor='white')
        if metric == 'top_speed_kmh':
            text_val = f'{val:.1f}'
        elif metric == 'distance_per_min_mmin':
            text_val = f'{val:.1f}'
        elif metric == 'acc_counts_per_min':
            text_val = f'{val:.1f}'
        else:
            text_val = f'{val:.1f}'
        ax.text(val, y, text_val, va='center', ha='center', fontsize=6.5, color='black', fontweight='bold')

    yticklabels = [f"{pos}s" for pos in position_order]
    ax.set_yticks(y_positions)
    ax.set_yticklabels(yticklabels, color='#E0DCDD')
    ax.set_xlabel(xlabel)
    ax.grid(axis='x', linestyle='--', alpha=0.6)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_position(('data', 0))
    ax.spines['left'].set_color('#E0DCDD')
    ax.spines['bottom'].set_color('#E0DCDD')

axes[0,0].set_ylabel('Position Group')
axes[1,0].set_ylabel('Position Group')
fig.suptitle('Average Top Speed, Distance per Minute, Acceleration and Deceleration Counts Per Minute by Position Group')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Draw thin horizontal lines with a large circle at the end for each position group, for four metrics in a 2x2 grid

metrics_to_plot = [
    ('distance_km', 'Average Distance (km)'),
    ('total_accelerations', 'Average Total Accelerations'),
    ('sprint_distance_m', 'Average Sprint Distance (m)'),
    ('player_load', 'Average Player Load')
]

# Define the order of position groups
position_order = ['Defender', 'Midfielder', 'Forward']

fig, axes = plt.subplots(2, 2, figsize=(14, 7), sharey=True)

for ax, (metric, xlabel) in zip(axes.flatten(), metrics_to_plot):
    avg_by_position = df.groupby('general_position')[metric].mean().reindex(position_order)
    n = len(avg_by_position)
    y_positions = np.arange(n)
    palette = sns.color_palette('Set1', n)
    circle_radius = 16

    for y, (pos, val), color in zip(y_positions, avg_by_position.items(), palette):
        ax.hlines(y=y, xmin=0, xmax=val, color=color, linewidth=2)
        ax.plot(val, y, 'o', markeredgecolor=color, markersize=circle_radius, markerfacecolor='white')
        if metric == 'distance_km':
            text_val = f'{val:.1f}'
        elif metric == 'sprint_distance_m':
            text_val = f'{val:.0f}'
        elif metric == 'player_load':
            text_val = f'{val:.0f}'
        else:
            text_val = f'{val:.0f}'
        ax.text(val, y, text_val, va='center', ha='center', fontsize=6.5, color='black', fontweight='bold')

    yticklabels = [f"{pos}s" for pos in position_order]
    ax.set_yticks(y_positions)
    ax.set_yticklabels(yticklabels, color='#E0DCDD')
    ax.set_xlabel(xlabel)
    ax.grid(axis='x', linestyle='--', alpha=0.6)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_position(('data', 0))
    ax.spines['left'].set_color('#E0DCDD')
    ax.spines['bottom'].set_color('#E0DCDD')

axes[0,0].set_ylabel('Position Group')
axes[1,0].set_ylabel('Position Group')
fig.suptitle('Average Distance, Sprint Distance, Player Load, and Total Accelerations by Position Group')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ### Comparison by Location

# %%
# Calculate average volume metrics by location
avg_volume_by_location = df.groupby('location')[volume_metrics].mean().round(2)
style_table_for_docs(avg_volume_by_location)
# Out:
# <style type="text/css">
# #T_497ab th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_497ab td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_497ab table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_497ab_row0_col0, #T_497ab_row0_col1, #T_497ab_row0_col2, #T_497ab_row0_col3, #T_497ab_row0_col4, #T_497ab_row0_col5, #T_497ab_row0_col6, #T_497ab_row1_col0, #T_497ab_row1_col1, #T_497ab_row1_col2, #T_497ab_row1_col3, #T_497ab_row1_col4, #T_497ab_row1_col5, #T_497ab_row1_col6 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_497ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_497ab_level0_col0" class="col_heading level0 col0" >distance_km</th>
#       <th id="T_497ab_level0_col1" class="col_heading level0 col1" >sprint_distance_m</th>
#       <th id="T_497ab_level0_col2" class="col_heading level0 col2" >power_plays</th>
#       <th id="T_497ab_level0_col3" class="col_heading level0 col3" >energy_kcal</th>
#       <th id="T_497ab_level0_col4" class="col_heading level0 col4" >impacts</th>
#       <th id="T_497ab_level0_col5" class="col_heading level0 col5" >total_accelerations</th>
#       <th id="T_497ab_level0_col6" class="col_heading level0 col6" >total_decelerations</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_497ab_level0_row0" class="row_heading level0 row0" >Away</th>
#       <td id="T_497ab_row0_col0" class="data row0 col0" >8.500000</td>
#       <td id="T_497ab_row0_col1" class="data row0 col1" >840.480000</td>
#       <td id="T_497ab_row0_col2" class="data row0 col2" >60.300000</td>
#       <td id="T_497ab_row0_col3" class="data row0 col3" >1039.150000</td>
#       <td id="T_497ab_row0_col4" class="data row0 col4" >6.240000</td>
#       <td id="T_497ab_row0_col5" class="data row0 col5" >398.140000</td>
#       <td id="T_497ab_row0_col6" class="data row0 col6" >382.340000</td>
#     </tr>
#     <tr>
#       <th id="T_497ab_level0_row1" class="row_heading level0 row1" >Home</th>
#       <td id="T_497ab_row1_col0" class="data row1 col0" >8.580000</td>
#       <td id="T_497ab_row1_col1" class="data row1 col1" >854.910000</td>
#       <td id="T_497ab_row1_col2" class="data row1 col2" >60.740000</td>
#       <td id="T_497ab_row1_col3" class="data row1 col3" >1049.340000</td>
#       <td id="T_497ab_row1_col4" class="data row1 col4" >6.330000</td>
#       <td id="T_497ab_row1_col5" class="data row1 col5" >398.810000</td>
#       <td id="T_497ab_row1_col6" class="data row1 col6" >382.820000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate average intensity metrics by location
avg_intensity_by_location = df.groupby('location')[[i for i in intensity_metrics if i not in ['top_speed_kmh','distance_per_min_mmin','max_acceleration_mss','max_deceleration_mss']]].mean()
style_table_for_docs(avg_intensity_by_location)
# Out:
# <style type="text/css">
# #T_176e5 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_176e5 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_176e5 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_176e5_row0_col0, #T_176e5_row0_col1, #T_176e5_row0_col2, #T_176e5_row0_col3, #T_176e5_row0_col4, #T_176e5_row1_col0, #T_176e5_row1_col1, #T_176e5_row1_col2, #T_176e5_row1_col3, #T_176e5_row1_col4 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_176e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_176e5_level0_col0" class="col_heading level0 col0" >player_load</th>
#       <th id="T_176e5_level0_col1" class="col_heading level0 col1" >power_score_wkg</th>
#       <th id="T_176e5_level0_col2" class="col_heading level0 col2" >work_ratio</th>
#       <th id="T_176e5_level0_col3" class="col_heading level0 col3" >acc_counts_per_min</th>
#       <th id="T_176e5_level0_col4" class="col_heading level0 col4" >dec_counts_per_min</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_176e5_level0_row0" class="row_heading level0 row0" >Away</th>
#       <td id="T_176e5_row0_col0" class="data row0 col0" >391.110584</td>
#       <td id="T_176e5_row0_col1" class="data row0 col1" >13.939831</td>
#       <td id="T_176e5_row0_col2" class="data row0 col2" >72.425354</td>
#       <td id="T_176e5_row0_col3" class="data row0 col3" >4.056297</td>
#       <td id="T_176e5_row0_col4" class="data row0 col4" >3.895412</td>
#     </tr>
#     <tr>
#       <th id="T_176e5_level0_row1" class="row_heading level0 row1" >Home</th>
#       <td id="T_176e5_row1_col0" class="data row1 col0" >393.809442</td>
#       <td id="T_176e5_row1_col1" class="data row1 col1" >14.064635</td>
#       <td id="T_176e5_row1_col2" class="data row1 col2" >72.868524</td>
#       <td id="T_176e5_row1_col3" class="data row1 col3" >4.066085</td>
#       <td id="T_176e5_row1_col4" class="data row1 col4" >3.903248</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculate max metrics by location
avg_intensity_by_location_ = df.groupby('location')[['top_speed_kmh','distance_per_min_mmin']].mean().round(2)
style_table_for_docs(avg_intensity_by_location_)
# Out:
# <style type="text/css">
# #T_745db th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_745db td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_745db table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_745db_row0_col0, #T_745db_row0_col1, #T_745db_row1_col0, #T_745db_row1_col1 {
#   color: black;
#   background-color: white;
#   border: 1px solid black;
#   text-align: center;
#   padding: 2px;
# }
# </style>
# <table id="T_745db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_745db_level0_col0" class="col_heading level0 col0" >top_speed_kmh</th>
#       <th id="T_745db_level0_col1" class="col_heading level0 col1" >distance_per_min_mmin</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_745db_level0_row0" class="row_heading level0 row0" >Away</th>
#       <td id="T_745db_row0_col0" class="data row0 col0" >29.540000</td>
#       <td id="T_745db_row0_col1" class="data row0 col1" >86.590000</td>
#     </tr>
#     <tr>
#       <th id="T_745db_level0_row1" class="row_heading level0 row1" >Home</th>
#       <td id="T_745db_row1_col0" class="data row1 col0" >29.620000</td>
#       <td id="T_745db_row1_col1" class="data row1 col1" >87.480000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Prepare data
home_speed = avg_intensity_by_location_.loc['Home', 'top_speed_kmh']
away_speed = avg_intensity_by_location_.loc['Away', 'top_speed_kmh']

# Make radius proportional to top speed (e.g., scale so max speed gets max_radius, min gets min_radius)
min_radius = 0.8
max_radius = 1.1
speeds = np.array([home_speed, away_speed])
norm_radii = min_radius + (speeds - speeds.min()) / (speeds.max() - speeds.min()) * (max_radius - min_radius)
home_radius, away_radius = norm_radii

color = '#003b59'

fig, ax = plt.subplots(figsize=(3, 3))
ax.set_aspect('equal')
ax.axis('off')

# Draw right (Home) semicircle: theta from -pi/2 to pi/2, center at (0,0)
theta_home = np.linspace(-np.pi/2, np.pi/2, 100)
x_home = home_radius * np.cos(theta_home)
y_home = home_radius * np.sin(theta_home)
ax.plot(x_home, y_home, color=color, linewidth=0.5)
if home_radius < away_radius:
    ax.fill_betweenx(y_home, 0, x_home, color=color, alpha=0.5)

# Draw left (Away) semicircle: theta from pi/2 to 3pi/2, center at (0,0)
theta_away = np.linspace(np.pi/2, 3*np.pi/2, 100)
x_away = away_radius * np.cos(theta_away)
y_away = away_radius * np.sin(theta_away)
ax.plot(x_away, y_away, color=color, linewidth=0.5)
if away_radius < home_radius:
    ax.fill_betweenx(y_away, x_away, 0, color=color, alpha=0.5)

# Draw the separating line (y from -max_radius to +max_radius at x=0)
ax.plot([0, 0], [-max(home_radius+0.5, away_radius+0.5), max(home_radius+0.5, away_radius+0.5)], color=color, linewidth=0.5, zorder=3)

# Place values inside semicircles, centered
ax.text(home_radius * 0.5, 0, f"{home_speed:.2f}\nHome", ha='center', va='center', fontsize=10, color='#000', fontweight='normal')
ax.text(-away_radius * 0.5, 0, f"{away_speed:.2f}\nAway", ha='center', va='center', fontsize=10, color='#fff', fontweight='normal')

plt.title('Top Speed (km/hr)', fontsize=12)
plt.show()

# %% [markdown]
# ### Metric Distribution

# %%
plt.figure(figsize=(16, 16))
for i, col in enumerate(num_cols):
    plt.subplot(5, 3, i + 1)
    sns.histplot(df[col], bins=30, kde=True)
    # Format title and x-label: replace _ with space, capitalize, add units if present
    label = col.replace('_', ' ').title()
    # Add units for specific columns
    if col == 'distance_km':
        label = 'Distance (km)'
    elif col == 'sprint_distance_m':
        label = 'Sprint Distance (m)'
    elif col == 'top_speed_kmh':
        label = 'Top Speed (km/h)'
    elif col == 'distance_per_min_mmin':
        label = 'Distance per Min (m/min)'
    elif col == 'power_score_wkg':
        label = 'Power Score (W/kg)'
    elif col == 'max_acceleration_mss':
        label = 'Max Acceleration (m/s²)'
    elif col == 'max_deceleration_mss':
        label = 'Max Deceleration (m/s²)'
    elif col == 'acc_counts_per_min':
        label = 'Acc. Counts per Min'
    elif col == 'dec_counts_per_min':
        label = 'Dec. Counts per Min'
    
    plt.title(f'Distribution of {label}')
    plt.xlabel(label)
    plt.xticks(rotation=90)
    # Remove top and right spines
    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

# %%
# Comparative bar graph for three leagues using vertical lines with large circles on top

leagues = [ 'UCL','PSL', 'UPL']
values = [ 10.94,10.045, 8.54]
palette = sns.color_palette('Set1', len(leagues))
circle_radius = 20

fig, ax = plt.subplots(figsize=(4, 4))

# Draw vertical lines for each league
for i, (league, val, color) in enumerate(zip(leagues, values, palette)):
    ax.vlines(i, 0, val, color=color, linewidth=3, zorder=2)
    ax.plot(i, val, 'o', markeredgecolor=color, markerfacecolor='white', markersize=circle_radius, zorder=3)
    ax.text(i, val, f'{val:.1f}', va='top', ha='center', fontweight='bold',fontsize=7, color='black')

ax.set_xticks(range(len(leagues)))
ax.set_xticklabels(leagues)
ax.set_ylabel('Average Total Distance Covered (km)')
ax.set_xlabel('League')
ax.set_title('Average Total Distance Covered by Players in Different Leagues', fontsize=11, fontweight='bold')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#E0DCDD')
ax.spines['bottom'].set_color('#E0DCDD')
ax.grid(axis='y', linestyle='--', alpha=0.6, zorder=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Trend Analysis

# %%
avg_volume_per_matchday = df.groupby('match_day')[volume_metrics + intensity_metrics].mean().reset_index()
# Ensure 'match_day' is a categorical variable with the correct order
avg_volume_per_matchday['match_day'] = pd.Categorical(
    avg_volume_per_matchday['match_day'],
    categories=matchday_order,
    ordered=True
)
avg_volume_per_matchday = avg_volume_per_matchday.sort_values(by='match_day').round(2)
style_table_for_docs(avg_volume_per_matchday)
# Out:
# <style type="text/css">
# #T_684a2 th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_684a2 td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_684a2 table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_684a2_row0_col0, #T_684a2_row0_col1, #T_684a2_row0_col2, #T_684a2_row0_col3, #T_684a2_row0_col4, #T_684a2_row0_col5, #T_684a2_row0_col6, #T_684a2_row0_col7, #T_684a2_row0_col8, #T_684a2_row0_col9, #T_684a2_row0_col10, #T_684a2_row0_col11, #T_684a2_row0_col12, #T_684a2_row0_col13, #T_684a2_row0_col14, #T_684a2_row0_col15, #T_684a2_row0_col16, #T_684a2_row1_col0, #T_684a2_row1_col1, #T_684a2_row1_col2, #T_684a2_row1_col3, #T_684a2_row1_col4, #T_684a2_row1_col5, #T_684a2_row1_col6, #T_684a2_row1_col7, #T_684a2_row1_col8, #T_684a2_row1_col9, #T_684a2_row1_col10, #T_684a2_row1_col11, #T_684a2_row1_col12, #T_684a2_row1_col13, #T_684a2_row1_col14, #T_684a2_row1_col15, #T_684a2_row1_col16, #T_684a2_row2_col0, #T_684a2_row2_col1, #T_684a2_row2_col2, #T_684a2_row2_col3, #T_684a2_row2_col4, #T_684a2_row2_col5, #T_684a2_row2_col6, #T_684a2_row2_col7, #T_684a2_row2_col8, #T_684a2_row2_col9, #T_684a2_row2_col10, #T_684a2_row2_col11, #T_684a2_row2_col12, #T_684a2_row2_col13, #T_684a2_row2_col14, #T_684a2_row2_col15, #T_684a2_row2_col16, #T_684a2_row3_col0, #T_684a2_row3_col1, #T_684a2_row3_col2, #T_684a2_row3_col3, #T_684a2_row3_col4, #T_684a2_row3_col5, #T_684a2_row3_col6, #T_684a2_row3_col7, #T_684a2_row3_col8, #T_684a2_row3_col9, #T_684a2_row3_col10, #T_684a2_row3_col11, #T_684a2_row3_col12, #T_684a2_row3_col13, #T_684a2_row3_col14, #T_684a2_row3_col15, #T_684a2_row3_col16, #T_684a2_row4_col0, #T_684a2_row4_col1, #T_684a2_row4_col2, #T_684a2_row4_col3, #T_684a2_row4_col4, #T_684a2_row4_col5, #T_684a2_row4_col6, #T_684a2_row4_col7, #T_684a2_row4_col8, #T_684a2_row4_col9, #T_684a2_row4_col10, #T_684a2_row4_col11, #T_684a2_row4_col12, #T_684a2_row4_col13, #T_684a2_row4_col14, #T_684a2_row4_col15, #T_684a2_row4_col16, #T_684a2_row5_col0, #T_684a2_row5_col1, #T_684a2_row5_col2, #T_684a2_row5_col3, #T_684a2_row5_col4, #T_684a2_row5_col5, #T_684a2_row5_col6, #T_684a2_row5_col7, #T_684a2_row5_col8, #T_684a2_row5_col9, #T_684a2_row5_col10, #T_684a2_row5_col11, #T_684a2_row5_col12, #T_684a2_row5_col13, #T_684a2_row5_col14, #T_684a2_row5_col15, #T_684a2_row5_col16, #T_684a2_row6_col0, #T_684a2_row6_col1, #T_684a2_row6_col2, #T_684a2_row6_col3, #T_684a2_row6_col4, #T_684a2_row6_col5, #T_684a2_row6_col6, #T_684a2_row6_col7, #T_684a2_row6_col8, #T_684a2_row6_col9, #T_684a2_row6_col10, #T_684a2_row6_col11, #T_684a2_row6_col12, #T_684a2_row6_col13, #T_684a2_row6_col14, #T_684a2_row6_col15, #T_684a2_row6_col16, #T_684a2_row7_col0, #T_684a2_row7_col1, #T_684a2_row7_col2, #T_684a2_row7_col3, #T_684a2_row7_col4, #T_684a2_row7_col5, #T_684a2_row7_col6, #T_684a2_row7_col7, #T_684a2_row7_col8, #T_684a2_row7_col9, #T_684a2_row7_col10, #T_684a2_row7_col11, #T_684a2_row7_col12, #T_684a2_row7_col13, #T_684a2_row7_col14, #T_684a2_row7_col15, #T_684a2_row7_col16, #T_684a2_row8_col0, #T_684a2_row8_col1, #T_684a2_row8_col2, #T_684a2_row8_col3, #T_684a2_row8_col4, #T_684a2_row8_col5, #T_684a2_row8_col6, #T_684a2_row8_col7, #T_684a2_row8_col8, #T_684a2_row8_col9, #T_684a2_row8_col10, #T_684a2_row8_col11, #T_684a2_row8_col12, #T_684a2_row8_col13, #T_684a2_row8_col14, #T_684a2_row8_col15, #T_684a2_row8_col16, #T_684a2_row9_col0, #T_684a2_row9_col1, #T_684a2_row9_col2, #T_684a2_row9_col3, #T_684a2_row9_col4, #T_684a2_row9_col5, #T_684a2_row9_col6, #T_684a2_row9_col7, #T_684a2_row9_col8, #T_684a2_row9_col9, #T_684a2_row9_col10, #T_684a2_row9_col11, #T_684a2_row9_col12, #T_684a2_row9_col13, #T_684a2_row9_col14, #T_684a2_row9_col15, #T_684a2_row9_col16, #T_684a2_row10_col0, #T_684a2_row10_col1, #T_684a2_row10_col2, #T_684a2_row10_col3, #T_684a2_row10_col4, #T_684a2_row10_col5, #T_684a2_row10_col6, #T_684a2_row10_col7, #T_684a2_row10_col8, #T_684a2_row10_col9, #T_684a2_row10_col10, #T_684a2_row10_col11, #T_684a2_row10_col12, #T_684a2_row10_col13, #T_684a2_row10_col14, #T_684a2_row10_col15, #T_684a2_row10_col16, #T_684a2_row11_col0, #T_684a2_row11_col1, #T_684a2_row11_col2, #T_684a2_row11_col3, #T_684a2_row11_col4, #T_684a2_row11_col5, #T_684a2_row11_col6, #T_684a2_row11_col7 ...

# %%
# Sort by match_day using the correct order
df['match_day'] = pd.Categorical(df['match_day'], categories=matchday_order, ordered=True)
df_sorted = df.sort_values('match_day')

# Compute rolling mean for each metric per match day
rolling_avg = (
    df_sorted.groupby('match_day', observed=True)[volume_metrics + intensity_metrics]
    .mean()
    .rolling(window=3, min_periods=1)
    .mean()
    .reset_index()
)

rolling_avg['match_day'] = pd.Categorical(rolling_avg['match_day'], categories=matchday_order, ordered=True)
rolling_avg = rolling_avg.sort_values(by='match_day').round(2)
style_table_for_docs(rolling_avg)
# Out:
# <style type="text/css">
# #T_e48ac th {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e48ac td {
#   color: black;
#   border: 1px solid black;
#   padding: 2px;
# }
# #T_e48ac table {
#   border: 2px solid black;
#   border-collapse: collapse;
# }
# #T_e48ac_row0_col0, #T_e48ac_row0_col1, #T_e48ac_row0_col2, #T_e48ac_row0_col3, #T_e48ac_row0_col4, #T_e48ac_row0_col5, #T_e48ac_row0_col6, #T_e48ac_row0_col7, #T_e48ac_row0_col8, #T_e48ac_row0_col9, #T_e48ac_row0_col10, #T_e48ac_row0_col11, #T_e48ac_row0_col12, #T_e48ac_row0_col13, #T_e48ac_row0_col14, #T_e48ac_row0_col15, #T_e48ac_row0_col16, #T_e48ac_row1_col0, #T_e48ac_row1_col1, #T_e48ac_row1_col2, #T_e48ac_row1_col3, #T_e48ac_row1_col4, #T_e48ac_row1_col5, #T_e48ac_row1_col6, #T_e48ac_row1_col7, #T_e48ac_row1_col8, #T_e48ac_row1_col9, #T_e48ac_row1_col10, #T_e48ac_row1_col11, #T_e48ac_row1_col12, #T_e48ac_row1_col13, #T_e48ac_row1_col14, #T_e48ac_row1_col15, #T_e48ac_row1_col16, #T_e48ac_row2_col0, #T_e48ac_row2_col1, #T_e48ac_row2_col2, #T_e48ac_row2_col3, #T_e48ac_row2_col4, #T_e48ac_row2_col5, #T_e48ac_row2_col6, #T_e48ac_row2_col7, #T_e48ac_row2_col8, #T_e48ac_row2_col9, #T_e48ac_row2_col10, #T_e48ac_row2_col11, #T_e48ac_row2_col12, #T_e48ac_row2_col13, #T_e48ac_row2_col14, #T_e48ac_row2_col15, #T_e48ac_row2_col16, #T_e48ac_row3_col0, #T_e48ac_row3_col1, #T_e48ac_row3_col2, #T_e48ac_row3_col3, #T_e48ac_row3_col4, #T_e48ac_row3_col5, #T_e48ac_row3_col6, #T_e48ac_row3_col7, #T_e48ac_row3_col8, #T_e48ac_row3_col9, #T_e48ac_row3_col10, #T_e48ac_row3_col11, #T_e48ac_row3_col12, #T_e48ac_row3_col13, #T_e48ac_row3_col14, #T_e48ac_row3_col15, #T_e48ac_row3_col16, #T_e48ac_row4_col0, #T_e48ac_row4_col1, #T_e48ac_row4_col2, #T_e48ac_row4_col3, #T_e48ac_row4_col4, #T_e48ac_row4_col5, #T_e48ac_row4_col6, #T_e48ac_row4_col7, #T_e48ac_row4_col8, #T_e48ac_row4_col9, #T_e48ac_row4_col10, #T_e48ac_row4_col11, #T_e48ac_row4_col12, #T_e48ac_row4_col13, #T_e48ac_row4_col14, #T_e48ac_row4_col15, #T_e48ac_row4_col16, #T_e48ac_row5_col0, #T_e48ac_row5_col1, #T_e48ac_row5_col2, #T_e48ac_row5_col3, #T_e48ac_row5_col4, #T_e48ac_row5_col5, #T_e48ac_row5_col6, #T_e48ac_row5_col7, #T_e48ac_row5_col8, #T_e48ac_row5_col9, #T_e48ac_row5_col10, #T_e48ac_row5_col11, #T_e48ac_row5_col12, #T_e48ac_row5_col13, #T_e48ac_row5_col14, #T_e48ac_row5_col15, #T_e48ac_row5_col16, #T_e48ac_row6_col0, #T_e48ac_row6_col1, #T_e48ac_row6_col2, #T_e48ac_row6_col3, #T_e48ac_row6_col4, #T_e48ac_row6_col5, #T_e48ac_row6_col6, #T_e48ac_row6_col7, #T_e48ac_row6_col8, #T_e48ac_row6_col9, #T_e48ac_row6_col10, #T_e48ac_row6_col11, #T_e48ac_row6_col12, #T_e48ac_row6_col13, #T_e48ac_row6_col14, #T_e48ac_row6_col15, #T_e48ac_row6_col16, #T_e48ac_row7_col0, #T_e48ac_row7_col1, #T_e48ac_row7_col2, #T_e48ac_row7_col3, #T_e48ac_row7_col4, #T_e48ac_row7_col5, #T_e48ac_row7_col6, #T_e48ac_row7_col7, #T_e48ac_row7_col8, #T_e48ac_row7_col9, #T_e48ac_row7_col10, #T_e48ac_row7_col11, #T_e48ac_row7_col12, #T_e48ac_row7_col13, #T_e48ac_row7_col14, #T_e48ac_row7_col15, #T_e48ac_row7_col16, #T_e48ac_row8_col0, #T_e48ac_row8_col1, #T_e48ac_row8_col2, #T_e48ac_row8_col3, #T_e48ac_row8_col4, #T_e48ac_row8_col5, #T_e48ac_row8_col6, #T_e48ac_row8_col7, #T_e48ac_row8_col8, #T_e48ac_row8_col9, #T_e48ac_row8_col10, #T_e48ac_row8_col11, #T_e48ac_row8_col12, #T_e48ac_row8_col13, #T_e48ac_row8_col14, #T_e48ac_row8_col15, #T_e48ac_row8_col16, #T_e48ac_row9_col0, #T_e48ac_row9_col1, #T_e48ac_row9_col2, #T_e48ac_row9_col3, #T_e48ac_row9_col4, #T_e48ac_row9_col5, #T_e48ac_row9_col6, #T_e48ac_row9_col7, #T_e48ac_row9_col8, #T_e48ac_row9_col9, #T_e48ac_row9_col10, #T_e48ac_row9_col11, #T_e48ac_row9_col12, #T_e48ac_row9_col13, #T_e48ac_row9_col14, #T_e48ac_row9_col15, #T_e48ac_row9_col16, #T_e48ac_row10_col0, #T_e48ac_row10_col1, #T_e48ac_row10_col2, #T_e48ac_row10_col3, #T_e48ac_row10_col4, #T_e48ac_row10_col5, #T_e48ac_row10_col6, #T_e48ac_row10_col7, #T_e48ac_row10_col8, #T_e48ac_row10_col9, #T_e48ac_row10_col10, #T_e48ac_row10_col11, #T_e48ac_row10_col12, #T_e48ac_row10_col13, #T_e48ac_row10_col14, #T_e48ac_row10_col15, #T_e48ac_row10_col16, #T_e48ac_row11_col0, #T_e48ac_row11_col1, #T_e48ac_row11_col2, #T_e48ac_row11_col3, #T_e48ac_row11_col4, #T_e48ac_row11_col5, #T_e48ac_row11_col6, #T_e48ac_row11_col7 ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
metrics = [
    ('distance_km', 'Distance (km)'),
    ('sprint_distance_m', 'Sprint Distance (m)'),
    ('player_load', 'Player Load'),
    ('top_speed_kmh', 'Top Speed (km/h)')
]

md15_idx = matchday_order.index('Md15')

for ax, (col, label) in zip(axes.flatten(), metrics):
    sns.lineplot(
        data=rolling_avg,
        x='match_day',
        y=col,
        marker='o',
        ax=ax,
        label=f'Average {label}'
    )
    avg_value = rolling_avg[col].mean()
    ax.axhline(avg_value, color='red', linestyle='--', label=f'Season Average: {avg_value:.2f}')
    # Draw vertical line at MD15
    ax.axvline(md15_idx, color='black', linestyle=':', linewidth=1)
    # Shade area before MD15 (First Round)
    ax.axvspan(-0.5, md15_idx - 0.5, color='skyblue', alpha=0.35)
    # Shade area after and including MD15 (Second Round)
    ax.axvspan(md15_idx - 0.5, md15_idx + 0.5, color='lightgreen', alpha=0.35)
    ax.axvspan(md15_idx + 0.5, len(matchday_order) - 0.5, color='lightgreen', alpha=0.35)
    xticklabels = [str(md).replace('Md', 'MD ') for md in rolling_avg['match_day']]
    ax.set_xticks(range(len(rolling_avg['match_day'])))
    ax.set_xticklabels(xticklabels, rotation=90)
    ax.set_title(f'{label} Across Match Days')
    ax.set_xlabel('Match Day')
    ax.set_ylabel(label)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    legend = ax.legend(frameon=False)
    ymin, ymax = ax.get_ylim()
    ax.text(md15_idx/2, avg_value - (ymax-ymin)*0.12, 'First Round', color='blue', fontsize=12, ha='center', va='top', alpha=0.7)
    ax.text(md15_idx + (len(matchday_order)-md15_idx)/2, avg_value + (ymax-ymin)*0.08, 'Second Round', color='green', fontsize=12, ha='center', va='bottom', alpha=0.7)

plt.tight_layout(rect=[0, 0.04, 1, 1])
plt.figtext(0.5, 0.01, "Note: All values are from a 3-match rolling average.", ha='center', fontsize=12, style='italic')
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
cols_to_corr = [col for col in num_cols if col != 'duration']
cols_to_corr.extend(['acc_counts_per_min','dec_counts_per_min','total_accelerations','total_decelerations'])
corr = df[cols_to_corr].corr(method='pearson')

# Mapping for pretty axis labels
pretty_labels = {
    'distance_km': 'Distance (km)',
    'sprint_distance_m': 'Sprint Distance (m)',
    'power_plays': 'Power Plays',
    'energy_kcal': 'Energy (kcal)',
    'impacts': 'Impacts',
    'player_load': 'Player Load',
    'top_speed_kmh': 'Top Speed (km/h)',
    'distance_per_min_mmin': 'Distance per Min (m/min)',
    'power_score_wkg': 'Power Score (W/kg)',
    'work_ratio': 'Work Ratio',
    'max_acceleration_mss': 'Max Acceleration (m/s²)',
    'max_deceleration_mss': 'Max Deceleration (m/s²)',
    'acc_counts_per_min':'Acceleration Counts Per Minute',
    'dec_counts_per_min':'Deceleration Counts Per Minute',
    'total_accelerations': 'Total Accelerations',
    'total_decelerations': 'Total Decelerations'
}

# Re-label the correlation matrix
corr = corr.rename(index=pretty_labels, columns=pretty_labels)

mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(8, 6))
sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5,
    mask=mask,
    annot_kws={"fontsize":8, "fontfamily":"serif"}
)
plt.title("Correlation Between Physical Performance Metrics", fontsize=12, fontfamily="serif")
plt.xticks(fontsize=8, fontfamily="serif", fontstyle="italic")
plt.yticks(fontsize=8, fontfamily="serif", fontstyle="italic")
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# Plot 1: All players, no hue
ax1 = axes[0]
sns.scatterplot(data=df, x='distance_km', y='sprint_distance_m', alpha=0.5, ax=ax1)
sns.regplot(data=df, x='distance_km', y='sprint_distance_m', scatter=False, ax=ax1, color='red', line_kws={'linewidth':1})
ax1.set_xlabel('Distance (km)')
ax1.set_ylabel('Sprint Distance (m)')
ax1.set_title('All Players')
ax1.grid(False)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_color('#E0DCDD')
ax1.spines['bottom'].set_color('#E0DCDD')

# Plot 2: Hue by player position, trend lines for each group
ax2 = axes[1]
sns.scatterplot(data=df, x='distance_km', y='sprint_distance_m', hue='general_position', alpha=0.2, ax=ax2)
for pos in df['general_position'].dropna().unique():
    sns.regplot(
        data=df[df['general_position'] == pos],
        x='distance_km',
        y='sprint_distance_m',
        scatter=False,
        ax=ax2,
        label=f"{pos} Trend",
        line_kws={'linewidth':1}
    )
ax2.set_xlabel('Distance (km)')
ax2.set_ylabel('Sprint Distance (m)')
ax2.set_title('By Player Position')
ax2.grid(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_color('#E0DCDD')
ax2.spines['bottom'].set_color('#E0DCDD')
ax2.legend(title='Position')

plt.suptitle('Relationship Between Total Distance and Sprint Distance')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
df[df['p_name'] == 'Brian Nkuubi'].describe().T
# Out:
#                            count         mean         std         min  \
# duration                    11.0    97.834848    3.371601   93.816667
# distance_km                 11.0    10.239109    2.593766    2.603100
# sprint_distance_m           11.0  1049.014545  264.467277  433.118000
# power_plays                 11.0    82.090909   22.042933   21.000000
# energy_kcal                 11.0  1235.483745  314.254983  313.990900
# ...                          ...          ...         ...         ...
# time_in_speed_zone_5_secs   11.0     7.654545    3.480047    2.100000
# total_accelerations         11.0   446.454545  125.383702  109.000000
# total_decelerations         11.0   438.181818  122.068684  108.000000
# acc_counts_per_min          11.0     4.567922    1.303166    1.127586
# dec_counts_per_min          11.0     4.484255    1.271863    1.117241
#
#                                    25%          50%          75%          max
# duration                     96.400000    96.933333    98.883333   106.266667
# distance_km                  10.407800    10.989000    11.284900    12.065600
# sprint_distance_m           980.834000  1014.799000  1165.071000  1428.996000
# power_plays                  79.500000    91.000000    93.000000   102.000000
# energy_kcal                1257.169000  1317.676700  1373.918350  1462.840400
# ...                                ...          ...          ...          ...
# time_in_speed_zone_5_secs     6.250000     7.500000     8.850000    14.800000
# total_accelerations         425.000000   455.000000   531.500000   565.000000
# total_decelerations         421.500000   441.000000   511.500000   559.000000
# acc_counts_per_min            4.305859     4.706664     5.507058     5.852901
# dec_counts_per_min            4.311017     4.581025     5.299036     5.790746
#
# [84 rows x 8 columns]

# %%
df[df['p_name'] == 'Bashir Mutanda'].describe().T
# Out:
#                            count        mean         std         min  \
# duration                     5.0   96.773333    1.666067   94.916667
# distance_km                  5.0    5.516540    2.033102    3.513700
# sprint_distance_m            5.0  350.357600  121.810832  203.935000
# power_plays                  5.0   26.400000    9.939819   17.000000
# energy_kcal                  5.0  681.701200  249.053857  434.832600
# ...                          ...         ...         ...         ...
# time_in_speed_zone_5_secs    5.0    5.160000    2.373394    2.600000
# total_accelerations          5.0  250.000000   77.035706  176.000000
# total_decelerations          5.0  239.400000   73.108139  166.000000
# acc_counts_per_min           5.0    2.574907    0.748288    1.823834
# dec_counts_per_min           5.0    2.465996    0.711057    1.720207
#
#                                   25%         50%         75%          max
# duration                    95.850000   96.500000   97.283333    99.316667
# distance_km                  4.464200    4.582600    6.373900     8.648300
# sprint_distance_m          250.304000  369.561000  434.788000   493.200000
# power_plays                 19.000000   25.000000   29.000000    42.000000
# energy_kcal                557.708000  570.036900  776.492000  1069.436500
# ...                               ...         ...         ...          ...
# time_in_speed_zone_5_secs    3.600000    5.100000    5.700000     8.800000
# total_accelerations        204.000000  226.000000  271.000000   373.000000
# total_decelerations        195.000000  220.000000  262.000000   354.000000
# acc_counts_per_min           2.128326    2.381036    2.785678     3.755664
# dec_counts_per_min           2.034429    2.317823    2.693164     3.564356
#
# [84 rows x 8 columns]

# %%
sns.scatterplot(data=df, x='distance_per_min_mmin', y='player_load', alpha=0.6)
plt.xlabel('Distance per Minute (m/min)')
plt.ylabel('Player Load')
plt.title('Scatterplot of Distance per Minute vs Player Load')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
